# %% [markdown]
# *Contents*
# ===
# - [1.Killing Time Trend Analysis](#1.Killing-Time-Trends-Analysis)
#     - [1.1Killing time trend](#1.1Killing-time-trend)
#     - [1.2Weapon used time trend](#1.2Weapon-used-time-trend)
#     - [1.3Body Camera usage time trend](#1.3Body-Camera-usage-time-trend)
# - [2.Gender Killing](#2.Gender-Killing)
# - [3.Age Killing](#3.Age-Killing)
# - [4.Mental Illness  Inference](#4.Mental-Illness-Inference)
# - [5.Race and body camera relation](#5.Race-and-body-camera-relation)
# - [6.Cleaning median household income data](#6.Cleaning-median-household-income-data)
# - [7.Cleaning percentage people below poverty level data](#7.Cleaning-percentage-people-below-poverty-level-data)
# - [8.Cleaning population density dataset](#8.Cleaning-population-density-dataset)
# - [9.Merging median household income and percentage people below poverty level data](#9.Merging-median-household-income-and-percentage-people-below-poverty-level-data)
# - [10.Data cleaning on percentage over 25 that completed high school dataset](#10.Data-cleaning-on-percentage-over-25-that-completed-high-school-dataset)
# - [11.Merging people below poverty level and percent over 25 that completed highschool dataset](#11.Merging-people-below-poverty-level-and-percent-over-25-that-completed-highschool-dataset)
# - [12.Data cleaning and merging People below poverty level, percent over 25 that completed highschool and median household income](#12.Data-cleaning-and-merging-People-below-poverty-level,-percent-over-25-that-completed-highschool-and-median-household-income)
# - [13.Data cleaning on shared race by city and merging with the main dataframe](#13.Data-cleaning-on-shared-race-by-city-and-merging-with-the-main-dataframe)
# - [14.Merging killing dataset with the main dataframe](#14.Merging-killing-dataset-with-the-main-dataframe)
# - [15.Economic and killing inference by race](#15.Economic-and-killing-inference-by-race)
#     - [15.1White people](#15.1White-people)
#     - [15.2Black people](#15.2Black-people)
#     - [15.3Hispanic people](#15.3Hispanic-people)
#     - [15.4Native americans people](#15.4Native-americans-people)
#     - [15.5Asian people](#15.5Asian-people)
# - [16.Killing by race and by state visualization with bars](#16.Killing-by-race-and-by-state-visualization-with-bars)
# - [17.Killing inference based on geographical mapped data](#17.Killing-inference-based-on-geographical-mapped-data)

# %%
import os
from datetime import datetime as dt

# %%
os.getcwd()
#os.chdir()
# Out:
# 'C:\\Users\\Fabry\\JupiterNotebook\\Git\\KagglePoliceKilling\\KagglePoliceKilling'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

df = pd.read_csv('fatal-police-shootings-data.csv',
                 parse_dates=True,
                 index_col='date')
df.head(5)
# Out:
#             id                name   manner_of_death       armed   age gender  \
# date
# 2015-01-02   3          Tim Elliot              shot         gun  53.0      M
# 2015-01-02   4    Lewis Lee Lembke              shot         gun  47.0      M
# 2015-01-03   5  John Paul Quintero  shot and Tasered     unarmed  23.0      M
# 2015-01-04   8     Matthew Hoffman              shot  toy weapon  32.0      M
# 2015-01-04   9   Michael Rodriguez              shot    nail gun  39.0      M
#
#            race           city state  signs_of_mental_illness threat_level  \
# date
# 2015-01-02    A        Shelton    WA                     True       attack
# 2015-01-02    W          Aloha    OR                    False       attack
# 2015-01-03    H        Wichita    KS                    False        other
# 2015-01-04    W  San Francisco    CA                     True       attack
# 2015-01-04    H          Evans    CO                    False       attack
#
#                    flee  body_camera  longitude  latitude  is_geocoding_exact
# date
# 2015-01-02  Not fleeing        False   -123.122    47.247                True
# 2015-01-02  Not fleeing        False   -122.892    45.487                True
# 2015-01-03  Not fleeing        False    -97.281    37.695                True
# 2015-01-04  Not fleeing        False   -122.422    37.763                True
# 2015-01-04  Not fleeing        False   -104.692    40.384                True

# %% [markdown]
# 1.Killing Time Trend Analysis
# ===
# Innanzi tutto vorrei capire se il trend di uccisioni è in aumento o meno nel tempo oppure è invariante.

# %% [markdown]
# Trattandosi di un'analisi di un'osservazione, non è estrapolabile nessun tipo di causalità ma solamente delle associazioni in quanto i dati non sono frutto di un processo random. Un'altra informazione che ci manca riguarda la completezza dei dati: non sapendo come sono stati raccolti i dati, l'osservazione non è generalizzabile.

# %%
df2=df.copy()

# %% [markdown]
# Nel codice sopra mi sono assicurato di eliminare tutti i leading e trailing spaces perchè nei merge che farò più avanti potrei avere problemi nel matching delle colonne comuni ai vari dataframe.

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6419 entries, 2015-01-02 to 2021-06-30
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       6419 non-null   int64
#  1   name                     6178 non-null   object
#  2   manner_of_death          6419 non-null   object
#  3   armed                    6211 non-null   object
#  4   age                      6127 non-null   float64
#  5   gender                   6418 non-null   object
#  6   race                     5726 non-null   object
#  7   city                     6419 non-null   object
#  8   state                    6419 non-null   object
#  9   signs_of_mental_illness  6419 non-null   bool
#  10  threat_level             6419 non-null   object
#  11  flee                     5985 non-null   object
#  12  body_camera              6419 non-null   bool
#  13  longitude                6108 non-null   float64
#  14  latitude                 6108 non-null   float64
#  15  is_geocoding_exact       6419 non-null   bool
# dtypes: bool(3), float64(3), int64(1), object(9)
# memory usage: 720.9+ KB

# %%
df2.head()
# Out:
#             id                name   manner_of_death       armed   age gender  \
# date
# 2015-01-02   3          Tim Elliot              shot         gun  53.0      M
# 2015-01-02   4    Lewis Lee Lembke              shot         gun  47.0      M
# 2015-01-03   5  John Paul Quintero  shot and Tasered     unarmed  23.0      M
# 2015-01-04   8     Matthew Hoffman              shot  toy weapon  32.0      M
# 2015-01-04   9   Michael Rodriguez              shot    nail gun  39.0      M
#
#            race           city state  signs_of_mental_illness threat_level  \
# date
# 2015-01-02    A        Shelton    WA                     True       attack
# 2015-01-02    W          Aloha    OR                    False       attack
# 2015-01-03    H        Wichita    KS                    False        other
# 2015-01-04    W  San Francisco    CA                     True       attack
# 2015-01-04    H          Evans    CO                    False       attack
#
#                    flee  body_camera  longitude  latitude  is_geocoding_exact
# date
# 2015-01-02  Not fleeing        False   -123.122    47.247                True
# 2015-01-02  Not fleeing        False   -122.892    45.487                True
# 2015-01-03  Not fleeing        False    -97.281    37.695                True
# 2015-01-04  Not fleeing        False   -122.422    37.763                True
# 2015-01-04  Not fleeing        False   -104.692    40.384                True

# %% [markdown]
# Estrapolo mese e anno per creare la sequenza di dati temporali

# %%
df2['YYMM'] = df2.index.strftime('%Y-%m')

# %%
import numpy as np

# %% [markdown]
# 1.1Killing time trend
# ---

# %% [markdown]
# Creo un array di uno per contare le uccisioni mensili e capire se c'è un qualche trend temporale

# %%
df2['Counter'] = np.ones(len(df))

# %%
srKillingTrend = df2.groupby('YYMM')['Counter'].count()

# %%
type(srKillingTrend)
# Out:
# pandas.core.series.Series

# %%
srKillingTrend.plot(figsize=(15, 3), title='Killing Trend by month')
# Out:
# <AxesSubplot:title={'center':'Killing Trend by month'}, xlabel='YYMM'>

# %% [markdown]
# Da questo grafico si può evincere che nel tempo questa oscillazione è ristretta a un range definito, di conseguenza non ci son trend o pattern che permettano di fare ulteriori inferenze.

# %%
df2['YY'] = df2.index.strftime('%Y')
srKillingTrendByYear = df2.groupby('YY')['Counter'].count()
srKillingTrendByYear
# Out:
# YY
# 2015     993
# 2016     960
# 2017     986
# 2018     990
# 2019     999
# 2020    1021
# 2021     470
# Name: Counter, dtype: int64

# %% [markdown]
# 1.2Weapon used time trend
# ---

# %% [markdown]
# Ripulisco le stringhe del file csv da spazi bianchi

# %%
df2["armed"]=df2["armed"].str.strip()

# %%
dfRaceArmed2 = df2.groupby("armed", sort=True).count()

# %%
dfRaceArmed2.head()
# Out:
#                     id  name  manner_of_death  age  gender  race  city  state  \
# armed
# Airsoft pistol       3     2                3    3       3     2     3      3
# BB gun              12    12               12   12      12    11    12     12
# BB gun and vehicle   1     1                1    1       1     1     1      1
# Taser               31    31               31   30      31    28    31     31
# air conditioner      1     1                1    1       1     1     1      1
#
#                     signs_of_mental_illness  threat_level  flee  body_camera  \
# armed
# Airsoft pistol                            3             3     3            3
# BB gun                                   12            12     8           12
# BB gun and vehicle                        1             1     1            1
# Taser                                    31            31    29           31
# air conditioner                           1             1     1            1
#
#                     longitude  latitude  is_geocoding_exact  YYMM  Counter  YY
# armed
# Airsoft pistol              3         3                   3     3        3   3
# BB gun                     12        12                  12    12       12  12
# BB gun and vehicle          1         1                   1     1        1   1
# Taser                      30        30                  31    31       31  31
# air conditioner             1         1                   1     1        1   1

# %% [markdown]
# Filtro la tipologia di arma per numero di uccisioni perchè in alcuni casi il numero è poco rilevante

# %%
dfRaceArmed3 = dfRaceArmed2.where(dfRaceArmed2["Counter"]> 100).dropna()

# %%
dfRaceArmed3.head()
# Out:
#                   id    name  manner_of_death     age  gender    race    city  \
# armed
# gun           3699.0  3559.0           3699.0  3525.0  3699.0  3266.0  3699.0
# knife          936.0   902.0            936.0   892.0   935.0   846.0   936.0
# toy weapon     219.0   215.0            219.0   212.0   219.0   201.0   219.0
# unarmed        413.0   413.0            413.0   410.0   413.0   407.0   413.0
# undetermined   174.0   150.0            174.0   153.0   174.0   128.0   174.0
#
#                state  signs_of_mental_illness  threat_level    flee  \
# armed
# gun           3699.0                   3699.0        3699.0  3449.0
# knife          936.0                    936.0         936.0   879.0
# toy weapon     219.0                    219.0         219.0   209.0
# unarmed        413.0                    413.0         413.0   397.0
# undetermined   174.0                    174.0         174.0   125.0
#
#               body_camera  longitude  latitude  is_geocoding_exact    YYMM  \
# armed
# gun                3699.0     3508.0    3508.0              3699.0  3699.0
# knife               936.0      893.0     893.0               936.0   936.0
# toy weapon          219.0      215.0     215.0               219.0   219.0
# unarmed             413.0      396.0     396.0               413.0   413.0
# undetermined        174.0      162.0     162.0               174.0   174.0
#
#               Counter      YY
# armed
# gun            3699.0  3699.0
# knife           936.0   936.0
# toy weapon      219.0   219.0
# unarmed         413.0   413.0
# undetermined    174.0   174.0

# %%
dfRaceArmed3.reset_index(inplace=True)
dfRaceArmed4 = dfRaceArmed3.loc[:,["armed" ,"Counter"]]

# %%
dftemp=dfRaceArmed4.loc[:,"Counter"]/dfRaceArmed4.iloc[:,-1].sum()

# %%
dfRaceArmed4.loc[:,"Weapon Kind Percentage"]=dftemp

# %%
dimensions = (10, 6)
fig, ax = plt.subplots(figsize=dimensions)
plt.xticks(rotation=90)
BarPlotArmed = sns.barplot(ax = ax, x='armed', y="Weapon Kind Percentage", data=dfRaceArmed4 )

# %% [markdown]
# Si deduce che il 65% circa dei casi di uccisione è avvenuto con i trasgessori in possesso di pistola, a seguire il 16% con coltello.

# %% [markdown]
# Verifico se c'è un qualche trend temporale nel tipo di arma in possesso durante lo scontro con la polizia. Lo applicherò solo alle due tipologie più usate

# %%
srWeaponGunTrend = df2.groupby('YYMM')['armed'].apply(lambda x: (x == "gun").sum())
srWeaponKnifeTrend = df2.groupby('YYMM')['armed'].apply(lambda x: (x == "knife").sum())

# %%
dimensions = (20, 3)
fig, ax = plt.subplots(figsize=dimensions)
plt.xticks(rotation=90)
fig.subplots_adjust(right=0.75)

twin1 = ax.twinx()

# Offset the right spine of twin2.  The ticks and label have already been
# placed on the right by twinx above.
twin1.spines.right.set_position(("axes", 1))

p1, = ax.plot(srWeaponGunTrend, "b-", label="Gun Trend")
p2, = twin1.plot(srWeaponKnifeTrend, "r-", label="Knife Trend")

ax.yaxis.label.set_color(p1.get_color())
twin1.yaxis.label.set_color(p2.get_color())
 
tkw = dict(size=4, width=1.5)
ax.tick_params(axis='y', colors=p1.get_color(), **tkw)
twin1.tick_params(axis='y', colors=p2.get_color(), **tkw)
ax.tick_params(axis='x', **tkw)

ax.legend(handles=[p1, p2])

plt.show()

# %% [markdown]
# Anche in questo caso non si evidenziano tendenze che permettano di estrapolare delle informazioni più specifiche, l'andamento è piuttosto "rumoroso".

# %% [markdown]
# 1.3 Body Camera usage time trend
# ---

# %%
dfTimeSeriesCameraUsed = df2.groupby('YYMM')['body_camera'].apply(lambda x: (x == False).sum())

# %%
dfTimeSeriesCameraUsed.plot(figsize=(15, 3), title='Body Camera usage Time Series')
# Out:
# <AxesSubplot:title={'center':'Body Camera usage Time Series'}, xlabel='YYMM'>

# %% [markdown]
# Anche l'utlizzo della body camera da parte della polizia non ha particolari trend esplicativi

# %% [markdown]
# 2.Gender Killing
# ===

# %% [markdown]
# Adesso vorrei capire se c'è una qualche distinzione tra il numero di uccisioni per sesso.

# %%
sns.catplot(x='gender', y="age", data=df2)

# %%
sns.violinplot(x='gender', y="age", data=df2)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='age'>

# %% [markdown]
# Possiamo dedurre che la percentuale di uomini uccisi è molto maggiore rispetto a quella delle donne.  L'età media per uomini
# e donne è nell'intorno dei 30 anni ed più o meno la stessa indipendentemente dal sesso.
#
# La distribuzione è right skewed perchè c'è una tendenza più lenta nel calo delle uccisioni tra i 30 e i 70 anni che tra i 20 e 30 anni ed è frequente anche in età avanzata.
#
# Si osserva anche la differenza nella quantità di dati di uccisioni di uomini rispetto alle donne che non è una sorpresa dato che il sesso maschile è per sua natura più aggressivo per effetto degli ormoni testosteronici.

# %% [markdown]
# 3.Age Killing
# ===

# %% [markdown]
# Innanzi tutto controllo se ci sono date duplicate perchè nel caso ce ne siano non posso utilizzare la data come indice per le elaborazioni ma devo creare un nuovo indice numerico con il metodo reset_index()

# %%
df2[df2.index.duplicated()]
# Out:
#               id                name manner_of_death         armed   age  \
# date
# 2015-01-02     4    Lewis Lee Lembke            shot           gun  47.0
# 2015-01-04     9   Michael Rodriguez            shot      nail gun  39.0
# 2015-01-04    11   Kenneth Joe Brown            shot           gun  18.0
# 2015-01-06    16       Autumn Steele            shot       unarmed  34.0
# 2015-01-06    17     Leslie Sapp III            shot    toy weapon  47.0
# ...          ...                 ...             ...           ...   ...
# 2021-06-28  6969        Robert Alire            shot         knife   NaN
# 2021-06-28  6970                 NaN            shot         knife   NaN
# 2021-06-28  6977                 NaN            shot           gun   NaN
# 2021-06-29  6975          Larry Hunt            shot  undetermined  58.0
# 2021-06-30  6976  Joseph Lee Humbles            shot           gun  29.0
#
#            gender race             city state  signs_of_mental_illness  \
# date
# 2015-01-02      M    W            Aloha    OR                    False
# 2015-01-04      M    H            Evans    CO                    False
# 2015-01-04      M    W          Guthrie    OK                    False
# 2015-01-06      F    W       Burlington    IA                    False
# 2015-01-06      M    B        Knoxville    PA                    False
# ...           ...  ...              ...   ...                      ...
# 2021-06-28      M  NaN    Commerce City    CO                     True
# 2021-06-28      M  NaN            Azusa    CA                    False
# 2021-06-28      M  NaN  Siskiyou County    CA                    False
# 2021-06-29      M  NaN           Bayard    NE                    False
# 2021-06-30      M  NaN          Atlanta    GA                    False
#
#             threat_level         flee  body_camera  longitude  latitude  \
# date
# 2015-01-02        attack  Not fleeing        False   -122.892    45.487
# 2015-01-04        attack  Not fleeing        False   -104.692    40.384
# 2015-01-04        attack  Not fleeing        False    -97.423    35.877
# 2015-01-06         other  Not fleeing         True    -91.119    40.809
# 2015-01-06        attack  Not fleeing        False    -79.991    40.413
# ...                  ...          ...          ...        ...       ...
# 2021-06-28        attack  Not fleeing        False   -104.931    39.822
# 2021-06-28         other  Not fleeing        False   -117.918    34.141
# 2021-06-28        attack          Car        False   -122.192    41.635
# 2021-06-29  undetermined          NaN        False   -103.322    41.752
# 2021-06-30        attack  Not fleeing        False    -84.385    33.774
#
#             is_geocoding_exact     YYMM  Counter    YY
# date
# 2015-01-02                True  2015-01      1.0  2015
# 2015-01-04                True  2015-01      1.0  2015
# 2015-01-04                True  2015-01      1.0  2015
# 2015-01-06                True  2015-01      1.0  2015
# 2015-01-06                True  2015-01      1.0  2015
# ...                        ...      ...      ...   ...
# 2021-06-28                True  2021-06      1.0  2021
# 2021-06-28                True  2021-06      1.0  2021
# 2021-06-28                True  2021-06      1.0  2021
# 2021-06-29                True  2021-06      1.0  2021
# 2021-06-30                True  2021-06      1.0  2021
#
# [4220 rows x 19 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6419 entries, 2015-01-02 to 2021-06-30
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       6419 non-null   int64
#  1   name                     6178 non-null   object
#  2   manner_of_death          6419 non-null   object
#  3   armed                    6211 non-null   object
#  4   age                      6127 non-null   float64
#  5   gender                   6418 non-null   object
#  6   race                     5726 non-null   object
#  7   city                     6419 non-null   object
#  8   state                    6419 non-null   object
#  9   signs_of_mental_illness  6419 non-null   bool
#  10  threat_level             6419 non-null   object
#  11  flee                     5985 non-null   object
#  12  body_camera              6419 non-null   bool
#  13  longitude                6108 non-null   float64
#  14  latitude                 6108 non-null   float64
#  15  is_geocoding_exact       6419 non-null   bool
#  16  YYMM                     6419 non-null   object
#  17  Counter                  6419 non-null   float64
#  18  YY                       6419 non-null   object
# dtypes: bool(3), float64(4), int64(1), object(11)
# memory usage: 1.1+ MB

# %%
df21=df2.reset_index()
sns.histplot(data=df21, x="age")
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %% [markdown]
# La distribuzione dei dati è centrata intorno ai 30 anni, è right skewed ed anche in questo caso è molto simile a quelle viste sopra distinte per sesso. Qui notiamo un fenomeno molto interessante. Sembra che la distribuzione, fra i 30 e i 40 anni abbia un buco o un incongruenza di dati in quanto non allineata con il profilo a campana della gaussiana.

# %% [markdown]
# 4.Mental Illness  Inference
# ===

# %%
sns.histplot(data=df21, x="manner_of_death" , hue="signs_of_mental_illness")
# Out:
# <AxesSubplot:xlabel='manner_of_death', ylabel='Count'>

# %%
sr_withIll = df21.groupby('manner_of_death')['signs_of_mental_illness'].apply(lambda x: (x == True).sum())
sr_withoutIll = df21.groupby('manner_of_death')['signs_of_mental_illness'].apply(lambda x: (x == False).sum())

# %%
type(sr_withIll)
# Out:
# pandas.core.series.Series

# %%
sr_withIll["shot"]/sr_withoutIll["shot"]
# Out:
# 0.28773784355179705

# %%
sr_withIll["shot and Tasered"]/sr_withoutIll["shot and Tasered"]
# Out:
# 0.5045871559633027

# %% [markdown]
# Si deduce quindi che le persone con cui è stato usato anche il teaser oltre alla pistola era più probabile (50% contro il 29%) che fossero soggetti a segni di malattie mentali

# %% [markdown]
# 5.Race and body camera relation
# ===

# %%
sns.histplot(data=df21, x="manner_of_death" , hue="body_camera")
# Out:
# <AxesSubplot:xlabel='manner_of_death', ylabel='Count'>

# %% [markdown]
# Dal grafico sopra invece si evidenzia come solo nel 20% circa dei casi la camera della polizia è attiva. Le ragioni per cui questo è accaduto potrebbero essere sostanzialmente queste:
#     a) la camera era volutamente spenta
#     b) la camera non era funzionante
#     c) l'agente di polizia aveva dimenticato la camera
#     d) non c'erano camere disponibili per filmare l'intervento
# In ogni caso tutti questi comportamenti si traducono in un qualche tipo di negligenza da parte dell'organo di polizia.

# %%
df4 = df21.copy()

# %%
df4.astype({'race': 'string'}).dtypes
# Out:
# date                       datetime64[ns]
# id                                  int64
# name                               object
# manner_of_death                    object
# armed                              object
# age                               float64
# gender                             object
# race                               string
# city                               object
# state                              object
# signs_of_mental_illness              bool
# threat_level                       object
# flee                               object
# body_camera                          bool
# longitude                         float64
# latitude                          float64
# is_geocoding_exact                   bool
# YYMM                               object
# Counter                           float64
# YY                                 object
# dtype: object

# %%
dimensions = (14, 8)

fig, ax = plt.subplots(figsize=dimensions)
sns.histplot(ax = ax , data=df4.dropna(), x='race', hue="body_camera" )
# Out:
# <AxesSubplot:xlabel='race', ylabel='Count'>

# %% [markdown]
# Da questo grafico si evidenziano due fenomemi:
# <ul>
#     conferma del fatto che sia molto più frequente il mancato utilizzo della camera
# - pur essendo il numero di uccisioni dei bianchi circa doppio rispetto a quello dei neri,la frequenza di utilizzo della       camera da parte dei poliziotti è la stessa.
#
# Ora suddivido i dati in 3 rami: razza bianca , razza non bianca e razza indefinita e rieffettuo la verifica della camera.

# %%
srRace = df4['race'].copy()

# %%
global i
i = 0
    
def WrapRace(character):  
    global i
    i += 1
    
    if pd.isna(character):
        item = "UnknownRace"
    else:
        if character !='W':
            item = "NotWhite"
        elif character =='W':
            item = "White"
                     
    return item#, print(i)

df4['WhiteAndNot'] = list(map(WrapRace,srRace))

# %%
dimensions = (8, 8)

fig, ax = plt.subplots(figsize=dimensions)
sns.histplot(ax = ax, data=df4, x='WhiteAndNot', hue="body_camera" )
# Out:
# <AxesSubplot:xlabel='WhiteAndNot', ylabel='Count'>

# %% [markdown]
# Ora eseguo il conteggio di tutti i decessi ripresi e non ripresi dalla camera suddivisi per razza bianca , non bianca e razza non identificata.

# %%
KillWithCamera = df4.groupby('WhiteAndNot')["body_camera"].apply(lambda x: (x == True).sum())
KillWithCamera
# Out:
# WhiteAndNot
# NotWhite       481
# UnknownRace     75
# White          308
# Name: body_camera, dtype: int64

# %%
KillNotWithCamera = df4.groupby('WhiteAndNot')["body_camera"].apply(lambda x: (x == False).sum())
KillNotWithCamera
# Out:
# WhiteAndNot
# NotWhite       2342
# UnknownRace     618
# White          2595
# Name: body_camera, dtype: int64

# %% [markdown]
# Dal conteggio emerge che il numero di decessi con razza non identificata è elevato, circa 1 su 8

# %%
Ratio = KillNotWithCamera/(KillWithCamera + KillNotWithCamera)   
Ratio
# Out:
# WhiteAndNot
# NotWhite       0.829614
# UnknownRace    0.891775
# White          0.893903
# Name: body_camera, dtype: float64

# %% [markdown]
# Dal ratio si deduce che la percentuale di agenti senza camera è del 6% maggiore con persone di razza non bianca (1) a parità di casi. La percentuale appena riportata potrebbe essere maggiore se si pensa al fatto che ci sono dei casi in cui la razza non è stata riportata.
#
# Entrando ora un po' più nel dettaglio m'interessa vedere l'utilizzo della camera nei vari stati.

# %%
dimensions = (14, 8)

fig, ax = plt.subplots(figsize=dimensions)
plt.xticks(rotation=90)
sns.histplot(ax=ax ,data=df4, x='state', hue="body_camera" )
# Out:
# <AxesSubplot:xlabel='state', ylabel='Count'>

# %% [markdown]
# Si notano dei particolari interessanti:
# <ul>
#     <li> ci sono 3 stati in cui la quantità di persone uccise è decisamente più alta e sono California , Texas e Florida. Qui la concentrazione di popolazione è anche molto maggiore rispetto agli altri stati. </li>
#     <li>è comune a molti stati USA il mancato utilizzo della camera da parte dei poliziotti. La credibilità delle forze dell'ordine viene meno se non c'è un forte senso di responsabilità e se non si cerca di essere impeccabili nel rispetto della giustizia. </li>
#     <li> ci sono al contrario alcuni stati in cui il livello di uccisioni è molto basso (sotto i 90) :Kansas, Iowa, Montana, Utah , Nevada , Minnesota, New Jersey , Massachusetts , New Hampshire , Idaho, Maryland , Nebraska , Maine , Delaware , West Virginia ,  Hawaii , Wyoming , Nord Dakota , South Dakota , Connecticut , Vermont , Rhode Island</li>
#     <li> tra gli stati con basso livello di uccisioni ce ne sono alcuni in cui la percentuale d'uso della camera è molto alta rispetto alla media degli altri stati anche se potrebbe dipendere molto dalla modalità con cui sono stati raccolti i dati:Nevada, Minnesota, Utah</li>
# </ul>

# %%
dfBodyCam = df4.groupby('state')["body_camera"].apply(lambda x: (x == True).sum())
dfNoBodyCam = df4.groupby('state')["body_camera"].apply(lambda x: (x == False).sum())

# %%
LowKillsStates=[(dfBodyCam.loc['MN']/dfNoBodyCam.loc['MN']),(dfBodyCam.loc['NV']/dfNoBodyCam.loc['NV']),(dfBodyCam.loc['UT']/dfNoBodyCam.loc['UT'])]
LowKillsStates
# Out:
# [0.5625, 0.5285714285714286, 0.4444444444444444]

# %%
HighKillsStates=[(dfBodyCam.loc['CA']/dfNoBodyCam.loc['CA']),(dfBodyCam.loc['TX']/dfNoBodyCam.loc['TX']),(dfBodyCam.loc['FL']/dfNoBodyCam.loc['FL'])]
HighKillsStates
# Out:
# [0.2153846153846154, 0.12648221343873517, 0.08505154639175258]

# %% [markdown]
# Andando a valutare in numeri la differenza tra i principali stati ad elevata uccisione e a bassa uccisione si nota una differenza percentuale più che doppia di mancato utilizzo della body camera.

# %%
StateKillWithCamera = df4.groupby('state')["body_camera"].apply(lambda x: (x == True).sum())

# %%
StateKillWithoutCamera = df4.groupby('state')["body_camera"].apply(lambda x: (x == False).sum())

# %%
StateKillRatio = StateKillWithoutCamera/(StateKillWithoutCamera+StateKillWithCamera)

fig = plt.figure()

ax = fig.add_axes([0,0,2,2])
ax.bar(StateKillRatio.index,StateKillRatio)
plt.xticks(rotation=90)
plt.show()

# %%
type(StateKillRatio)
# Out:
# pandas.core.series.Series

# %% [markdown]
# 6.Cleaning median household income data
# ===

# %% [markdown]
# Utilizzo la libreria "chardet" per riuscire a gestire eventuali caratteri Unicode all'interno del CSV dato che normalmente python utilizza la codifica UTF8.

# %%
import chardet

with open(r'MedianHouseholdIncome2015.csv', 'rb') as f:
    result = chardet.detect(f.read()) 
    print(result)
 
dfMedianHouseholdIncome2015 = pd.read_csv('MedianHouseholdIncome2015.csv',encoding=result['encoding'])
dfMedianHouseholdIncome2015["Geographic Area"]=dfMedianHouseholdIncome2015["Geographic Area"].str.strip()
dfMedianHouseholdIncome2015["City"]=dfMedianHouseholdIncome2015["City"].str.strip()
dfMedianHouseholdIncome2015.info()
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29322 entries, 0 to 29321
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  29322 non-null  object
#  1   City             29322 non-null  object
#  2   Median Income    29271 non-null  object
# dtypes: object(3)
# memory usage: 687.4+ KB

# %% [markdown]
# Applicare il metodo strip() è molto importante perchè elimina le tabulazioni e gli spazi bianchi contenuti nei csv evitando che nel merge stringhe con lo stesso contenuto siano riconosciute come diverse.

# %%
result
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
df2_MedianHouseholdIncome2015 = dfMedianHouseholdIncome2015.copy()

# %% [markdown]
# Come convenzione imposto tutte le città con caratteri in minuscolo in modo che nel merge non abbia problemi di matching del case tra i diversi dataframe.
#
# Elimino anche il cdp che dovrebbe essere sia una tag che sta per "census designated place" per lo stesso motivo riportato sopra.

# %%
df2_MedianHouseholdIncome2015["City"] = df2_MedianHouseholdIncome2015["City"].str.lower()

# %%
 
df2_MedianHouseholdIncome2015["City"] = df2_MedianHouseholdIncome2015["City"].str.replace("cdp","")

# %%
 
df2_MedianHouseholdIncome2015.head(10)
# Out:
#   Geographic Area                 City Median Income
# 0              AL              abanda          11207
# 1              AL       abbeville city         25615
# 2              AL      adamsville city         42575
# 3              AL         addison town         37083
# 4              AL           akron town         21667
# 5              AL       alabaster city         71816
# 6              AL     albertville city         32911
# 7              AL  alexander city city         29874
# 8              AL          alexandria          56058
# 9              AL      aliceville city         21131

# %%
dfMedianHouseholdIncome2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29322 entries, 0 to 29321
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  29322 non-null  object
#  1   City             29322 non-null  object
#  2   Median Income    29271 non-null  object
# dtypes: object(3)
# memory usage: 687.4+ KB

# %% [markdown]
# Nel successivo blocco, dopo aver identificato la tipologia di dato per colonna le operazioni che devo eseguire sono le seguenti:
# <ul>
#   <li>Iterare nella colonna income per verificare la consistenza dei dati.Il fatto di avere dei dati row non mi permette di convertirli immediatamente in float o int perchè l'interprete mi restituirebbe un errore nel caso non tutti fossero del tipo corretto</li>
#   <li>Splittare la stringa per poter applicare il metodo isnumeric che controlla se il contenuto della stringa è un numero intero</li>
#   <li>Eliminare le righe con valori percentuali non numerici.</li>
#   <li>Trasformare il tipo di dato da python object a float</li>
# </ul>

# %%
df3_MedianHouseholdIncome2015 = df2_MedianHouseholdIncome2015.dropna()
df4_MedianHouseholdIncome2015 = df3_MedianHouseholdIncome2015.copy()
df4_MedianHouseholdIncome2015.info()

for j,item in enumerate(df4_MedianHouseholdIncome2015['Median Income']):
    if not item.isnumeric():
        df4_MedianHouseholdIncome2015.drop(index=j, inplace = True) 
        print(str(j)+' :Not a number.'+ ' Value: '+item)
 
df4_MedianHouseholdIncome2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29271 entries, 0 to 29320
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  29271 non-null  object
#  1   City             29271 non-null  object
#  2   Median Income    29271 non-null  object
# dtypes: object(3)
# memory usage: 914.7+ KB
# 44 :Not a number. Value: (X)
# 56 :Not a number. Value: (X)
# 57 :Not a number. Value: (X)
# 65 :Not a number. Value: (X)
# 71 :Not a number. Value: -
# 74 :Not a number. Value: -
# 78 :Not a number. Value: (X)
# 80 :Not a number. Value: (X)
# 84 :Not a number. Value: -
# 95 :Not a number. Value: (X)
# 124 :Not a number. Value: (X)
# 131 :Not a number. Value: (X)
# 134 :Not a number. Value: (X)
# 135 :Not a number. Value: (X)
# 176 :Not a number. Value: (X)
# 243 :Not a number. Value: (X)
# 256 :Not a number. Value: (X)
# 260 :Not a number. Value: (X)
# 301 :Not a number. Value: (X)
# 323 :Not a number. Value: (X)
# 326 :Not a number. Value: (X)
# 330 :Not a number. Value: (X)
# 338 :Not a number. Value: -
# 339 :Not a number. Value: (X)
# 364 :Not a number. Value: (X)
# 367 :Not a number. Value: (X)
# 372 :Not a number. Value: (X)
# 375 :Not a number. Value: (X)
# 392 :Not a number. Value: (X)
# 407 :Not a number. Value: (X)
# 411 :Not a number. Value: (X)
# 438 :Not a number. Value: (X)
# 461 :Not a number. Value: (X)
# 462 :Not a number. Value: -
# 499 :Not a number. Value: (X)
# 501 :Not a number. Value: -
# 526 :Not a number. Value: -
# 556 :Not a number. Value: (X)
# 573 :Not a number. Value: -
# 591 :Not a number. Value: -
# 592 :Not a number. Value: -
# 594 :Not a number. Value: -
# 608 :Not a number. Value: -
# 613 :Not a number. Value: (X)
# 618 :Not a number. Value: -
# 624 :Not a number. Value: (X)
# 626 :Not a number. Value: -
# 629 :Not a number. Value: (X)
# 632 :Not a number. Value: -
# 636 :Not a number. Value: -
# 637 :Not a number. Value: -
# 638 :Not a number. Value: (X)
# 639 :Not a number. Value: (X)
# 642 :Not a number. Value: (X)
# 647 :Not a number. Value: -
# 662 :Not a number. Value: -
# 664 :Not a number. Value: (X)
# 666 :Not a number. Value: (X)
# 667 :Not a number. Value: -
# 676 :Not a number. Value: -
# 678 :Not a number. Value: -
# 683 :Not a number. Value: -
# 685 :Not a number. Value: -
# 686 :Not a number. Value: (X)
# 688 :Not a number. Value: -
# 696 :Not a number. Value: -
# 699 :Not a number. Value: (X)
# 704 :Not a number. Value: (X)
# 707 :Not a number. Value: -
# 711 :Not a number. Value: -
# 712 :Not a number. Value: -
# 718 :Not a number. Value: -
# 723 :Not a number. Value: -
# 726 :Not a number. Value: -
# 738 :Not a number. Value: (X)
# 762 :Not a number. Value: -
# 768 :Not a number. Value: (X)
# 769 :Not a number. Value: -
# 770 :Not a number. Value: -
# 771 :Not a number. Value: -
# 773 :Not a number. Value: -
# 774 :Not a number. Value: -
# 782 :Not a number. Value: -
# 784 :Not a number. Value: -
# 792 :Not a number. Value: -
# 797 :Not a number. Value: (X)
# 824 :Not a number. Value: (X)
# 827 :Not a number. Value: -
# 832 :Not a number. Value: -
# 838 :Not a number. Value: -
# 842 :Not a number. Value: -
# 843 :Not a number. Value: -
# 844 :Not a number. Value: -
# 847 :Not a number. Value: -
# 851 :Not a number. Value: (X)
# 853 :Not a number. Value: -
# 855 :Not a number. Value: -
# 857 :Not a number. Value: -
# 875 :Not a number. Value: (X)
# 893 :Not a number. Value: -
# 894 :Not a number. Value: -
# 911 :Not a number. Value: -
# 912 :Not a number. Value: -
# 929 :Not a number. Value: -
# 931 :Not a number. Value: -
# 932 :Not a number. Value: -
# 935 :Not a number. Value: -
# 936 :Not a number. Value: -
# 942 :Not a number. Value: -
# 944 :Not a number. Value: -
# 946 :Not a number. Value: (X)
# 947 :Not a number. Value: (X)
# 948 :Not a number. Value: (X)
# 950 :Not a number. Value: (X)
# 958 :Not a number. Value: (X)
# 963 :Not a number. Value: -
# 965 :Not a number. Value: -
# 967 :Not a number. Value: (X)
# 980 :Not a number. Value: -
# 987 :Not a number. Value: -
# 1001 :Not a number. Value: (X)
# 1004 :Not a number. Value: (X)
# 1005 :Not a number. Value: -
# 1019 :Not a number. Value: (X)
# 1022 :Not a number. Value: -
# 1023 :Not a number. Value: -
# 1026 :Not a number. Value: -
# 1033 :Not a number. Value: -
# 1036 :Not a number. Value: -
# 1039 :Not a number. Value: (X)
# 1069 :Not a number. Value: (X)
# 1078 :Not a number. Value: (X)
# 1081 :Not a number. Value: (X)
# 1083 :Not a number. Value: -
# 1096 :Not a number. Value: -
# 1099 :Not a number. Value: -
# 1103 :Not a number. Value: -
# 1104 :Not a number. Value: (X)
# 1105 :Not a number. Value: (X)
# 1113 :Not a number. Value: -
# 1116 :Not a number. Value: (X)
# 1123 :Not a number. Value: (X)
# 1126 :Not a number. Value: (X)
# 1131 :Not a number. Value: -
# 1132 :Not a number. Value: (X)
# 1134 :Not a number. Value: -
# 1145 :Not a number. Value: -
# 1148 :Not a number. Value: (X)
# 1150 :Not a number. Value: -
# 1151 :Not a number. Value: -
# 1162 :Not a number. Value: -
# 1170 :Not a number. Value: -
# 1173 :Not a number. Value: (X)
# 1177 :Not a number. Value: (X)
# 1184 :Not a number. Value: -
# 1186 :Not a number. Value: -
# 1188 :Not a number. Value: (X)
# 1193 :Not a number. Value: (X)
# 1196 :Not a number. Value: (X)
# 1213 :Not a number. Value: (X)
# 1216 :Not a number. Value: -
# 1234 :Not a number. Value: -
# 1238 :Not a number. Value: -
# 1240 :Not a number. Value: -
# 1244 :Not a number. Value: (X)
# 1245 :Not a number. Value: (X)
# 1263 :Not a number. Value: -
# 1272 :Not a number. Value: (X)
# 1273 :Not a number. Value: (X)
# 1296 :Not a number. Value: -
# 1303 :Not a number. Value: -
# 1304 :Not a number. Value: -
# 1311 :Not a number. Value: -
# 1323 :Not a number. Value: -
# 1327 :Not a number. Value: -
# 1329 :Not a number. Value: -
# 1339 :Not a number. Value: (X)
# 1342 :Not a number. Value: -
# 1344 :Not a number. Value: (X)
# 1347 :Not a number. Value: 2,500-
# 1349 :Not a number. Value: -
# 1353 :Not a number. Value: (X)
# 1368 :Not a number. Value: (X)
# 1370 :Not a number. Value: -
# 1376 :Not a number. Value: -
# 1383 :Not a number. Value: (X)
# 1384 :Not a number. Value: -
# 1391 :Not a number. Value: (X)
# 1409 :Not a number. Value: (X)
# 1435 :Not a number. Value: (X)
# 1442 :Not a number. Value: (X)
# 1443 :Not a number. Value: (X)
# 1482 :Not a number. Value: -
# 1502 :Not a number. Value: (X)
# 1512 :Not a number. Value: (X)
# 1576 :Not a number. Value: (X)
# 1600 :Not a number. Value: (X)
# 1617 :Not a number. Value: (X)
# 1649 :Not a number. Value: (X)
# 1711 :Not a number. Value: (X)
# 1720 :Not a number. Value: -
# 1724 :Not a number. Value: (X)
# 1750 :Not a number. Value: (X)
# 1766 :Not a number. Value: (X)
# 1811 :Not a number. Value: -
# 1828 :Not a number. Value: (X)
# 1836 :Not a number. Value: -
# 1874 :Not a number. Value: (X)
# 1890 :Not a number. Value: (X)
# 1894 :Not a number. Value: (X)
# 1915 :Not a number. Value: (X)
# 1924 :Not a number. Value: (X)
# 1936 :Not a number. Value: (X)
# 1945 :Not a number. Value: (X)
# 1950 :Not a number. Value: -
# 1953 :Not a number. Value: -
# 1990 :Not a number. Value: -
# 1992 :Not a number. Value: 250,000+
# 2017 :Not a number. Value: (X)
# 2018 :Not a number. Value: (X)
# 2019 :Not a number. Value: (X)
# 2022 :Not a number. Value: (X)
# 2023 :Not a number. Value: -
# 2035 :Not a number. Value: (X)
# 2045 :Not a number. Value: (X)
# 2056 :Not a number. Value: (X)
# 2062 :Not a number. Value: (X)
# 2078 :Not a number. Value: (X)
# 2079 :Not a number. Value: (X)
# 2093 :Not a number. Value: -
# 2094 :Not a number. Value: -
# 2104 :Not a number. Value: -
# 2105 :Not a number. Value: (X)
# 2113 :Not a number. Value: (X)
# 2114 :Not a number. Value: (X)
# 2120 :Not a number. Value: (X)
# 2131 :Not a number. Value: (X)
# 2138 :Not a number. Value: -
# 2141 :Not a number. Value: -
# 2145 :Not a number. Value: -
# 2149 :Not a number. Value: -
# 2157 :Not a number. Value: (X)
# 2167 :Not a number. Value: -
# 2169 :Not a number. Value: (X)
# 2176 :Not a number. Value: (X)
# 2182 :Not a number. Value: -
# 2184 :Not a number. Value: (X)
# 2201 :Not a number. Value: (X)
# 2202 :Not a number. Value: -
# 2205 :Not a number. Value: (X)
# 2208 :Not a number. Value: (X)
# 2224 :Not a number. Value: (X)
# 2241 :Not a number. Value: (X)
# 2243 :Not a number. Value: (X)
# 2248 :Not a number. Value: (X)
# 2252 :Not a number. Value: -
# 2253 :Not a number. Value: (X)
# 2268 :Not a number. Value: -
# 2269 :Not a number. Value: -
# 2278 :Not a number. Value: (X)
# 2302 :Not a number. Value: (X)
# 2305 :Not a number. Value: (X)
# 2311 :Not a number. Value: (X)
# 2322 :Not a number. Value: (X)
# 2343 :Not a number. Value: (X)
# 2363 :Not a number. Value: -
# 2391 :Not a number. Value: (X)
# 2398 :Not a number. Value: (X)
# 2404 :Not a number. Value: (X)
# 2409 :Not a number. Value: (X)
# 2429 :Not a number. Value: (X)
# 2440 :Not a number. Value: (X)
# 2448 :Not a number. Value: (X)
# 2460 :Not a number. Value: -
# 2465 :Not a number. Value: -
# 2472 :Not a number. Value: -
# 2490 :Not a number. Value: (X)
# 2494 :Not a number. Value: (X)
# 2503 :Not a number. Value: (X)
# 2504 :Not a number. Value: -
# 2536 :Not a number. Value: -
# 2537 :Not a number. Value: (X)
# 2542 :Not a number. Value: -
# 2548 :Not a number. Value: (X)
# 2550 :Not a number. Value: -
# 2578 :Not a number. Value: -
# 2580 :Not a number. Value: -
# 2587 :Not a number. Value: (X)
# 2592 :Not a number. Value: -
# 2604 :Not a number. Value: -
# 2605 :Not a number. Value: (X)
# 2611 :Not a number. Value: 250,000+
# 2625 :Not a number. Value: (X)
# 2628 :Not a number. Value: 2,500-
# 2629 :Not a number. Value: -
# 2634 :Not a number. Value: (X)
# 2653 :Not a number. Value: (X)
# 2656 :Not a number. Value: -
# 2673 :Not a number. Value: (X)
# 2674 :Not a number. Value: -
# 2675 :Not a number. Value: (X)
# 2687 :Not a number. Value: -
# 2696 :Not a number. Value: -
# 2697 :Not a number. Value: (X)
# 2710 :Not a number. Value: (X)
# 2717 :Not a number. Value: -
# 2719 :Not a number. Value: (X)
# 2742 :Not a number. Value: -
# 2745 :Not a number. Value: -
# 2749 :Not a number. Value: (X)
# 2773 :Not a number. Value: (X)
# 2800 :Not a number. Value: (X)
# 2801 :Not a number. Value: (X)
# 2809 :Not a number. Value: (X)
# 2817 :Not a number. Value: (X)
# 2821 :Not a number. Value: (X)
# 2824 :Not a number. Value: (X)
# 2833 :Not a number. Value: -
# 2848 :Not a number. Value: -
# 2858 :Not a number. Value: -
# 2864 :Not a number. Value: -
# 2873 :Not a number. Value: (X)
# 2884 :Not a number. Value: (X)
# 2885 :Not a number. Value: 250,000+
# 2899 :Not a number. Value: (X)
# 2902 :Not a number. Value: (X)
# 2910 :Not a number. Value: -
# 2918 :Not a number. Value: (X)
# 2965 :Not a number. Value: -
# 2967 :Not a number. Value: -
# 2972 :Not a number. Value: (X)
# 2977 :Not a number. Value: (X)
# 2981 :Not a number. Value: -
# 2982 :Not a number. Value: (X)
# 3011 :Not a number. Value: -
# 3018 :Not a number. Value: -
# 3019 :Not a number. Value: -
# 3023 :Not a number. Value: -
# 3025 :Not a number. Value: (X)
# 3029 :Not a number. Value: (X)
# 3032 :Not a number. Value: (X)
# 3076 :Not a number. Value: -
# 3079 :Not a number. Value: (X)
# 3085 :Not a number. Value: (X)
# 3096 :Not a number. Value: (X)
# 3107 :Not a number. Value: -
# 3109 :Not a number. Value: (X)
# 3148 :Not a number. Value: (X)
# 3169 :Not a number. Value: -
# 3181 :Not a number. Value: -
# 3182 :Not a number. Value: (X)
# 3190 :Not a number. Value: (X)
# 3194 :Not a number. Value: -
# 3202 :Not a number. Value: -
# 3213 :Not a number. Value: -
# 3235 :Not a number. Value: -
# 3246 :Not a number. Value: (X)
# 3248 :Not a number. Value: (X)
# 3251 :Not a number. Value: -
# 3255 :Not a number. Value: -
# 3256 :Not a number. Value: -
# 3257 :Not a number. Value: -
# 3258 :Not a number. Value: -
# 3282 :Not a number. Value: (X)
# 3300 :Not a number. Value: (X)
# 3304 :Not a number. Value: -
# 3305 :Not a number. Value: (X)
# 3306 :Not a number. Value: (X)
# 3319 :Not a number. Value: -
# 3320 :Not a number. Value: (X)
# 3328 :Not a number. Value: -
# 3330 :Not a number. Value: -
# 3337 :Not a number. Value: -
# 3351 :Not a number. Value: -
# 3355 :Not a number. Value: (X)
# 3357 :Not a number. Value: (X)
# 3368 :Not a number. Value: -
# 3377 :Not a number. Value: -
# 3379 :Not a number. Value: -
# 3413 :Not a number. Value: (X)
# 3414 :Not a number. Value: (X)
# 3424 :Not a number. Value: -
# 3429 :Not a number. Value: (X)
# 3439 :Not a number. Value: 250,000+
# 3443 :Not a number. Value: -
# 3463 :Not a number. Value: (X)
# 3465 :Not a number. Value: (X)
# 3493 :Not a number. Value: -
# 3494 :Not a number. Value: -
# 3499 :Not a number. Value: -
# 3502 :Not a number. Value: -
# 3511 :Not a number. Value: (X)
# 3519 :Not a number. Value: -
# 3520 :Not a number. Value: (X)
# 3539 :Not a number. Value: -
# 3546 :Not a number. Value: (X)
# 3549 :Not a number. Value: -
# 3568 :Not a number. Value: -
# 3583 :Not a number. Value: (X)
# 3618 :Not a number. Value: -
# 3620 :Not a number. Value: -
# 3627 :Not a number. Value: -
# 3632 :Not a number. Value: (X)
# 3641 :Not a number. Value: (X)
# 3646 :Not a number. Value: (X)
# 3651 :Not a number. Value: -
# 3652 :Not a number. Value: -
# 3666 :Not a number. Value: (X)
# 3676 :Not a number. Value: (X)
# 3690 :Not a number. Value: (X)
# 3695 :Not a number. Value: (X)
# 3707 :Not a number. Value: -
# 3720 :Not a number. Value: -
# 3722 :Not a number. Value: -
# 3729 :Not a number. Value: (X)
# 3737 :Not a number. Value: (X)
# 3744 :Not a number. Value: (X)
# 3748 :Not a number. Value: (X)
# 3753 :Not a number. Value: (X)
# 3754 :Not a number. Value: -
# 3765 :Not a number. Value: (X)
# 3781 :Not a number. Value: -
# 3788 :Not a number. Value: (X)
# 3803 :Not a number. Value: (X)
# 3805 :Not a number. Value: -
# 3806 :Not a number. Value: (X)
# 3810 :Not a number. Value: -
# 3813 :Not a number. Value: -
# 3823 :Not a number. Value: (X)
# 3826 :Not a number. Value: (X)
# 3831 :Not a number. Value: (X)
# 3832 :Not a number. Value: (X)
# 3872 :Not a number. Value: -
# 3879 :Not a number. Value: (X)
# 3881 :Not a number. Value: -
# 3884 :Not a number. Value: (X)
# 3905 :Not a number. Value: -
# 3925 :Not a number. Value: (X)
# 4014 :Not a number. Value: (X)
# 4130 :Not a number. Value: (X)
# 4169 :Not a number. Value: (X)
# 4172 :Not a number. Value: (X)
# 4255 :Not a number. Value: (X)
# 4269 :Not a number. Value: (X)
# 4358 :Not a number. Value: -
# 4359 :Not a number. Value: -
# 4371 :Not a number. Value: (X)
# 4372 :Not a number. Value: (X)
# 4403 :Not a number. Value: (X)
# 4412 :Not a number. Value: (X)
# 4484 :Not a number. Value: 250,000+
# 4500 :Not a number. Value: (X)
# 4517 :Not a number. Value: 250,000+
# 4546 :Not a number. Value: -
# 4554 :Not a number. Value: (X)
# 4567 :Not a number. Value: (X)
# 4578 :Not a number. Value: (X)
# 4589 :Not a number. Value: (X)
# 4591 :Not a number. Value: -
# 4620 :Not a number. Value: -
# 4661 :Not a number. Value: (X)
# 4664 :Not a number. Value: (X)
# 4681 :Not a number. Value: (X)
# 4712 :Not a number. Value: -
# 4717 :Not a number. Value: -
# 4774 :Not a number. Value: -
# 4784 :Not a number. Value: (X)
# 4878 :Not a number. Value: (X)
# 4911 :Not a number. Value: (X)
# 4943 :Not a number. Value: (X)
# 4973 :Not a number. Value: (X)
# 4985 :Not a number. Value: (X)
# 4990 :Not a number. Value: -
# 5107 :Not a number. Value: (X)
# 5116 :Not a number. Value: (X)
# 5142 :Not a number. Value: (X)
# 5151 :Not a number. Value: -
# 5174 :Not a number. Value: -
# 5216 :Not a number. Value: 250,000+
# 5233 :Not a number. Value: -
# 5332 :Not a number. Value: -
# 5360 :Not a number. Value: -
# 5414 :Not a number. Value: (X)
# 5424 :Not a number. Value: (X)
# 5486 :Not a number. Value: -
# 5523 :Not a number. Value: (X)
# 5527 :Not a number. Value: (X)
# 5531 :Not a number. Value: (X)
# 5601 :Not a number. Value: (X)
# 5602 :Not a number. Value: -
# 5673 :Not a number. Value: (X)
# 5724 :Not a number. Value: -
# 5732 :Not a number. Value: (X)
# 5765 :Not a number. Value: -
# 5829 :Not a number. Value: (X)
# 5840 :Not a number. Value: -
# 5862 :Not a number. Value: -
# 5877 :Not a number. Value: (X)
# 5881 :Not a number. Value: -
# 5886 :Not a number. Value: (X)
# 5946 :Not a number. Value: -
# 5947 :Not a number. Value: -
# 5959 :Not a number. Value: (X)
# 6023 :Not a number. Value: (X)
# 6029 :Not a number. Value: (X)
# 6045 :Not a number. Value: -
# 6054 :Not a number. Value: -
# 6056 :Not a number. Value: (X)
# 6085 :Not a number. Value: -
# 6141 :Not a number. Value: (X)
# 6241 :Not a number. Value: (X)
# 6277 :Not a number. Value: (X)
# 6358 :Not a number. Value: -
# 6474 :Not a number. Value: -
# 6504 :Not a number. Value: (X)
# 6521 :Not a number. Value: (X)
# 6536 :Not a number. Value: (X)
# 6682 :Not a number. Value: (X)
# 6730 :Not a number. Value: (X)
# 6901 :Not a number. Value: (X)
# 7002 :Not a number. Value: -
# 7037 :Not a number. Value: (X)
# 7087 :Not a number. Value: -
# 7307 :Not a number. Value: -
# 7426 :Not a number. Value: (X)
# 7442 :Not a number. Value: (X)
# 7464 :Not a number. Value: (X)
# 7472 :Not a number. Value: (X)
# 7481 :Not a number. Value: (X)
# 7488 :Not a number. Value: (X)
# 7497 :Not a number. Value: (X)
# 7502 :Not a number. Value: (X)
# 7533 :Not a number. Value: (X)
# 7537 :Not a number. Value: -
# 7570 :Not a number. Value: -
# 7572 :Not a number. Value: (X)
# 7573 :Not a number. Value: -
# 7599 :Not a number. Value: (X)
# 7628 :Not a number. Value: (X)
# 7678 :Not a number. Value: (X)
# 7711 :Not a number. Value: (X)
# 7740 :Not a number. Value: (X)
# 7864 :Not a number. Value: 250,000+
# 7873 :Not a number. Value: (X)
# 7888 :Not a number. Value: (X)
# 7889 :Not a number. Value: (X)
# 7920 :Not a number. Value: -
# 7931 :Not a number. Value: (X)
# 7959 :Not a number. Value: (X)
# 7966 :Not a number. Value: (X)
# 7967 :Not a number. Value: (X)
# 7977 :Not a number. Value: (X)
# 7988 :Not a number. Value: (X)
# 8026 :Not a number. Value: -
# 8128 :Not a number. Value: -
# 8148 :Not a number. Value: -
# 8165 :Not a number. Value: -
# 8172 :Not a number. Value: (X)
# 8198 :Not a number. Value: -
# 8222 :Not a number. Value: (X)
# 8228 :Not a number. Value: (X)
# 8237 :Not a number. Value: (X)
# 8252 :Not a number. Value: (X)
# 8257 :Not a number. Value: (X)
# 8299 :Not a number. Value: (X)
# 8363 :Not a number. Value: (X)
# 8377 :Not a number. Value: -
# 8433 :Not a number. Value: -
# 8434 :Not a number. Value: (X)
# 8437 :Not a number. Value: (X)
# 8448 :Not a number. Value: (X)
# 8506 :Not a number. Value: -
# 8510 :Not a number. Value: (X)
# 8516 :Not a number. Value: (X)
# 8530 :Not a number. Value: -
# 8533 :Not a number. Value: (X)
# 8541 :Not a number. Value: -
# 8560 :Not a number. Value: -
# 8599 :Not a number. Value: (X)
# 8609 :Not a number. Value: -
# 8634 :Not a number. Value: -
# 8697 :Not a number. Value: -
# 8702 :Not a number. Value: -
# 8795 :Not a number. Value: -
# 8817 :Not a number. Value: (X)
# 8823 :Not a number. Value: -
# 8836 :Not a number. Value: (X)
# 8837 :Not a number. Value: -
# 8882 :Not a number. Value: -
# 8895 :Not a number. Value: -
# 8930 :Not a number. Value: -
# 8985 :Not a number. Value: (X)
# 9067 :Not a number. Value: (X)
# 9077 :Not a number. Value: (X)
# 9106 :Not a number. Value: (X)
# 9135 :Not a number. Value: -
# 9151 :Not a number. Value: (X)
# 9153 :Not a number. Value: (X)
# 9203 :Not a number. Value: -
# 9206 :Not a number. Value: (X)
# 9243 :Not a number. Value: (X)
# 9286 :Not a number. Value: 250,000+
# 9314 :Not a number. Value: -
# 9316 :Not a number. Value: -
# 9329 :Not a number. Value: (X)
# 9339 :Not a number. Value: (X)
# 9345 :Not a number. Value: -
# 9364 :Not a number. Value: -
# 9383 :Not a number. Value: (X)
# 9389 :Not a number. Value: (X)
# 9399 :Not a number. Value: (X)
# 9401 :Not a number. Value: (X)
# 9423 :Not a number. Value: -
# 9430 :Not a number. Value: -
# 9463 :Not a number. Value: (X)
# 9473 :Not a number. Value: (X)
# 9474 :Not a number. Value: (X)
# 9519 :Not a number. Value: (X)
# 9530 :Not a number. Value: (X)
# 9552 :Not a number. Value: (X)
# 9563 :Not a number. Value: 2,500-
# 9567 :Not a number. Value: (X)
# 9603 :Not a number. Value: (X)
# 9650 :Not a number. Value: -
# 9669 :Not a number. Value: (X)
# 9700 :Not a number. Value: (X)
# 9735 :Not a number. Value: (X)
# 9746 :Not a number. Value: (X)
# 9785 :Not a number. Value: (X)
# 9788 :Not a number. Value: (X)
# 9789 :Not a number. Value: (X)
# 9808 :Not a number. Value: (X)
# 9821 :Not a number. Value: (X)
# 9825 :Not a number. Value: -
# 9872 :Not a number. Value: (X)
# 9881 :Not a number. Value: (X)
# 9885 :Not a number. Value: (X)
# 9891 :Not a number. Value: (X)
# 9914 :Not a number. Value: (X)
# 9924 :Not a number. Value: -
# 9932 :Not a number. Value: (X)
# 9951 :Not a number. Value: (X)
# 9972 :Not a number. Value: (X)
# 9980 :Not a number. Value: (X)
# 9988 :Not a number. Value: -
# 10037 :Not a number. Value: (X)
# 10043 :Not a number. Value: (X)
# 10077 :Not a number. Value: (X)
# 10088 :Not a number. Value: (X)
# 10094 :Not a number. Value: (X)
# 10097 :Not a number. Value: (X)
# 10116 :Not a number. Value: -
# 10118 :Not a number. Value: 250,000+
# 10152 :Not a number. Value: -
# 10167 :Not a number. Value: (X)
# 10202 :Not a number. Value: (X)
# 10206 :Not a number. Value: -
# 10242 :Not a number. Value: -
# 10247 :Not a number. Value: (X)
# 10259 :Not a number. Value: (X)
# 10266 :Not a number. Value: (X)
# 10279 :Not a number. Value: (X)
# 10282 :Not a number. Value: (X)
# 10312 :Not a number. Value: (X)
# 10372 :Not a number. Value: (X)
# 10383 :Not a number. Value: (X)
# 10413 :Not a number. Value: (X)
# 10464 :Not a number. Value: (X)
# 10488 :Not a number. Value: -
# 10547 :Not a number. Value: (X)
# 10570 :Not a number. Value: (X)
# 10577 :Not a number. Value: (X)
# 10611 :Not a number. Value: (X)
# 10616 :Not a number. Value: (X)
# 10624 :Not a number. Value: (X)
# 10643 :Not a number. Value: (X)
# 10698 :Not a number. Value: (X)
# 10710 :Not a number. Value: (X)
# 10742 :Not a number. Value: -
# 10748 :Not a number. Value: (X)
# 10773 :Not a number. Value: (X)
# 10774 :Not a number. Value: (X)
# 10844 :Not a number. Value: (X)
# 10931 :Not a number. Value: -
# 10944 :Not a number. Value: -
# 10950 :Not a number. Value: (X)
# 10953 :Not a number. Value: (X)
# 10965 :Not a number. Value: -
# 10966 :Not a number. Value: -
# 10987 :Not a number. Value: -
# 11007 :Not a number. Value: -
# 11021 :Not a number. Value: 250,000+
# 11023 :Not a number. Value: 250,000+
# 11026 :Not a number. Value: 250,000+
# 11033 :Not a number. Value: -
# 11055 :Not a number. Value: (X)
# 11056 :Not a number. Value: (X)
# 11067 :Not a number. Value: -
# 11074 :Not a number. Value: -
# 11080 :Not a number. Value: (X)
# 11094 :Not a number. Value: -
# 11097 :Not a number. Value: (X)
# 11101 :Not a number. Value: -
# 11108 :Not a number. Value: (X)
# 11117 :Not a number. Value: (X)
# 11119 :Not a number. Value: (X)
# 11133 :Not a number. Value: (X)
# 11137 :Not a number. Value: (X)
# 11149 :Not a number. Value: -
# 11174 :Not a number. Value: -
# 11178 :Not a number. Value: -
# 11183 :Not a number. Value: (X)
# 11218 :Not a number. Value: -
# 11227 :Not a number. Value: (X)
# 11229 :Not a number. Value: (X)
# 11235 :Not a number. Value: 250,000+
# 11243 :Not a number. Value: (X)
# 11244 :Not a number. Value: -
# 11255 :Not a number. Value: (X)
# 11266 :Not a number. Value: (X)
# 11267 :Not a number. Value: -
# 11284 :Not a number. Value: -
# 11288 :Not a number. Value: (X)
# 11317 :Not a number. Value: -
# 11326 :Not a number. Value: -
# 11334 :Not a number. Value: -
# 11337 :Not a number. Value: (X)
# 11347 :Not a number. Value: -
# 11352 :Not a number. Value: (X)
# 11353 :Not a number. Value: (X)
# 11358 :Not a number. Value: (X)
# 11377 :Not a number. Value: 250,000+
# 11382 :Not a number. Value: (X)
# 11389 :Not a number. Value: -
# 11405 :Not a number. Value: (X)
# 11417 :Not a number. Value: -
# 11427 :Not a number. Value: (X)
# 11434 :Not a number. Value: -
# 11439 :Not a number. Value: (X)
# 11440 :Not a number. Value: -
# 11515 :Not a number. Value: (X)
# 11607 :Not a number. Value: -
# 11625 :Not a number. Value: -
# 11629 :Not a number. Value: (X)
# 11639 :Not a number. Value: -
# 11729 :Not a number. Value: 250,000+
# 11806 :Not a number. Value: (X)
# 11836 :Not a number. Value: (X)
# 11844 :Not a number. Value: (X)
# 12004 :Not a number. Value: (X)
# 12015 :Not a number. Value: (X)
# 12086 :Not a number. Value: -
# 12140 :Not a number. Value: (X)
# 12391 :Not a number. Value: (X)
# 12398 :Not a number. Value: -
# 12426 :Not a number. Value: -
# 12480 :Not a number. Value: (X)
# 12554 :Not a number. Value: (X)
# 12592 :Not a number. Value: (X)
# 12618 :Not a number. Value: (X)
# 12624 :Not a number. Value: (X)
# 12665 :Not a number. Value: (X)
# 12792 :Not a number. Value: -
# 12802 :Not a number. Value: (X)
# 12812 :Not a number. Value: -
# 12869 :Not a number. Value: (X)
# 12872 :Not a number. Value: (X)
# 12877 :Not a number. Value: (X)
# 12890 :Not a number. Value: (X)
# 12956 :Not a number. Value: (X)
# 13027 :Not a number. Value: (X)
# 13085 :Not a number. Value: (X)
# 13176 :Not a number. Value: (X)
# 13181 :Not a number. Value: -
# 13249 :Not a number. Value: (X)
# 13286 :Not a number. Value: (X)
# 13314 :Not a number. Value: (X)
# 13319 :Not a number. Value: (X)
# 13324 :Not a number. Value: (X)
# 13338 :Not a number. Value: (X)
# 13377 :Not a number. Value: (X)
# 13398 :Not a number. Value: (X)
# 13421 :Not a number. Value: (X)
# 13427 :Not a number. Value: (X)
# 13441 :Not a number. Value: (X)
# 13459 :Not a number. Value: (X)
# 13477 :Not a number. Value: (X)
# 13495 :Not a number. Value: (X)
# 13503 :Not a number. Value: (X)
# 13514 :Not a number. Value: (X)
# 13548 :Not a number. Value: (X)
# 13590 :Not a number. Value: (X)
# 13605 :Not a number. Value: -
# 13628 :Not a number. Value: (X)
# 13654 :Not a number. Value: (X)
# 13661 :Not a number. Value: (X)
# 13679 :Not a number. Value: (X)
# 13681 :Not a number. Value: -
# 13694 :Not a number. Value: -
# 13696 :Not a number. Value: (X)
# 13713 :Not a number. Value: (X)
# 13724 :Not a number. Value: -
# 13725 :Not a number. Value: -
# 13727 :Not a number. Value: (X)
# 13735 :Not a number. Value: (X)
# 13808 :Not a number. Value: -
# 13823 :Not a number. Value: -
# 13852 :Not a number. Value: (X)
# 13862 :Not a number. Value: -
# 13867 :Not a number. Value: 250,000+
# 13916 :Not a number. Value: -
# 13945 :Not a number. Value: (X)
# 13969 :Not a number. Value: -
# 13976 :Not a number. Value: (X)
# 13982 :Not a number. Value: (X)
# 14000 :Not a number. Value: (X)
# 14017 :Not a number. Value: -
# 14019 :Not a number. Value: -
# 14026 :Not a number. Value: (X)
# 14059 :Not a number. Value: -
# 14060 :Not a number. Value: -
# 14061 :Not a number. Value: (X)
# 14065 :Not a number. Value: (X)
# 14101 :Not a number. Value: (X)
# 14103 :Not a number. Value: (X)
# 14118 :Not a number. Value: -
# 14168 :Not a number. Value: -
# 14176 :Not a number. Value: -
# 14213 :Not a number. Value: (X)
# 14226 :Not a number. Value: (X)
# 14261 :Not a number. Value: (X)
# 14286 :Not a number. Value: -
# 14287 :Not a number. Value: -
# 14361 :Not a number. Value: -
# 14365 :Not a number. Value: (X)
# 14384 :Not a number. Value: -
# 14391 :Not a number. Value: -
# 14401 :Not a number. Value: -
# 14409 :Not a number. Value: -
# 14431 :Not a number. Value: (X)
# 14456 :Not a number. Value: -
# 14516 :Not a number. Value: (X)
# 14520 :Not a number. Value: (X)
# 14526 :Not a number. Value: (X)
# 14544 :Not a number. Value: (X)
# 14565 :Not a number. Value: -
# 14569 :Not a number. Value: (X)
# 14570 :Not a number. Value: -
# 14582 :Not a number. Value: (X)
# 14623 :Not a number. Value: -
# 14633 :Not a number. Value: (X)
# 14653 :Not a number. Value: (X)
# 14670 :Not a number. Value: (X)
# 14684 :Not a number. Value: (X)
# 14690 :Not a number. Value: (X)
# 14701 :Not a number. Value: (X)
# 14710 :Not a number. Value: (X)
# 14715 :Not a number. Value: (X)
# 14716 :Not a number. Value: -
# 14720 :Not a number. Value: -
# 14728 :Not a number. Value: (X)
# 14748 :Not a number. Value: (X)
# 14755 :Not a number. Value: (X)
# 14762 :Not a number. Value: -
# 14776 :Not a number. Value: -
# 14797 :Not a number. Value: (X)
# 14811 :Not a number. Value: (X)
# 14818 :Not a number. Value: (X)
# 14827 :Not a number. Value: (X)
# 14842 :Not a number. Value: (X)
# 14843 :Not a number. Value: (X)
# 14844 :Not a number. Value: -
# 14846 :Not a number. Value: -
# 14847 :Not a number. Value: (X)
# 14849 :Not a number. Value: (X)
# 14865 :Not a number. Value: (X)
# 14871 :Not a number. Value: (X)
# 14882 :Not a number. Value: (X)
# 14891 :Not a number. Value: (X)
# 14896 :Not a number. Value: (X)
# 14902 :Not a number. Value: (X)
# 14905 :Not a number. Value: -
# 14907 :Not a number. Value: (X)
# 14933 :Not a number. Value: (X)
# 14940 :Not a number. Value: (X)
# 14944 :Not a number. Value: (X)
# 14945 :Not a number. Value: (X)
# 14947 :Not a number. Value: -
# 14948 :Not a number. Value: (X)
# 14959 :Not a number. Value: -
# 14962 :Not a number. Value: -
# 14977 :Not a number. Value: (X)
# 14980 :Not a number. Value: (X)
# 14981 :Not a number. Value: (X)
# 14983 :Not a number. Value: (X)
# 14986 :Not a number. Value: (X)
# 15033 :Not a number. Value: -
# 15041 :Not a number. Value: -
# 15054 :Not a number. Value: -
# 15065 :Not a number. Value: (X)
# 15074 :Not a number. Value: (X)
# 15088 :Not a number. Value: (X)
# 15097 :Not a number. Value: -
# 15104 :Not a number. Value: (X)
# 15107 :Not a number. Value: (X)
# 15112 :Not a number. Value: (X)
# 15118 :Not a number. Value: -
# 15123 :Not a number. Value: (X)
# 15146 :Not a number. Value: (X)
# 15155 :Not a number. Value: (X)
# 15163 :Not a number. Value: (X)
# 15220 :Not a number. Value: -
# 15234 :Not a number. Value: -
# 15243 :Not a number. Value: (X)
# 15250 :Not a number. Value: (X)
# 15264 :Not a number. Value: -
# 15293 :Not a number. Value: (X)
# 15295 :Not a number. Value: (X)
# 15328 :Not a number. Value: (X)
# 15337 :Not a number. Value: (X)
# 15352 :Not a number. Value: -
# 15353 :Not a number. Value: -
# 15377 :Not a number. Value: (X)
# 15385 :Not a number. Value: (X)
# 15392 :Not a number. Value: -
# 15394 :Not a number. Value: (X)
# 15449 :Not a number. Value: -
# 15467 :Not a number. Value: (X)
# 15473 :Not a number. Value: -
# 15491 :Not a number. Value: -
# 15503 :Not a number. Value: (X)
# 15536 :Not a number. Value: (X)
# 15537 :Not a number. Value: (X)
# 15577 :Not a number. Value: (X)
# 15598 :Not a number. Value: -
# 15601 :Not a number. Value: -
# 15602 :Not a number. Value: (X)
# 15605 :Not a number. Value: -
# 15623 :Not a number. Value: (X)
# 15627 :Not a number. Value: -
# 15628 :Not a number. Value: (X)
# 15629 :Not a number. Value: (X)
# 15641 :Not a number. Value: -
# 15643 :Not a number. Value: -
# 15648 :Not a number. Value: -
# 15656 :Not a number. Value: (X)
# 15661 :Not a number. Value: (X)
# 15665 :Not a number. Value: -
# 15670 :Not a number. Value: -
# 15671 :Not a number. Value: (X)
# 15680 :Not a number. Value: (X)
# 15684 :Not a number. Value: -
# 15687 :Not a number. Value: -
# 15690 :Not a number. Value: -
# 15695 :Not a number. Value: (X)
# 15697 :Not a number. Value: -
# 15699 :Not a number. Value: -
# 15702 :Not a number. Value: -
# 15703 :Not a number. Value: (X)
# 15709 :Not a number. Value: (X)
# 15710 :Not a number. Value: (X)
# 15711 :Not a number. Value: -
# 15712 :Not a number. Value: -
# 15720 :Not a number. Value: (X)
# 15738 :Not a number. Value: -
# 15739 :Not a number. Value: (X)
# 15740 :Not a number. Value: -
# 15762 :Not a number. Value: (X)
# 15766 :Not a number. Value: (X)
# 15768 :Not a number. Value: (X)
# 15812 :Not a number. Value: (X)
# 15836 :Not a number. Value: (X)
# 15840 :Not a number. Value: (X)
# 15851 :Not a number. Value: -
# 15909 :Not a number. Value: -
# 15923 :Not a number. Value: -
# 16080 :Not a number. Value: (X)
# 16226 :Not a number. Value: -
# 16236 :Not a number. Value: (X)
# 16238 :Not a number. Value: -
# 16274 :Not a number. Value: -
# 16293 :Not a number. Value: 250,000+
# 16328 :Not a number. Value: -
# 16394 :Not a number. Value: -
# 16395 :Not a number. Value: -
# 16396 :Not a number. Value: -
# 16409 :Not a number. Value: -
# 16411 :Not a number. Value: -
# 16412 :Not a number. Value: -
# 16415 :Not a number. Value: (X)
# 16423 :Not a number. Value: (X)
# 16426 :Not a number. Value: -
# 16428 :Not a number. Value: (X)
# 16431 :Not a number. Value: (X)
# 16434 :Not a number. Value: -
# 16437 :Not a number. Value: -
# 16442 :Not a number. Value: (X)
# 16443 :Not a number. Value: -
# 16454 :Not a number. Value: (X)
# 16459 :Not a number. Value: -
# 16462 :Not a number. Value: (X)
# 16463 :Not a number. Value: -
# 16468 :Not a number. Value: -
# 16470 :Not a number. Value: (X)
# 16473 :Not a number. Value: -
# 16477 :Not a number. Value: -
# 16481 :Not a number. Value: -
# 16483 :Not a number. Value: (X)
# 16485 :Not a number. Value: (X)
# 16487 :Not a number. Value: (X)
# 16490 :Not a number. Value: -
# 16497 :Not a number. Value: (X)
# 16501 :Not a number. Value: -
# 16509 :Not a number. Value: (X)
# 16515 :Not a number. Value: (X)
# 16516 :Not a number. Value: (X)
# 16517 :Not a number. Value: -
# 16518 :Not a number. Value: -
# 16519 :Not a number. Value: -
# 16526 :Not a number. Value: -
# 16531 :Not a number. Value: (X)
# 16532 :Not a number. Value: (X)
# 16534 :Not a number. Value: -
# 16537 :Not a number. Value: -
# 16538 :Not a number. Value: (X)
# 16539 :Not a number. Value: -
# 16545 :Not a number. Value: (X)
# 16551 :Not a number. Value: (X)
# 16554 :Not a number. Value: -
# 16555 :Not a number. Value: (X)
# 16556 :Not a number. Value: -
# 16557 :Not a number. Value: (X)
# 16568 :Not a number. Value: -
# 16575 :Not a number. Value: (X)
# 16576 :Not a number. Value: -
# 16578 :Not a number. Value: -
# 16579 :Not a number. Value: -
# 16580 :Not a number. Value: (X)
# 16583 :Not a number. Value: -
# 16587 :Not a number. Value: (X)
# 16592 :Not a number. Value: (X)
# 16597 :Not a number. Value: (X)
# 16599 :Not a number. Value: (X)
# 16600 :Not a number. Value: -
# 16608 :Not a number. Value: (X)
# 16612 :Not a number. Value: -
# 16614 :Not a number. Value: -
# 16615 :Not a number. Value: (X)
# 16616 :Not a number. Value: (X)
# 16617 :Not a number. Value: (X)
# 16623 :Not a number. Value: -
# 16624 :Not a number. Value: (X)
# 16626 :Not a number. Value: -
# 16632 :Not a number. Value: (X)
# 16636 :Not a number. Value: (X)
# 16638 :Not a number. Value: (X)
# 16639 :Not a number. Value: -
# 16645 :Not a number. Value: (X)
# 16657 :Not a number. Value: -
# 16658 :Not a number. Value: (X)
# 16663 :Not a number. Value: -
# 16665 :Not a number. Value: (X)
# 16668 :Not a number. Value: (X)
# 16674 :Not a number. Value: -
# 16676 :Not a number. Value: -
# 16684 :Not a number. Value: -
# 16685 :Not a number. Value: (X)
# 16688 :Not a number. Value: (X)
# 16697 :Not a number. Value: -
# 16699 :Not a number. Value: (X)
# 16701 :Not a number. Value: -
# 16702 :Not a number. Value: -
# 16710 :Not a number. Value: -
# 16713 :Not a number. Value: -
# 16715 :Not a number. Value: (X)
# 16718 :Not a number. Value: -
# 16722 :Not a number. Value: (X)
# 16728 :Not a number. Value: -
# 16729 :Not a number. Value: (X)
# 16730 :Not a number. Value: -
# 16731 :Not a number. Value: -
# 16734 :Not a number. Value: (X)
# 16739 :Not a number. Value: -
# 16744 :Not a number. Value: -
# 16745 :Not a number. Value: -
# 16764 :Not a number. Value: -
# 16766 :Not a number. Value: (X)
# 16772 :Not a number. Value: (X)
# 16773 :Not a number. Value: (X)
# 16774 :Not a number. Value: (X)
# 16779 :Not a number. Value: (X)
# 16780 :Not a number. Value: -
# 16784 :Not a number. Value: (X)
# 16787 :Not a number. Value: (X)
# 16792 :Not a number. Value: (X)
# 16794 :Not a number. Value: (X)
# 16798 :Not a number. Value: (X)
# 16799 :Not a number. Value: -
# 16802 :Not a number. Value: (X)
# 16805 :Not a number. Value: (X)
# 16810 :Not a number. Value: (X)
# 16816 :Not a number. Value: (X)
# 16818 :Not a number. Value: (X)
# 16822 :Not a number. Value: -
# 16823 :Not a number. Value: -
# 16827 :Not a number. Value: -
# 16831 :Not a number. Value: (X)
# 16832 :Not a number. Value: -
# 16833 :Not a number. Value: (X)
# 16834 :Not a number. Value: (X)
# 16924 :Not a number. Value: -
# 17050 :Not a number. Value: (X)
# 17051 :Not a number. Value: (X)
# 17091 :Not a number. Value: -
# 17102 :Not a number. Value: (X)
# 17175 :Not a number. Value: (X)
# 17301 :Not a number. Value: 250,000+
# 17305 :Not a number. Value: (X)
# 17410 :Not a number. Value: (X)
# 17530 :Not a number. Value: (X)
# 17550 :Not a number. Value: (X)
# 17598 :Not a number. Value: (X)
# 17628 :Not a number. Value: (X)
# 17638 :Not a number. Value: -
# 17642 :Not a number. Value: -
# 17671 :Not a number. Value: 250,000+
# 17699 :Not a number. Value: (X)
# 17715 :Not a number. Value: (X)
# 17788 :Not a number. Value: (X)
# 17828 :Not a number. Value: (X)
# 17874 :Not a number. Value: -
# 17905 :Not a number. Value: -
# 17911 :Not a number. Value: (X)
# 17913 :Not a number. Value: 250,000+
# 17935 :Not a number. Value: (X)
# 17952 :Not a number. Value: -
# 17963 :Not a number. Value: -
# 18045 :Not a number. Value: (X)
# 18078 :Not a number. Value: (X)
# 18083 :Not a number. Value: (X)
# 18098 :Not a number. Value: -
# 18105 :Not a number. Value: (X)
# 18109 :Not a number. Value: -
# 18136 :Not a number. Value: (X)
# 18143 :Not a number. Value: (X)
# 18157 :Not a number. Value: (X)
# 18198 :Not a number. Value: -
# 18199 :Not a number. Value: (X)
# 18210 :Not a number. Value: -
# 18237 :Not a number. Value: (X)
# 18243 :Not a number. Value: (X)
# 18254 :Not a number. Value: (X)
# 18263 :Not a number. Value: -
# 18275 :Not a number. Value: (X)
# 18286 :Not a number. Value: (X)
# 18291 :Not a number. Value: (X)
# 18309 :Not a number. Value: (X)
# 18333 :Not a number. Value: (X)
# 18341 :Not a number. Value: -
# 18438 :Not a number. Value: (X)
# 18455 :Not a number. Value: (X)
# 18541 :Not a number. Value: (X)
# 18551 :Not a number. Value: (X)
# 18570 :Not a number. Value: -
# 18587 :Not a number. Value: (X)
# 18594 :Not a number. Value: (X)
# 18612 :Not a number. Value: (X)
# 18631 :Not a number. Value: (X)
# 18669 :Not a number. Value: (X)
# 18718 :Not a number. Value: -
# 18731 :Not a number. Value: -
# 18780 :Not a number. Value: (X)
# 18785 :Not a number. Value: (X)
# 18786 :Not a number. Value: (X)
# 18788 :Not a number. Value: (X)
# 18791 :Not a number. Value: -
# 18793 :Not a number. Value: (X)
# 18794 :Not a number. Value: (X)
# 18797 :Not a number. Value: -
# 18803 :Not a number. Value: (X)
# 18810 :Not a number. Value: -
# 18815 :Not a number. Value: (X)
# 18816 :Not a number. Value: (X)
# 18817 :Not a number. Value: (X)
# 18819 :Not a number. Value: -
# 18826 :Not a number. Value: -
# 18827 :Not a number. Value: -
# 18831 :Not a number. Value: (X)
# 18836 :Not a number. Value: (X)
# 18841 :Not a number. Value: -
# 18843 :Not a number. Value: (X)
# 18854 :Not a number. Value: -
# 18860 :Not a number. Value: (X)
# 18865 :Not a number. Value: (X)
# 18882 :Not a number. Value: (X)
# 18883 :Not a number. Value: (X)
# 18886 :Not a number. Value: -
# 18888 :Not a number. Value: (X)
# 18904 :Not a number. Value: (X)
# 18930 :Not a number. Value: -
# 18938 :Not a number. Value: (X)
# 18944 :Not a number. Value: (X)
# 18954 :Not a number. Value: (X)
# 18955 :Not a number. Value: -
# 18965 :Not a number. Value: -
# 18971 :Not a number. Value: (X)
# 18984 :Not a number. Value: -
# 18986 :Not a number. Value: (X)
# 18997 :Not a number. Value: (X)
# 18998 :Not a number. Value: -
# 18999 :Not a number. Value: -
# 19001 :Not a number. Value: (X)
# 19004 :Not a number. Value: -
# 19032 :Not a number. Value: (X)
# 19040 :Not a number. Value: -
# 19056 :Not a number. Value: (X)
# 19057 :Not a number. Value: -
# 19067 :Not a number. Value: -
# 19080 :Not a number. Value: -
# 19090 :Not a number. Value: (X)
# 19097 :Not a number. Value: -
# 19100 :Not a number. Value: (X)
# 19104 :Not a number. Value: (X)
# 19108 :Not a number. Value: -
# 19109 :Not a number. Value: (X)
# 19115 :Not a number. Value: (X)
# 19119 :Not a number. Value: -
# 19129 :Not a number. Value: -
# 19135 :Not a number. Value: (X)
# 19170 :Not a number. Value: (X)
# 19171 :Not a number. Value: (X)
# 19173 :Not a number. Value: (X)
# 19215 :Not a number. Value: (X)
# 19286 :Not a number. Value: -
# 19311 :Not a number. Value: (X)
# 19343 :Not a number. Value: (X)
# 19351 :Not a number. Value: (X)
# 19428 :Not a number. Value: (X)
# 19435 :Not a number. Value: -
# 19439 :Not a number. Value: (X)
# 19462 :Not a number. Value: (X)
# 19483 :Not a number. Value: (X)
# 19495 :Not a number. Value: (X)
# 19520 :Not a number. Value: -
# 19542 :Not a number. Value: (X)
# 19543 :Not a number. Value: (X)
# 19578 :Not a number. Value: (X)
# 19611 :Not a number. Value: (X)
# 19642 :Not a number. Value: (X)
# 19662 :Not a number. Value: 250,000+
# 19671 :Not a number. Value: (X)
# 19686 :Not a number. Value: (X)
# 19694 :Not a number. Value: (X)
# 19705 :Not a number. Value: (X)
# 19751 :Not a number. Value: (X)
# 19781 :Not a number. Value: (X)
# 19787 :Not a number. Value: (X)
# 19835 :Not a number. Value: (X)
# 19861 :Not a number. Value: (X)
# 19988 :Not a number. Value: (X)
# 19991 :Not a number. Value: (X)
# 20012 :Not a number. Value: (X)
# 20015 :Not a number. Value: (X)
# 20043 :Not a number. Value: -
# 20080 :Not a number. Value: (X)
# 20083 :Not a number. Value: (X)
# 20084 :Not a number. Value: (X)
# 20105 :Not a number. Value: (X)
# 20108 :Not a number. Value: (X)
# 20112 :Not a number. Value: (X)
# 20135 :Not a number. Value: (X)
# 20208 :Not a number. Value: -
# 20224 :Not a number. Value: (X)
# 20262 :Not a number. Value: (X)
# 20305 :Not a number. Value: (X)
# 20348 :Not a number. Value: -
# 20411 :Not a number. Value: (X)
# 20440 :Not a number. Value: (X)
# 20442 :Not a number. Value: (X)
# 20443 :Not a number. Value: -
# 20472 :Not a number. Value: -
# 20475 :Not a number. Value: (X)
# 20485 :Not a number. Value: (X)
# 20497 :Not a number. Value: -
# 20499 :Not a number. Value: -
# 20522 :Not a number. Value: (X)
# 20548 :Not a number. Value: -
# 20570 :Not a number. Value: -
# 20573 :Not a number. Value: (X)
# 20583 :Not a number. Value: 2,500-
# 20585 :Not a number. Value: (X)
# 20596 :Not a number. Value: -
# 20613 :Not a number. Value: (X)
# 20623 :Not a number. Value: (X)
# 20632 :Not a number. Value: (X)
# 20640 :Not a number. Value: (X)
# 20656 :Not a number. Value: -
# 20665 :Not a number. Value: (X)
# 20667 :Not a number. Value: (X)
# 20697 :Not a number. Value: (X)
# 20701 :Not a number. Value: (X)
# 20706 :Not a number. Value: (X)
# 20709 :Not a number. Value: -
# 20718 :Not a number. Value: -
# 20721 :Not a number. Value: (X)
# 20722 :Not a number. Value: (X)
# 20723 :Not a number. Value: (X)
# 20751 :Not a number. Value: (X)
# 20758 :Not a number. Value: -
# 20777 :Not a number. Value: (X)
# 20790 :Not a number. Value: -
# 20791 :Not a number. Value: -
# 20793 :Not a number. Value: (X)
# 20809 :Not a number. Value: (X)
# 20849 :Not a number. Value: -
# 20857 :Not a number. Value: (X)
# 20869 :Not a number. Value: -
# 20883 :Not a number. Value: (X)
# 20915 :Not a number. Value: (X)
# 20923 :Not a number. Value: (X)
# 20928 :Not a number. Value: (X)
# 20942 :Not a number. Value: -
# 20958 :Not a number. Value: (X)
# 20962 :Not a number. Value: (X)
# 20980 :Not a number. Value: (X)
# 20982 :Not a number. Value: (X)
# 21009 :Not a number. Value: (X)
# 21011 :Not a number. Value: (X)
# 21023 :Not a number. Value: (X)
# 21045 :Not a number. Value: (X)
# 21112 :Not a number. Value: -
# 21113 :Not a number. Value: -
# 21127 :Not a number. Value: (X)
# 21137 :Not a number. Value: (X)
# 21156 :Not a number. Value: -
# 21157 :Not a number. Value: (X)
# 21160 :Not a number. Value: (X)
# 21163 :Not a number. Value: -
# 21165 :Not a number. Value: (X)
# 21176 :Not a number. Value: (X)
# 21185 :Not a number. Value: (X)
# 21204 :Not a number. Value: (X)
# 21231 :Not a number. Value: -
# 21257 :Not a number. Value: (X)
# 21259 :Not a number. Value: (X)
# 21263 :Not a number. Value: -
# 21299 :Not a number. Value: (X)
# 21313 :Not a number. Value: (X)
# 21329 :Not a number. Value: (X)
# 21358 :Not a number. Value: (X)
# 21376 :Not a number. Value: (X)
# 21385 :Not a number. Value: (X)
# 21391 :Not a number. Value: -
# 21399 :Not a number. Value: (X)
# 21407 :Not a number. Value: -
# 21417 :Not a number. Value: (X)
# 21432 :Not a number. Value: -
# 21433 :Not a number. Value: -
# 21449 :Not a number. Value: (X)
# 21454 :Not a number. Value: (X)
# 21458 :Not a number. Value: (X)
# 21464 :Not a number. Value: (X)
# 21482 :Not a number. Value: -
# 21494 :Not a number. Value: (X)
# 21520 :Not a number. Value: (X)
# 21524 :Not a number. Value: (X)
# 21534 :Not a number. Value: (X)
# 21546 :Not a number. Value: -
# 21590 :Not a number. Value: (X)
# 21592 :Not a number. Value: (X)
# 21662 :Not a number. Value: (X)
# 21703 :Not a number. Value: (X)
# 21746 :Not a number. Value: (X)
# 21751 :Not a number. Value: (X)
# 21767 :Not a number. Value: -
# 21809 :Not a number. Value: (X)
# 21843 :Not a number. Value: (X)
# 21873 :Not a number. Value: -
# 21901 :Not a number. Value: (X)
# 21908 :Not a number. Value: -
# 21945 :Not a number. Value: (X)
# 21969 :Not a number. Value: (X)
# 21995 :Not a number. Value: (X)
# 22025 :Not a number. Value: -
# 22038 :Not a number. Value: -
# 22043 :Not a number. Value: (X)
# 22113 :Not a number. Value: (X)
# 22194 :Not a number. Value: (X)
# 22206 :Not a number. Value: -
# 22272 :Not a number. Value: (X)
# 22277 :Not a number. Value: (X)
# 22289 :Not a number. Value: -
# 22360 :Not a number. Value: -
# 22368 :Not a number. Value: (X)
# 22413 :Not a number. Value: (X)
# 22425 :Not a number. Value: (X)
# 22460 :Not a number. Value: -
# 22510 :Not a number. Value: (X)
# 22541 :Not a number. Value: (X)
# 22550 :Not a number. Value: -
# 22608 :Not a number. Value: (X)
# 22613 :Not a number. Value: (X)
# 22630 :Not a number. Value: (X)
# 22663 :Not a number. Value: (X)
# 22703 :Not a number. Value: -
# 22747 :Not a number. Value: (X)
# 22758 :Not a number. Value: (X)
# 22791 :Not a number. Value: (X)
# 22792 :Not a number. Value: (X)
# 22829 :Not a number. Value: (X)
# 22856 :Not a number. Value: (X)
# 22858 :Not a number. Value: -
# 22869 :Not a number. Value: (X)
# 22944 :Not a number. Value: -
# 22945 :Not a number. Value: (X)
# 23015 :Not a number. Value: -
# 23058 :Not a number. Value: (X)
# 23099 :Not a number. Value: (X)
# 23103 :Not a number. Value: -
# 23108 :Not a number. Value: (X)
# 23111 :Not a number. Value: -
# 23117 :Not a number. Value: (X)
# 23128 :Not a number. Value: (X)
# 23181 :Not a number. Value: -
# 23281 :Not a number. Value: (X)
# 23340 :Not a number. Value: (X)
# 23375 :Not a number. Value: (X)
# 23379 :Not a number. Value: (X)
# 23381 :Not a number. Value: (X)
# 23385 :Not a number. Value: -
# 23415 :Not a number. Value: -
# 23438 :Not a number. Value: (X)
# 23439 :Not a number. Value: -
# 23468 :Not a number. Value: -
# 23562 :Not a number. Value: -
# 23569 :Not a number. Value: (X)
# 23571 :Not a number. Value: (X)
# 23585 :Not a number. Value: (X)
# 23622 :Not a number. Value: (X)
# 23655 :Not a number. Value: (X)
# 23659 :Not a number. Value: (X)
# 23665 :Not a number. Value: (X)
# 23677 :Not a number. Value: 2,500-
# 23693 :Not a number. Value: 2,500-
# 23706 :Not a number. Value: (X)
# 23714 :Not a number. Value: (X)
# 23718 :Not a number. Value: -
# 23720 :Not a number. Value: (X)
# 23731 :Not a number. Value: (X)
# 23736 :Not a number. Value: -
# 23748 :Not a number. Value: (X)
# 23766 :Not a number. Value: -
# 23789 :Not a number. Value: -
# 23790 :Not a number. Value: -
# 23792 :Not a number. Value: -
# 23806 :Not a number. Value: (X)
# 23823 :Not a number. Value: -
# 23825 :Not a number. Value: (X)
# 23826 :Not a number. Value: -
# 23829 :Not a number. Value: (X)
# 23837 :Not a number. Value: (X)
# 23838 :Not a number. Value: (X)
# 23847 :Not a number. Value: -
# 23852 :Not a number. Value: -
# 23867 :Not a number. Value: -
# 23889 :Not a number. Value: -
# 23895 :Not a number. Value: (X)
# 23904 :Not a number. Value: (X)
# 23910 :Not a number. Value: -
# 23912 :Not a number. Value: (X)
# 23914 :Not a number. Value: -
# 23916 :Not a number. Value: -
# 23932 :Not a number. Value: -
# 23939 :Not a number. Value: (X)
# 23944 :Not a number. Value: (X)
# 23947 :Not a number. Value: (X)
# 23960 :Not a number. Value: -
# 23962 :Not a number. Value: -
# 23965 :Not a number. Value: (X)
# 23984 :Not a number. Value: -
# 23992 :Not a number. Value: (X)
# 23995 :Not a number. Value: (X)
# 23997 :Not a number. Value: (X)
# 24005 :Not a number. Value: -
# 24006 :Not a number. Value: (X)
# 24010 :Not a number. Value: -
# 24017 :Not a number. Value: (X)
# 24024 :Not a number. Value: (X)
# 24027 :Not a number. Value: (X)
# 24028 :Not a number. Value: -
# 24044 :Not a number. Value: (X)
# 24050 :Not a number. Value: -
# 24069 :Not a number. Value: -
# 24075 :Not a number. Value: -
# 24078 :Not a number. Value: (X)
# 24081 :Not a number. Value: -
# 24088 :Not a number. Value: (X)
# 24091 :Not a number. Value: (X)
# 24113 :Not a number. Value: (X)
# 24124 :Not a number. Value: (X)
# 24132 :Not a number. Value: (X)
# 24135 :Not a number. Value: (X)
# 24273 :Not a number. Value: (X)
# 24498 :Not a number. Value: (X)
# 24521 :Not a number. Value: (X)
# 24532 :Not a number. Value: -
# 24541 :Not a number. Value: -
# 24543 :Not a number. Value: (X)
# 24553 :Not a number. Value: -
# 24554 :Not a number. Value: -
# 24559 :Not a number. Value: (X)
# 24560 :Not a number. Value: -
# 24582 :Not a number. Value: (X)
# 24583 :Not a number. Value: (X)
# 24609 :Not a number. Value: -
# 24641 :Not a number. Value: -
# 24646 :Not a number. Value: (X)
# 24663 :Not a number. Value: (X)
# 24672 :Not a number. Value: -
# 24677 :Not a number. Value: -
# 24680 :Not a number. Value: (X)
# 24707 :Not a number. Value: -
# 24716 :Not a number. Value: -
# 24729 :Not a number. Value: (X)
# 24742 :Not a number. Value: (X)
# 24762 :Not a number. Value: -
# 24763 :Not a number. Value: -
# 24767 :Not a number. Value: (X)
# 24780 :Not a number. Value: -
# 24781 :Not a number. Value: -
# 24794 :Not a number. Value: (X)
# 24824 :Not a number. Value: (X)
# 24844 :Not a number. Value: (X)
# 24850 :Not a number. Value: -
# 24855 :Not a number. Value: (X)
# 24874 :Not a number. Value: -
# 24885 :Not a number. Value: (X)
# 24924 :Not a number. Value: (X)
# 24938 :Not a number. Value: (X)
# 24951 :Not a number. Value: (X)
# 24956 :Not a number. Value: (X)
# 24957 :Not a number. Value: -
# 24960 :Not a number. Value: (X)
# 24961 :Not a number. Value: (X)
# 24963 :Not a number. Value: (X)
# 24967 :Not a number. Value: -
# 24968 :Not a number. Value: (X)
# 24973 :Not a number. Value: -
# 24975 :Not a number. Value: (X)
# 24978 :Not a number. Value: (X)
# 24979 :Not a number. Value: (X)
# 24981 :Not a number. Value: -
# 24992 :Not a number. Value: -
# 24998 :Not a number. Value: -
# 25006 :Not a number. Value: -
# 25007 :Not a number. Value: -
# 25010 :Not a number. Value: (X)
# 25021 :Not a number. Value: -
# 25025 :Not a number. Value: -
# 25028 :Not a number. Value: (X)
# 25043 :Not a number. Value: -
# 25044 :Not a number. Value: -
# 25055 :Not a number. Value: (X)
# 25056 :Not a number. Value: (X)
# 25067 :Not a number. Value: (X)
# 25068 :Not a number. Value: -
# 25085 :Not a number. Value: (X)
# 25116 :Not a number. Value: (X)
# 25125 :Not a number. Value: -
# 25126 :Not a number. Value: -
# 25131 :Not a number. Value: -
# 25155 :Not a number. Value: -
# 25160 :Not a number. Value: (X)
# 25183 :Not a number. Value: -
# 25185 :Not a number. Value: (X)
# 25214 :Not a number. Value: -
# 25215 :Not a number. Value: 250,000+
# 25229 :Not a number. Value: (X)
# 25230 :Not a number. Value: -
# 25249 :Not a number. Value: -
# 25256 :Not a number. Value: -
# 25304 :Not a number. Value: -
# 25305 :Not a number. Value: -
# 25306 :Not a number. Value: -
# 25308 :Not a number. Value: -
# 25312 :Not a number. Value: -
# 25313 :Not a number. Value: -
# 25315 :Not a number. Value: -
# 25316 :Not a number. Value: -
# 25339 :Not a number. Value: (X)
# 25347 :Not a number. Value: (X)
# 25351 :Not a number. Value: (X)
# 25360 :Not a number. Value: (X)
# 25368 :Not a number. Value: -
# 25369 :Not a number. Value: -
# 25370 :Not a number. Value: -
# 25373 :Not a number. Value: -
# 25376 :Not a number. Value: -
# 25378 :Not a number. Value: -
# 25425 :Not a number. Value: (X)
# 25426 :Not a number. Value: -
# 25427 :Not a number. Value: -
# 25429 :Not a number. Value: -
# 25430 :Not a number. Value: -
# 25435 :Not a number. Value: -
# 25438 :Not a number. Value: -
# 25443 :Not a number. Value: -
# 25444 :Not a number. Value: (X)
# 25445 :Not a number. Value: -
# 25446 :Not a number. Value: -
# 25447 :Not a number. Value: -
# 25449 :Not a number. Value: -
# 25450 :Not a number. Value: -
# 25454 :Not a number. Value: (X)
# 25455 :Not a number. Value: -
# 25457 :Not a number. Value: -
# 25458 :Not a number. Value: -
# 25459 :Not a number. Value: -
# 25461 :Not a number. Value: -
# 25462 :Not a number. Value: -
# 25463 :Not a number. Value: (X)
# 25468 :Not a number. Value: (X)
# 25471 :Not a number. Value: (X)
# 25495 :Not a number. Value: (X)
# 25496 :Not a number. Value: -
# 25503 :Not a number. Value: (X)
# 25509 :Not a number. Value: -
# 25526 :Not a number. Value: (X)
# 25533 :Not a number. Value: (X)
# 25555 :Not a number. Value: -
# 25568 :Not a number. Value: (X)
# 25570 :Not a number. Value: -
# 25571 :Not a number. Value: -
# 25594 :Not a number. Value: -
# 25599 :Not a number. Value: -
# 25608 :Not a number. Value: (X)
# 25609 :Not a number. Value: -
# 25619 :Not a number. Value: 2,500-
# 25627 :Not a number. Value: (X)
# 25629 :Not a number. Value: -
# 25638 :Not a number. Value: (X)
# 25641 :Not a number. Value: -
# 25645 :Not a number. Value: -
# 25659 :Not a number. Value: (X)
# 25667 :Not a number. Value: -
# 25669 :Not a number. Value: (X)
# 25683 :Not a number. Value: (X)
# 25686 :Not a number. Value: -
# 25689 :Not a number. Value: -
# 25723 :Not a number. Value: -
# 25743 :Not a number. Value: 250,000+
# 25761 :Not a number. Value: (X)
# 25788 :Not a number. Value: -
# 25792 :Not a number. Value: (X)
# 25797 :Not a number. Value: -
# 25803 :Not a number. Value: -
# 25805 :Not a number. Value: -
# 25806 :Not a number. Value: -
# 25807 :Not a number. Value: (X)
# 25808 :Not a number. Value: -
# 25809 :Not a number. Value: -
# 25811 :Not a number. Value: (X)
# 25813 :Not a number. Value: (X)
# 25814 :Not a number. Value: (X)
# 25817 :Not a number. Value: -
# 25820 :Not a number. Value: (X)
# 25823 :Not a number. Value: -
# 25828 :Not a number. Value: -
# 25838 :Not a number. Value: -
# 25844 :Not a number. Value: (X)
# 25858 :Not a number. Value: -
# 25873 :Not a number. Value: (X)
# 25877 :Not a number. Value: (X)
# 25907 :Not a number. Value: (X)
# 25910 :Not a number. Value: -
# 25912 :Not a number. Value: -
# 25919 :Not a number. Value: (X)
# 25920 :Not a number. Value: (X)
# 25923 :Not a number. Value: (X)
# 25925 :Not a number. Value: -
# 25931 :Not a number. Value: 2,500-
# 25946 :Not a number. Value: -
# 25948 :Not a number. Value: (X)
# 25951 :Not a number. Value: (X)
# 25954 :Not a number. Value: -
# 26048 :Not a number. Value: (X)
# 26063 :Not a number. Value: -
# 26064 :Not a number. Value: -
# 26066 :Not a number. Value: (X)
# 26075 :Not a number. Value: (X)
# 26076 :Not a number. Value: -
# 26095 :Not a number. Value: (X)
# 26096 :Not a number. Value: -
# 26105 :Not a number. Value: -
# 26116 :Not a number. Value: (X)
# 26123 :Not a number. Value: (X)
# 26124 :Not a number. Value: (X)
# 26135 :Not a number. Value: -
# 26142 :Not a number. Value: (X)
# 26150 :Not a number. Value: (X)
# 26151 :Not a number. Value: -
# 26152 :Not a number. Value: -
# 26153 :Not a number. Value: (X)
# 26166 :Not a number. Value: -
# 26168 :Not a number. Value: -
# 26170 :Not a number. Value: (X)
# 26199 :Not a number. Value: (X)
# 26207 :Not a number. Value: (X)
# 26240 :Not a number. Value: (X)
# 26264 :Not a number. Value: -
# 26267 :Not a number. Value: -
# 26287 :Not a number. Value: -
# 26292 :Not a number. Value: (X)
# 26294 :Not a number. Value: -
# 26297 :Not a number. Value: (X)
# 26300 :Not a number. Value: -
# 26316 :Not a number. Value: -
# 26326 :Not a number. Value: (X)
# 26339 :Not a number. Value: (X)
# 26365 :Not a number. Value: (X)
# 26367 :Not a number. Value: (X)
# 26379 :Not a number. Value: -
# 26403 :Not a number. Value: (X)
# 26414 :Not a number. Value: (X)
# 26419 :Not a number. Value: (X)
# 26445 :Not a number. Value: -
# 26476 :Not a number. Value: -
# 26479 :Not a number. Value: (X)
# 26493 :Not a number. Value: (X)
# 26502 :Not a number. Value: (X)
# 26538 :Not a number. Value: (X)
# 26547 :Not a number. Value: (X)
# 26556 :Not a number. Value: -
# 26573 :Not a number. Value: (X)
# 26587 :Not a number. Value: (X)
# 26615 :Not a number. Value: (X)
# 26628 :Not a number. Value: (X)
# 26668 :Not a number. Value: (X)
# 26673 :Not a number. Value: (X)
# 26723 :Not a number. Value: (X)
# 26739 :Not a number. Value: -
# 26750 :Not a number. Value: (X)
# 26837 :Not a number. Value: (X)
# 26846 :Not a number. Value: (X)
# 26858 :Not a number. Value: (X)
# 26864 :Not a number. Value: (X)
# 26867 :Not a number. Value: (X)
# 26875 :Not a number. Value: (X)
# 26896 :Not a number. Value: (X)
# 26903 :Not a number. Value: -
# 26946 :Not a number. Value: -
# 26948 :Not a number. Value: (X)
# 26961 :Not a number. Value: -
# 26973 :Not a number. Value: (X)
# 26978 :Not a number. Value: (X)
# 26990 :Not a number. Value: (X)
# 27001 :Not a number. Value: (X)
# 27006 :Not a number. Value: (X)
# 27018 :Not a number. Value: -
# 27039 :Not a number. Value: (X)
# 27040 :Not a number. Value: (X)
# 27046 :Not a number. Value: (X)
# 27074 :Not a number. Value: (X)
# 27075 :Not a number. Value: (X)
# 27080 :Not a number. Value: (X)
# 27092 :Not a number. Value: (X)
# 27102 :Not a number. Value: (X)
# 27106 :Not a number. Value: (X)
# 27117 :Not a number. Value: -
# 27119 :Not a number. Value: (X)
# 27147 :Not a number. Value: (X)
# 27159 :Not a number. Value: (X)
# 27191 :Not a number. Value: -
# 27192 :Not a number. Value: (X)
# 27220 :Not a number. Value: (X)
# 27221 :Not a number. Value: (X)
# 27250 :Not a number. Value: (X)
# 27271 :Not a number. Value: (X)
# 27277 :Not a number. Value: -
# 27295 :Not a number. Value: (X)
# 27311 :Not a number. Value: -
# 27316 :Not a number. Value: -
# 27319 :Not a number. Value: (X)
# 27323 :Not a number. Value: (X)
# 27341 :Not a number. Value: (X)
# 27365 :Not a number. Value: -
# 27404 :Not a number. Value: (X)
# 27410 :Not a number. Value: (X)
# 27418 :Not a number. Value: (X)
# 27430 :Not a number. Value: -
# 27431 :Not a number. Value: (X)
# 27444 :Not a number. Value: (X)
# 27447 :Not a number. Value: (X)
# 27457 :Not a number. Value: -
# 27460 :Not a number. Value: -
# 27472 :Not a number. Value: (X)
# 27474 :Not a number. Value: -
# 27519 :Not a number. Value: (X)
# 27535 :Not a number. Value: (X)
# 27541 :Not a number. Value: -
# 27548 :Not a number. Value: -
# 27552 :Not a number. Value: (X)
# 27561 :Not a number. Value: -
# 27566 :Not a number. Value: (X)
# 27572 :Not a number. Value: -
# 27581 :Not a number. Value: (X)
# 27586 :Not a number. Value: (X)
# 27610 :Not a number. Value: -
# 27622 :Not a number. Value: (X)
# 27636 :Not a number. Value: -
# 27637 :Not a number. Value: (X)
# 27643 :Not a number. Value: -
# 27647 :Not a number. Value: (X)
# 27650 :Not a number. Value: (X)
# 27653 :Not a number. Value: -
# 27656 :Not a number. Value: (X)
# 27675 :Not a number. Value: -
# 27695 :Not a number. Value: (X)
# 27711 :Not a number. Value: -
# 27728 :Not a number. Value: (X)
# 27731 :Not a number. Value: -
# 27732 :Not a number. Value: -
# 27734 :Not a number. Value: (X)
# 27737 :Not a number. Value: (X)
# 27750 :Not a number. Value: (X)
# 27788 :Not a number. Value: (X)
# 27807 :Not a number. Value: -
# 27813 :Not a number. Value: -
# 27858 :Not a number. Value: (X)
# 27867 :Not a number. Value: (X)
# 27887 :Not a number. Value: (X)
# 27889 :Not a number. Value: -
# 27898 :Not a number. Value: -
# 27945 :Not a number. Value: (X)
# 27946 :Not a number. Value: (X)
# 27948 :Not a number. Value: (X)
# 27954 :Not a number. Value: (X)
# 27966 :Not a number. Value: (X)
# 27974 :Not a number. Value: -
# 27981 :Not a number. Value: (X)
# 27983 :Not a number. Value: -
# 27996 :Not a number. Value: (X)
# 28004 :Not a number. Value: (X)
# 28028 :Not a number. Value: (X)
# 28029 :Not a number. Value: -
# 28035 :Not a number. Value: (X)
# 28038 :Not a number. Value: (X)
# 28051 :Not a number. Value: (X)
# 28064 :Not a number. Value: (X)
# 28081 :Not a number. Value: (X)
# 28086 :Not a number. Value: (X)
# 28090 :Not a number. Value: (X)
# 28097 :Not a number. Value: (X)
# 28098 :Not a number. Value: (X)
# 28107 :Not a number. Value: (X)
# 28109 :Not a number. Value: -
# 28110 :Not a number. Value: -
# 28113 :Not a number. Value: (X)
# 28141 :Not a number. Value: (X)
# 28152 :Not a number. Value: 2,500-
# 28173 :Not a number. Value: (X)
# 28179 :Not a number. Value: (X)
# 28182 :Not a number. Value: (X)
# 28201 :Not a number. Value: (X)
# 28207 :Not a number. Value: (X)
# 28213 :Not a number. Value: (X)
# 28224 :Not a number. Value: (X)
# 28233 :Not a number. Value: (X)
# 28236 :Not a number. Value: (X)
# 28248 :Not a number. Value: (X)
# 28258 :Not a number. Value: -
# 28270 :Not a number. Value: (X)
# 28298 :Not a number. Value: (X)
# 28299 :Not a number. Value: -
# 28307 :Not a number. Value: (X)
# 28308 :Not a number. Value: (X)
# 28311 :Not a number. Value: -
# 28322 :Not a number. Value: (X)
# 28332 :Not a number. Value: -
# 28338 :Not a number. Value: (X)
# 28476 :Not a number. Value: (X)
# 28608 :Not a number. Value: (X)
# 28855 :Not a number. Value: -
# 28960 :Not a number. Value: (X)
# 28992 :Not a number. Value: (X)
# 29094 :Not a number. Value: (X)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27385 entries, 0 to 29320
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  27385 non-null  object
#  1   City             27385 non-null  object
#  2   Median Income    27385 non-null  object
# dtypes: object(3)
# memory usage: 855.8+ KB

# %%
#converto in intero il tipo oggetto
df4_MedianHouseholdIncome2015['Median Income'] = df4_MedianHouseholdIncome2015['Median Income'].astype(int)

# %%
df4_MedianHouseholdIncome2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27385 entries, 0 to 29320
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  27385 non-null  object
#  1   City             27385 non-null  object
#  2   Median Income    27385 non-null  int32
# dtypes: int32(1), object(2)
# memory usage: 748.8+ KB

# %%
dimensions = (28, 10)
fig, ax = plt.subplots(figsize=dimensions)
plt.xticks(rotation=90)
sns.violinplot(ax=ax ,data=df4_MedianHouseholdIncome2015, x='Geographic Area', y="Median Income" )
# Out:
# <AxesSubplot:xlabel='Geographic Area', ylabel='Median Income'>

# %% [markdown]
# Dal grafico, tenendo in considerazione i risulatati delle precedenti analisi, una prima percezione che si ha è che negli stati in cui la ricchezza è inequamente distribuita quindi con gaussiane più piatte e divario tra mediana e outlier elevata, il tasso di uccisioni sia più elevato; in generale questa affermazione non è sempre valida.

# %% [markdown]
# 7.Cleaning percentage people below poverty level data
# ===

# %%
with open(r'PercentagePeopleBelowPovertyLevel.csv', 'rb') as f:
    result = chardet.detect(f.read())  
    print(result)
dfPercentagePeopleBelowPovertyLevel = pd.read_csv('PercentagePeopleBelowPovertyLevel.csv',encoding=result['encoding'])
dfPercentagePeopleBelowPovertyLevel["Geographic Area"]=dfPercentagePeopleBelowPovertyLevel["Geographic Area"].str.strip()
dfPercentagePeopleBelowPovertyLevel["City"]=dfPercentagePeopleBelowPovertyLevel["City"].str.strip()
dfPercentagePeopleBelowPovertyLevel.head(5)
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
#   Geographic Area             City poverty_rate
# 0              AL       Abanda CDP         78.8
# 1              AL   Abbeville city         29.1
# 2              AL  Adamsville city         25.5
# 3              AL     Addison town         30.7
# 4              AL       Akron town           42

# %%
dfPercentagePeopleBelowPovertyLevel.dtypes
# Out:
# Geographic Area    object
# City               object
# poverty_rate       object
# dtype: object

# %%
dfPercentagePeopleBelowPovertyLevel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29329 entries, 0 to 29328
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  29329 non-null  object
#  1   City             29329 non-null  object
#  2   poverty_rate     29329 non-null  object
# dtypes: object(3)
# memory usage: 687.5+ KB

# %%
df2_PercentagePeopleBelowPovertyLevel = dfPercentagePeopleBelowPovertyLevel.copy()
df2_PercentagePeopleBelowPovertyLevel["City"] = df2_PercentagePeopleBelowPovertyLevel["City"].str.lower()
df2_PercentagePeopleBelowPovertyLevel["City"] = df2_PercentagePeopleBelowPovertyLevel["City"].str.replace("cdp","")

# %% [markdown]
# Nel successivo blocco, dopo aver identificato la tipologia di dato per colonna le operazioni che devo eseguire sono le seguenti:
# <ul>
#   <li>Iterare nella colonna income per verificare la consistenza dei dati.Il fatto di avere dei dati row non mi permette di convertirli immediatamente in float o int perchè l'interprete mi restituirebbe un errore nel caso non tutti fossero del tipo corretto</li>
#   <li>Splittare la stringa per poter applicare il metodo isnumeric che controlla se il contenuto della stringa è un numero intero</li>
#   <li>Eliminare le righe con valori percentuali non numerici.</li>
#   <li>Trasformare il tipo di dato da python object a float</li>
# </ul>

# %%
for j,item in enumerate(df2_PercentagePeopleBelowPovertyLevel['poverty_rate']):
    #if not item.isnumeric():
    item2 = df2_PercentagePeopleBelowPovertyLevel['poverty_rate'][j].split(".")
    if not item2[0].isnumeric():
        df2_PercentagePeopleBelowPovertyLevel.drop(index=j, inplace = True) 
        print(str(j)+' :Not a number.'+ ' Value: '+item)
df2_PercentagePeopleBelowPovertyLevel['poverty_rate'] = df2_PercentagePeopleBelowPovertyLevel['poverty_rate'].astype(float)
df2_PercentagePeopleBelowPovertyLevel.dtypes
# Out:
# 573 :Not a number. Value: -
# 608 :Not a number. Value: -
# 632 :Not a number. Value: -
# 637 :Not a number. Value: -
# 662 :Not a number. Value: -
# 667 :Not a number. Value: -
# 676 :Not a number. Value: -
# 685 :Not a number. Value: -
# 711 :Not a number. Value: -
# 712 :Not a number. Value: -
# 726 :Not a number. Value: -
# 770 :Not a number. Value: -
# 784 :Not a number. Value: -
# 792 :Not a number. Value: -
# 832 :Not a number. Value: -
# 842 :Not a number. Value: -
# 843 :Not a number. Value: -
# 844 :Not a number. Value: -
# 847 :Not a number. Value: -
# 894 :Not a number. Value: -
# 911 :Not a number. Value: -
# 932 :Not a number. Value: -
# 1096 :Not a number. Value: -
# 1113 :Not a number. Value: -
# 1151 :Not a number. Value: -
# 1184 :Not a number. Value: -
# 1263 :Not a number. Value: -
# 1329 :Not a number. Value: -
# 1376 :Not a number. Value: -
# 1953 :Not a number. Value: -
# 2023 :Not a number. Value: -
# 2141 :Not a number. Value: -
# 2167 :Not a number. Value: -
# 2472 :Not a number. Value: -
# 2504 :Not a number. Value: -
# 2656 :Not a number. Value: -
# 2696 :Not a number. Value: -
# 2864 :Not a number. Value: -
# 2965 :Not a number. Value: -
# 3076 :Not a number. Value: -
# 3202 :Not a number. Value: -
# 3235 :Not a number. Value: -
# 3251 :Not a number. Value: -
# 3256 :Not a number. Value: -
# 3257 :Not a number. Value: -
# 3319 :Not a number. Value: -
# 3328 :Not a number. Value: -
# 3337 :Not a number. Value: -
# 3351 :Not a number. Value: -
# 3424 :Not a number. Value: -
# 3493 :Not a number. Value: -
# 3539 :Not a number. Value: -
# 3618 :Not a number. Value: -
# 3652 :Not a number. Value: -
# 3754 :Not a number. Value: -
# 3905 :Not a number. Value: -
# 4547 :Not a number. Value: -
# 4621 :Not a number. Value: -
# 4775 :Not a number. Value: -
# 5236 :Not a number. Value: -
# 5335 :Not a number. Value: -
# 5605 :Not a number. Value: -
# 5864 :Not a number. Value: -
# 6047 :Not a number. Value: -
# 6360 :Not a number. Value: -
# 6476 :Not a number. Value: -
# 7089 :Not a number. Value: -
# 8131 :Not a number. Value: -
# 8168 :Not a number. Value: -
# 8700 :Not a number. Value: -
# 8705 :Not a number. Value: -
# 8898 :Not a number. Value: -
# 9138 :Not a number. Value: -
# 9319 :Not a number. Value: -
# 10747 :Not a number. Value: -
# 11079 :Not a number. Value: -
# 11106 :Not a number. Value: -
# 11644 :Not a number. Value: -
# 13699 :Not a number. Value: -
# 13729 :Not a number. Value: -
# 13974 :Not a number. Value: -
# 14024 :Not a number. Value: -
# 14064 :Not a number. Value: -
# 14173 :Not a number. Value: -
# 14181 :Not a number. Value: -
# 14396 :Not a number. Value: -
# 14570 :Not a number. Value: -
# 14768 :Not a number. Value: -
# 15039 :Not a number. Value: -
# 15398 :Not a number. Value: -
# 15479 :Not a number. Value: -
# 15607 :Not a number. Value: -
# 15708 :Not a number. Value: -
# 16280 :Not a number. Value: -
# 16400 :Not a number. Value: -
# 16449 :Not a number. Value: -
# 16532 :Not a number. Value: -
# 16543 :Not a number. Value: -
# 16582 :Not a number. Value: -
# 16584 :Not a number. Value: -
# 16618 :Not a number. Value: -
# 16645 :Not a number. Value: -
# 16663 :Not a number. Value: -
# 16724 :Not a number. Value: -
# 16805 :Not a number. Value: -
# 16828 :Not a number. Value: -
# 16930 :Not a number. Value: -
# 17648 :Not a number. Value: -
# 17911 :Not a number. Value: -
# 18269 :Not a number. Value: -
# 19063 :Not a number. Value: -
# 19441 :Not a number. Value: -
# 20354 :Not a number. Value: -
# 20554 :Not a number. Value: -
# 20602 :Not a number. Value: -
# 20715 :Not a number. Value: -
# 20724 :Not a number. Value: -
# 21162 :Not a number. Value: -
# 21237 :Not a number. Value: -
# 21552 :Not a number. Value: -
# 21914 :Not a number. Value: -
# 22709 :Not a number. Value: -
# 23109 :Not a number. Value: -
# 23445 :Not a number. Value: -
# 23742 :Not a number. Value: -
# 23772 :Not a number. Value: -
# 23798 :Not a number. Value: -
# 23858 :Not a number. Value: -
# 23873 :Not a number. Value: -
# 23895 :Not a number. Value: -
# 23968 :Not a number. Value: -
# 24560 :Not a number. Value: -
# 24616 :Not a number. Value: -
# 24648 :Not a number. Value: -
# 24714 :Not a number. Value: -
# 24881 :Not a number. Value: -
# 24980 :Not a number. Value: -
# 25050 :Not a number. Value: -
# 25133 :Not a number. Value: -
# 25190 :Not a number. Value: -
# 25237 :Not a number. Value: -
# 25312 :Not a number. Value: -
# 25313 :Not a number. Value: -
# 25376 :Not a number. Value: -
# 25380 :Not a number. Value: -
# 25385 :Not a number. Value: -
# 25436 :Not a number. Value: -
# 25442 :Not a number. Value: -
# 25445 :Not a number. Value: -
# 25456 :Not a number. Value: -
# 25464 :Not a number. Value: -
# 25468 :Not a number. Value: -
# 25516 :Not a number. Value: -
# 25606 :Not a number. Value: -
# 25652 :Not a number. Value: -
# 25674 :Not a number. Value: -
# 25693 :Not a number. Value: -
# 25795 :Not a number. Value: -
# 25804 :Not a number. Value: -
# 25810 :Not a number. Value: -
# 25816 :Not a number. Value: -
# 25865 :Not a number. Value: -
# 25961 :Not a number. Value: -
# 26071 :Not a number. Value: -
# 26083 :Not a number. Value: -
# 26103 :Not a number. Value: -
# 26158 :Not a number. Value: -
# 26159 :Not a number. Value: -
# 26294 :Not a number. Value: -
# 26301 :Not a number. Value: -
# 26307 :Not a number. Value: -
# 26323 :Not a number. Value: -
# 26386 :Not a number. Value: -
# 26452 :Not a number. Value: -
# 26483 :Not a number. Value: -
# 27467 :Not a number. Value: -
# 27481 :Not a number. Value: -
# 27548 :Not a number. Value: -
# 27579 :Not a number. Value: -
# 27617 :Not a number. Value: -
# 27643 :Not a number. Value: -
# 27660 :Not a number. Value: -
# 27682 :Not a number. Value: -
# 27990 :Not a number. Value: -
# 29128 :Not a number. Value: -
# 29133 :Not a number. Value: -
# 29151 :Not a number. Value: -
# 29152 :Not a number. Value: -
# 29160 :Not a number. Value: -
# 29171 :Not a number. Value: -
# 29193 :Not a number. Value: -
# 29198 :Not a number. Value: -
# 29220 :Not a number. Value: -
# 29224 :Not a number. Value: -
# 29238 :Not a number. Value: -
# 29244 :Not a number. Value: -
# 29261 :Not a number. Value: -
# 29266 :Not a number. Value: -
# 29273 :Not a number. Value: -
# 29289 :Not a number. Value: -
# 29304 :Not a number. Value: -
# Geographic Area     object
# City                object
# poverty_rate       float64
# dtype: object

# %%
df2_PercentagePeopleBelowPovertyLevel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29128 entries, 0 to 29328
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  29128 non-null  object
#  1   City             29128 non-null  object
#  2   poverty_rate     29128 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 1.9+ MB

# %%
df2_PercentagePeopleBelowPovertyLevel.head(10)
# Out:
#   Geographic Area                 City  poverty_rate
# 0              AL              abanda           78.8
# 1              AL       abbeville city          29.1
# 2              AL      adamsville city          25.5
# 3              AL         addison town          30.7
# 4              AL           akron town          42.0
# 5              AL       alabaster city          11.2
# 6              AL     albertville city          26.7
# 7              AL  alexander city city          30.4
# 8              AL          alexandria            9.7
# 9              AL      aliceville city          41.3

# %%
dimensions = (28, 10)
fig, ax = plt.subplots(figsize=dimensions)
plt.xticks(rotation=90)
sns.violinplot(ax=ax ,data=df2_PercentagePeopleBelowPovertyLevel, x='Geographic Area', y="poverty_rate" )
# Out:
# <AxesSubplot:xlabel='Geographic Area', ylabel='poverty_rate'>

# %% [markdown]
# Anche dal confronto di questi dati con le considerazioni fatte attraverso il grafico delle uccisioni a barre si deduce che c'è una correlazione tra il tasso di povertà negli stati ed il numero di uccisioni.
#
# Osservando gli stati ad alto numero di uccisioni ( California, Colorado , Texas e Florida ) si nota che la distribuzione dei tassi di povertà è molto ampia : ciò significa che il divario retributivo tra i pù ricchi ed i più poveri è estremamente alto. Non sono però gli unici stati ad avere questa caratteristica.

# %% [markdown]
# 8.Cleaning population density dataset
# ===

# %% [markdown]
# Qui sotto viene calcolata la media della stima di densità di popolazione per stato dal 2015 al 2020 saltando le prime 5 righe del dataframe perchè contengono dati di macro aree più generiche.

# %%
with open(r'nst-est2020.csv', 'rb') as f:
    result = chardet.detect(f.read())  
    print(result)
dfPopDensity = pd.read_csv('nst-est2020.csv',encoding=result['encoding'])
dfPopDensity["NAME"]=dfPopDensity["NAME"].str.strip()
sr1_States = dfPopDensity["NAME"].iloc[5::]
sr1_PopDensity = pd.Series(((dfPopDensity["POPESTIMATE2015"].iloc[5::]+dfPopDensity["POPESTIMATE2016"].iloc[5::]+
dfPopDensity["POPESTIMATE2017"].iloc[5::]+dfPopDensity["POPESTIMATE2018"].iloc[5::]+
dfPopDensity["POPESTIMATE2019"].iloc[5::]+dfPopDensity["POPESTIMATE2020"].iloc[5::])/6), name = "Population Estimate")
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %%
dfPopDensity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SUMLEV             57 non-null     int64
#  1   REGION             57 non-null     object
#  2   DIVISION           57 non-null     object
#  3   STATE              57 non-null     int64
#  4   NAME               57 non-null     object
#  5   CENSUS2010POP      57 non-null     int64
#  6   ESTIMATESBASE2010  57 non-null     int64
#  7   POPESTIMATE2010    57 non-null     int64
#  8   POPESTIMATE2011    57 non-null     int64
#  9   POPESTIMATE2012    57 non-null     int64
#  10  POPESTIMATE2013    57 non-null     int64
#  11  POPESTIMATE2014    57 non-null     int64
#  12  POPESTIMATE2015    57 non-null     int64
#  13  POPESTIMATE2016    57 non-null     int64
#  14  POPESTIMATE2017    57 non-null     int64
#  15  POPESTIMATE2018    57 non-null     int64
#  16  POPESTIMATE2019    57 non-null     int64
#  17  POPESTIMATE042020  57 non-null     int64
#  18  POPESTIMATE2020    57 non-null     int64
# dtypes: int64(16), object(3)
# memory usage: 8.6+ KB

# %%
srStateKills = StateKillWithoutCamera+StateKillWithCamera
srStateKills.name = 'Geographic Area'
df1_PopDensity = pd.concat([sr1_States,sr1_PopDensity] ,  axis =1 )

# %%
df1_PopDensity = df1_PopDensity.drop(index = 56)

# %%
df1_PopDensity=df1_PopDensity.reset_index()

# %% [markdown]
# Qui sotto ho copiato a mano le associazioni tra nomi di stati e relative sigle perchè nel merge tra uccisioni e densità di popolazione dovrò far corrispondere gli stati USA.

# %%
df1_PopDensity.loc[0 , "Geographic Area"] = "AL"
df1_PopDensity.loc[1 , "Geographic Area"] = "AK"
df1_PopDensity.loc[2 , "Geographic Area"] = "AZ"
df1_PopDensity.loc[3 , "Geographic Area"] = "AR"
df1_PopDensity.loc[4 , "Geographic Area"] = "CA"
df1_PopDensity.loc[5 , "Geographic Area"] = "CO"
df1_PopDensity.loc[6 , "Geographic Area"] = "CT"
df1_PopDensity.loc[7 , "Geographic Area"] = "DE"
df1_PopDensity.loc[8 , "Geographic Area"] = "DC" 
df1_PopDensity.loc[9 , "Geographic Area"] = "FL"
df1_PopDensity.loc[10 , "Geographic Area"] = "GA"
df1_PopDensity.loc[11 , "Geographic Area"] = "HI"
df1_PopDensity.loc[12 , "Geographic Area"] = "ID"
df1_PopDensity.loc[13 , "Geographic Area"] = "IL"
df1_PopDensity.loc[14 , "Geographic Area"] = "IN"
df1_PopDensity.loc[15 , "Geographic Area"] = "IA"
df1_PopDensity.loc[16 , "Geographic Area"] = "KS"
df1_PopDensity.loc[17 , "Geographic Area"] = "KY"
df1_PopDensity.loc[18 , "Geographic Area"] = "LA"
df1_PopDensity.loc[19 , "Geographic Area"] = "ME"
df1_PopDensity.loc[20 , "Geographic Area"] = "MD"
df1_PopDensity.loc[21 , "Geographic Area"] = "MA"
df1_PopDensity.loc[22 , "Geographic Area"] = "MI"
df1_PopDensity.loc[23 , "Geographic Area"] = "MN"
df1_PopDensity.loc[24 , "Geographic Area"] = "MS"
df1_PopDensity.loc[25 , "Geographic Area"] = "MO"
df1_PopDensity.loc[26 , "Geographic Area"] = "MT"
df1_PopDensity.loc[27 , "Geographic Area"] = "NE"
df1_PopDensity.loc[28 , "Geographic Area"] = "NV"
df1_PopDensity.loc[29 , "Geographic Area"] = "NH"
df1_PopDensity.loc[30 , "Geographic Area"] = "NJ"
df1_PopDensity.loc[31 , "Geographic Area"] = "NM"
df1_PopDensity.loc[32 , "Geographic Area"] = "NY"
df1_PopDensity.loc[33 , "Geographic Area"] = "NC"
df1_PopDensity.loc[34 , "Geographic Area"] = "ND"
df1_PopDensity.loc[35 , "Geographic Area"] = "OH"
df1_PopDensity.loc[36 , "Geographic Area"] = "OK"
df1_PopDensity.loc[37 , "Geographic Area"] = "OR"
df1_PopDensity.loc[38 , "Geographic Area"] = "PA"
df1_PopDensity.loc[39 , "Geographic Area"] = "RI"
df1_PopDensity.loc[40 , "Geographic Area"] = "SC"
df1_PopDensity.loc[41 , "Geographic Area"] = "SD"
df1_PopDensity.loc[42 , "Geographic Area"] = "TN"
df1_PopDensity.loc[43 , "Geographic Area"] = "TX"
df1_PopDensity.loc[44 , "Geographic Area"] = "UT"
df1_PopDensity.loc[45 , "Geographic Area"] = "VA"
df1_PopDensity.loc[46 , "Geographic Area"] = "VT"
df1_PopDensity.loc[47 , "Geographic Area"] = "WA"
df1_PopDensity.loc[48 , "Geographic Area"] = "WV"
df1_PopDensity.loc[49 , "Geographic Area"] = "WI"
df1_PopDensity.loc[50 , "Geographic Area"] = "WY"

# %%
df1_PopDensity = df1_PopDensity.drop(columns="index")

# %%
srStateKills = StateKillWithoutCamera + StateKillWithCamera
dfStateKills = srStateKills.reset_index()

# %%
dfStateKills = dfStateKills.rename(columns={'body_camera': 'Kills'})
dfStateKills = dfStateKills.rename(columns={'state': 'Geographic Area'})

# %%
dfStateKills.head(5)
# Out:
#   Geographic Area  Kills
# 0              AK     45
# 1              AL    123
# 2              AR     95
# 3              AZ    298
# 4              CA    948

# %% [markdown]
# L'operazione di merge non fa altro che trovare l'intersezione tra due blocchi di dati. Questo mi dà la possibilità di poter creare delle visualizzazioni e dei grafici di correlazione più complessi rispetto ad analizzare ogni dato solo con sè stesso.

# %%
df_PopDensityAndStateKills = pd.merge(df1_PopDensity , dfStateKills , on=["Geographic Area"])

# %%
df_PopDensityAndStateKills.head(5)
# Out:
#          NAME  Population Estimate Geographic Area  Kills
# 0     Alabama         4.886790e+06              AL    123
# 1      Alaska         7.372288e+05              AK     45
# 2     Arizona         7.117190e+06              AZ    298
# 3    Arkansas         3.006512e+06              AR     95
# 4  California         3.927240e+07              CA    948

# %%
from scipy import stats

# %%
jpPopDensity = sns.jointplot(x="Kills", y="Population Estimate", kind='kde', data=df_PopDensityAndStateKills)
r, p = stats.pearsonr(df_PopDensityAndStateKills["Kills"], df_PopDensityAndStateKills["Population Estimate"])
phantom, = jpPopDensity.ax_joint.plot([], [], linestyle="", alpha=0)
jpPopDensity.ax_joint.legend([phantom],['r={:f}, p={:f}'.format(r,p)])

# %% [markdown]
# Dal grafico si evidenzia una correlazione piuttosto lineare (r molto vicino a 1) tra la densità di popolazione dello stato e le uccisioni. Si vede anche che la densità abitativa negli stati è mediamente intorno ai 5.000.000 di abitanti.
#
# Il pvalue molto piccolo esprime elevata significatività del risultato.

# %% [markdown]
# 9.Merging median household income and percentage people below poverty level data
# ===

# %%
 
df5_MedianHouseholdIncome2015 = df4_MedianHouseholdIncome2015.copy()

# %% [markdown]
# Riordino per stato e per ogni stato USA riordino per città.In questo modo se devo fare dei check in modo manuale mi viene più semplice.

# %%
df5_MedianHouseholdIncome2015 = df5_MedianHouseholdIncome2015.sort_values(["Geographic Area","City"])

# %%
df5_MedianHouseholdIncome2015.head(5)
# Out:
#     Geographic Area         City  Median Income
# 585              AK    adak city          78500
# 586              AK  akhiok city          26250
# 587              AK    akiachak           38750
# 588              AK   akiak city          42000
# 589              AK  akutan city          24750

# %%
df5_MedianHouseholdIncome2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27385 entries, 585 to 29320
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  27385 non-null  object
#  1   City             27385 non-null  object
#  2   Median Income    27385 non-null  int32
# dtypes: int32(1), object(2)
# memory usage: 748.8+ KB

# %%
df2_PercentagePeopleBelowPovertyLevel = df2_PercentagePeopleBelowPovertyLevel.sort_values(["Geographic Area","City"])

# %%
df2_PercentagePeopleBelowPovertyLevel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29128 entries, 585 to 29327
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  29128 non-null  object
#  1   City             29128 non-null  object
#  2   poverty_rate     29128 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 910.2+ KB

# %% [markdown]
# L'operazione di merge non fa altro che trovare l'intersezione tra due blocchi di dati. Questo mi dà la possibilità di poter creare delle visualizzazioni e dei grafici di correlazione più complessi rispetto ad analizzare ogni dato solo con sè stesso.

# %%
dfPercPovertyAndHouseIncome = pd.merge(df5_MedianHouseholdIncome2015, df2_PercentagePeopleBelowPovertyLevel, on=["Geographic Area", "City"])

# %%
dfPercPovertyAndHouseIncome.head(10)
# Out:
#   Geographic Area                 City  Median Income  poverty_rate
# 0              AK            adak city          78500          39.3
# 1              AK          akhiok city          26250          40.5
# 2              AK            akiachak           38750          26.1
# 3              AK           akiak city          42000          31.3
# 4              AK          akutan city          24750          16.1
# 5              AK        alakanuk city          32917          44.6
# 6              AK       aleknagik city          41875          11.6
# 7              AK       allakaket city          26500           9.1
# 8              AK          ambler city          42344          21.4
# 9              AK  anaktuvuk pass city          66250          26.3

# %%
dfPercPovertyAndHouseIncome.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27383 entries, 0 to 27382
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  27383 non-null  object
#  1   City             27383 non-null  object
#  2   Median Income    27383 non-null  int32
#  3   poverty_rate     27383 non-null  float64
# dtypes: float64(1), int32(1), object(2)
# memory usage: 962.7+ KB

# %%
df6_MedianHouseholdIncome2015 = df5_MedianHouseholdIncome2015.copy()
df6_MedianHouseholdIncome2015 = df6_MedianHouseholdIncome2015.sort_values(["Geographic Area","City"])#Riordino nuovamente a fronte di un ricampionamento di entrambi i dataframe

# %%
df6_MedianHouseholdIncome2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27385 entries, 585 to 29320
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  27385 non-null  object
#  1   City             27385 non-null  object
#  2   Median Income    27385 non-null  int32
# dtypes: int32(1), object(2)
# memory usage: 748.8+ KB

# %% [markdown]
# 10.Data cleaning on percentage over 25 that completed high school dataset
# ===

# %%
with open(r'PercentOver25CompletedHighSchool.csv', 'rb') as f:
    result = chardet.detect(f.read())  
    print(result)
dfPercentOver25CompletedHighSchool = pd.read_csv('PercentOver25CompletedHighSchool.csv',encoding=result['encoding'])
dfPercentOver25CompletedHighSchool["Geographic Area"]=dfPercentOver25CompletedHighSchool["Geographic Area"].str.strip()
dfPercentOver25CompletedHighSchool["City"]=dfPercentOver25CompletedHighSchool["City"].str.strip()
dfPercentOver25CompletedHighSchool.head(5)
# Out:
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
#   Geographic Area             City percent_completed_hs
# 0              AL       Abanda CDP                 21.2
# 1              AL   Abbeville city                 69.1
# 2              AL  Adamsville city                 78.9
# 3              AL     Addison town                 81.4
# 4              AL       Akron town                 68.6

# %%
dfPercentOver25CompletedHighSchool.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29329 entries, 0 to 29328
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Geographic Area       29329 non-null  object
#  1   City                  29329 non-null  object
#  2   percent_completed_hs  29329 non-null  object
# dtypes: object(3)
# memory usage: 687.5+ KB

# %%
df2_PercentOver25CompletedHighSchool = dfPercentOver25CompletedHighSchool.copy()
for j,item in enumerate(df2_PercentOver25CompletedHighSchool['percent_completed_hs']):
    item2 = df2_PercentOver25CompletedHighSchool['percent_completed_hs'][j].split(".")
    if not item2[0].isnumeric():
        df2_PercentOver25CompletedHighSchool.drop(index=j, inplace = True)
        print(str(j)+' :Not a number.'+ ' Value: '+item)

df2_PercentOver25CompletedHighSchool['percent_completed_hs'] = df2_PercentOver25CompletedHighSchool['percent_completed_hs'].astype(float)
df2_PercentOver25CompletedHighSchool.dtypes
# Out:
# 573 :Not a number. Value: -
# 632 :Not a number. Value: -
# 637 :Not a number. Value: -
# 662 :Not a number. Value: -
# 667 :Not a number. Value: -
# 676 :Not a number. Value: -
# 685 :Not a number. Value: -
# 711 :Not a number. Value: -
# 712 :Not a number. Value: -
# 726 :Not a number. Value: -
# 770 :Not a number. Value: -
# 784 :Not a number. Value: -
# 792 :Not a number. Value: -
# 832 :Not a number. Value: -
# 842 :Not a number. Value: -
# 843 :Not a number. Value: -
# 844 :Not a number. Value: -
# 894 :Not a number. Value: -
# 911 :Not a number. Value: -
# 932 :Not a number. Value: -
# 1096 :Not a number. Value: -
# 1113 :Not a number. Value: -
# 1151 :Not a number. Value: -
# 1184 :Not a number. Value: -
# 1263 :Not a number. Value: -
# 1329 :Not a number. Value: -
# 1376 :Not a number. Value: -
# 1953 :Not a number. Value: -
# 2023 :Not a number. Value: -
# 2141 :Not a number. Value: -
# 2167 :Not a number. Value: -
# 2472 :Not a number. Value: -
# 2504 :Not a number. Value: -
# 2656 :Not a number. Value: -
# 2696 :Not a number. Value: -
# 2864 :Not a number. Value: -
# 2965 :Not a number. Value: -
# 3076 :Not a number. Value: -
# 3202 :Not a number. Value: -
# 3235 :Not a number. Value: -
# 3251 :Not a number. Value: -
# 3256 :Not a number. Value: -
# 3257 :Not a number. Value: -
# 3319 :Not a number. Value: -
# 3328 :Not a number. Value: -
# 3337 :Not a number. Value: -
# 3351 :Not a number. Value: -
# 3424 :Not a number. Value: -
# 3493 :Not a number. Value: -
# 3539 :Not a number. Value: -
# 3618 :Not a number. Value: -
# 3652 :Not a number. Value: -
# 3754 :Not a number. Value: -
# 3905 :Not a number. Value: -
# 4547 :Not a number. Value: -
# 4621 :Not a number. Value: -
# 4775 :Not a number. Value: -
# 5236 :Not a number. Value: -
# 5335 :Not a number. Value: -
# 5605 :Not a number. Value: -
# 5864 :Not a number. Value: -
# 6047 :Not a number. Value: -
# 6360 :Not a number. Value: -
# 6476 :Not a number. Value: -
# 7089 :Not a number. Value: -
# 8131 :Not a number. Value: -
# 8168 :Not a number. Value: -
# 8700 :Not a number. Value: -
# 8705 :Not a number. Value: -
# 8898 :Not a number. Value: -
# 9138 :Not a number. Value: -
# 9319 :Not a number. Value: -
# 9928 :Not a number. Value: -
# 10747 :Not a number. Value: -
# 11079 :Not a number. Value: -
# 11106 :Not a number. Value: -
# 11644 :Not a number. Value: -
# 13699 :Not a number. Value: -
# 13729 :Not a number. Value: -
# 13974 :Not a number. Value: -
# 14024 :Not a number. Value: -
# 14064 :Not a number. Value: -
# 14173 :Not a number. Value: -
# 14181 :Not a number. Value: -
# 14396 :Not a number. Value: -
# 14570 :Not a number. Value: -
# 14768 :Not a number. Value: -
# 15039 :Not a number. Value: -
# 15398 :Not a number. Value: -
# 15479 :Not a number. Value: -
# 15607 :Not a number. Value: -
# 15708 :Not a number. Value: -
# 16280 :Not a number. Value: -
# 16400 :Not a number. Value: -
# 16449 :Not a number. Value: -
# 16532 :Not a number. Value: -
# 16543 :Not a number. Value: -
# 16582 :Not a number. Value: -
# 16584 :Not a number. Value: -
# 16618 :Not a number. Value: -
# 16645 :Not a number. Value: -
# 16663 :Not a number. Value: -
# 16724 :Not a number. Value: -
# 16805 :Not a number. Value: -
# 16828 :Not a number. Value: -
# 17911 :Not a number. Value: -
# 18269 :Not a number. Value: -
# 19063 :Not a number. Value: -
# 19441 :Not a number. Value: -
# 20354 :Not a number. Value: -
# 20554 :Not a number. Value: -
# 20602 :Not a number. Value: -
# 20715 :Not a number. Value: -
# 20724 :Not a number. Value: -
# 21162 :Not a number. Value: -
# 21237 :Not a number. Value: -
# 21413 :Not a number. Value: -
# 21914 :Not a number. Value: -
# 23445 :Not a number. Value: -
# 23742 :Not a number. Value: -
# 23772 :Not a number. Value: -
# 23798 :Not a number. Value: -
# 23858 :Not a number. Value: -
# 23873 :Not a number. Value: -
# 23895 :Not a number. Value: -
# 23968 :Not a number. Value: -
# 24560 :Not a number. Value: -
# 24616 :Not a number. Value: -
# 24648 :Not a number. Value: -
# 24714 :Not a number. Value: -
# 24881 :Not a number. Value: -
# 24980 :Not a number. Value: -
# 25050 :Not a number. Value: -
# 25133 :Not a number. Value: -
# 25190 :Not a number. Value: -
# 25237 :Not a number. Value: -
# 25312 :Not a number. Value: -
# 25313 :Not a number. Value: -
# 25376 :Not a number. Value: -
# 25380 :Not a number. Value: -
# 25385 :Not a number. Value: -
# 25436 :Not a number. Value: -
# 25442 :Not a number. Value: -
# 25445 :Not a number. Value: -
# 25456 :Not a number. Value: -
# 25464 :Not a number. Value: -
# 25468 :Not a number. Value: -
# 25516 :Not a number. Value: -
# 25606 :Not a number. Value: -
# 25652 :Not a number. Value: -
# 25674 :Not a number. Value: -
# 25693 :Not a number. Value: -
# 25795 :Not a number. Value: -
# 25804 :Not a number. Value: -
# 25810 :Not a number. Value: -
# 25816 :Not a number. Value: -
# 25865 :Not a number. Value: -
# 25961 :Not a number. Value: -
# 26071 :Not a number. Value: -
# 26083 :Not a number. Value: -
# 26103 :Not a number. Value: -
# 26158 :Not a number. Value: -
# 26159 :Not a number. Value: -
# 26294 :Not a number. Value: -
# 26301 :Not a number. Value: -
# 26307 :Not a number. Value: -
# 26323 :Not a number. Value: -
# 26386 :Not a number. Value: -
# 26452 :Not a number. Value: -
# 26483 :Not a number. Value: -
# 27467 :Not a number. Value: -
# 27481 :Not a number. Value: -
# 27548 :Not a number. Value: -
# 27579 :Not a number. Value: -
# 27617 :Not a number. Value: -
# 27643 :Not a number. Value: -
# 27660 :Not a number. Value: -
# 27682 :Not a number. Value: -
# 27990 :Not a number. Value: -
# 29128 :Not a number. Value: -
# 29133 :Not a number. Value: -
# 29151 :Not a number. Value: -
# 29152 :Not a number. Value: -
# 29160 :Not a number. Value: -
# 29171 :Not a number. Value: -
# 29193 :Not a number. Value: -
# 29198 :Not a number. Value: -
# 29220 :Not a number. Value: -
# 29224 :Not a number. Value: -
# 29227 :Not a number. Value: -
# 29238 :Not a number. Value: -
# 29244 :Not a number. Value: -
# 29261 :Not a number. Value: -
# 29266 :Not a number. Value: -
# 29273 :Not a number. Value: -
# 29289 :Not a number. Value: -
# 29304 :Not a number. Value: -
# Geographic Area          object
# City                     object
# percent_completed_hs    float64
# dtype: object

# %%
df3_PercentOver25CompletedHighSchool = df2_PercentOver25CompletedHighSchool.copy()
df3_PercentOver25CompletedHighSchool["City"] = df3_PercentOver25CompletedHighSchool["City"].str.lower()
df3_PercentOver25CompletedHighSchool["City"] = df3_PercentOver25CompletedHighSchool["City"].str.replace("cdp","")

# %%
df3_PercentOver25CompletedHighSchool = df3_PercentOver25CompletedHighSchool.sort_values(["Geographic Area","City"])

# %%
df3_PercentOver25CompletedHighSchool.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29132 entries, 585 to 29327
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Geographic Area       29132 non-null  object
#  1   City                  29132 non-null  object
#  2   percent_completed_hs  29132 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 910.4+ KB

# %%
df3_PercentOver25CompletedHighSchool.head(5)
# Out:
#     Geographic Area         City  percent_completed_hs
# 585              AK    adak city                  93.4
# 586              AK  akhiok city                  62.5
# 587              AK    akiachak                   76.7
# 588              AK   akiak city                  81.3
# 589              AK  akutan city                  73.0

# %% [markdown]
# 11.Merging people below poverty level and percent over 25 that completed highschool dataset
# ===

# %%
df3_PercentagePeopleBelowPovertyLevel = df2_PercentagePeopleBelowPovertyLevel.copy()
df3_PercentagePeopleBelowPovertyLevel = df3_PercentagePeopleBelowPovertyLevel.sort_values(["Geographic Area","City"])#Riordino nuovamente a fronte di un ricampionamento di entrambi i dataframe

# %%
df3_PercentagePeopleBelowPovertyLevel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29128 entries, 585 to 29327
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  29128 non-null  object
#  1   City             29128 non-null  object
#  2   poverty_rate     29128 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 910.2+ KB

# %%
df3_PercentagePeopleBelowPovertyLevel.head(5)
# Out:
#     Geographic Area         City  poverty_rate
# 585              AK    adak city          39.3
# 586              AK  akhiok city          40.5
# 587              AK    akiachak           26.1
# 588              AK   akiak city          31.3
# 589              AK  akutan city          16.1

# %%
dfPovertyAndCompletedHighSchool = pd.merge(df3_PercentagePeopleBelowPovertyLevel, df3_PercentOver25CompletedHighSchool, 
                                  on=["Geographic Area","City"])

# %%
dfPovertyAndCompletedHighSchool.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29125 entries, 0 to 29124
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Geographic Area       29125 non-null  object
#  1   City                  29125 non-null  object
#  2   poverty_rate          29125 non-null  float64
#  3   percent_completed_hs  29125 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 1.1+ MB

# %%
dfPovertyAndCompletedHighSchool.head(5)
# Out:
#   Geographic Area         City  poverty_rate  percent_completed_hs
# 0              AK    adak city          39.3                  93.4
# 1              AK  akhiok city          40.5                  62.5
# 2              AK    akiachak           26.1                  76.7
# 3              AK   akiak city          31.3                  81.3
# 4              AK  akutan city          16.1                  73.0

# %%
df3_PercentOver25CompletedHighSchool.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29132 entries, 585 to 29327
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Geographic Area       29132 non-null  object
#  1   City                  29132 non-null  object
#  2   percent_completed_hs  29132 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 910.4+ KB

# %% [markdown]
# 12.Data cleaning and merging People below poverty level, percent over 25 that completed highschool and median household income
# ===

# %%
df6_MedianHouseholdIncome2015.reset_index(drop=True,inplace=True)

# %%
df6_MedianHouseholdIncome2015.to_csv('df6_MedianHouseholdIncome2015.csv')
dfPovertyAndCompletedHighSchool.to_csv('dfPovertyAndCompletedHighSchool.csv')

# %%
dfPovertyAndCompletedHighSchool.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29125 entries, 0 to 29124
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Geographic Area       29125 non-null  object
#  1   City                  29125 non-null  object
#  2   poverty_rate          29125 non-null  float64
#  3   percent_completed_hs  29125 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 1.1+ MB

# %%
dfMedianIncomePovertyCompletedHighSchool = pd.merge(df6_MedianHouseholdIncome2015,dfPovertyAndCompletedHighSchool, on=["Geographic Area","City"])

# %%
dfMedianIncomePovertyCompletedHighSchool.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27383 entries, 0 to 27382
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Geographic Area       27383 non-null  object
#  1   City                  27383 non-null  object
#  2   Median Income         27383 non-null  int32
#  3   poverty_rate          27383 non-null  float64
#  4   percent_completed_hs  27383 non-null  float64
# dtypes: float64(2), int32(1), object(2)
# memory usage: 1.1+ MB

# %%
jp = sns.jointplot(x="Median Income", y="percent_completed_hs", kind='kde', data=dfMedianIncomePovertyCompletedHighSchool)
r, p = stats.pearsonr(dfMedianIncomePovertyCompletedHighSchool["Median Income"], dfMedianIncomePovertyCompletedHighSchool["percent_completed_hs"])
phantom, = jp.ax_joint.plot([], [], linestyle="", alpha=0)
jp.ax_joint.legend([phantom],['r={:f}, p={:f}'.format(r,p)])

# %% [markdown]
# Innanzi tutto le distribuzioni di dati sono entrambe right skewed.
#
# Possiamo inferire che in generale c'è una correlazione di tipo logaritmico tra la percentuale di Over 25 che ha completato le scuole superiori e l'income medio: in particolare, in media, all'aumentare dello stipendio, la percentuale di over  25 con diploma aumenta dal 50% al 90-95% tra 40000 dollari fino ai 90000 dollari. Dopo i 100000 dollari la percentuale di diplomati tende al 100% con poca variabilità.

# %%
jp1 = sns.jointplot(x="poverty_rate", y="percent_completed_hs", kind='reg', data=dfMedianIncomePovertyCompletedHighSchool)
r, p = stats.pearsonr(dfMedianIncomePovertyCompletedHighSchool["poverty_rate"], dfMedianIncomePovertyCompletedHighSchool["percent_completed_hs"])
phantom, = jp1.ax_joint.plot([], [], linestyle="", alpha=0)
jp1.ax_joint.legend([phantom],['r={:f}, p={:f}'.format(r,p)])

# %% [markdown]
# Anche in questo caso le distribuzioni di dati sono entrambe right skewed ed il poverty rate in particolare ha una andamento con una deviazione standard abbastanza ampia.
#
# C'è una correlazione lineare diretta tra il tasso di povertà e la percentuale di over 25 diplomata ed è inversamente lineare. La tendenza è tale per cui all'aumentare del tasso di povertà la percentuale di diplomati diminuisce.

# %% [markdown]
# 13.Data cleaning on shared race by city and merging with the main dataframe
# ===

# %% [markdown]
# L'obiettivo, in questa sezione, è quello di unire tutti i file csv in un unico dataframe con dati presenti in ogni riga in modo da poter studiare diverse correlazioni.

# %%
ShareRaceByCity = pd.read_csv('ShareRaceByCity.csv')
ShareRaceByCity["Geographic area"]=ShareRaceByCity["Geographic area"].str.strip()
ShareRaceByCity["City"]=ShareRaceByCity["City"].str.strip()
ShareRaceByCity.head(5)
# Out:
#   Geographic area             City share_white share_black  \
# 0              AL       Abanda CDP        67.2        30.2
# 1              AL   Abbeville city        54.4        41.4
# 2              AL  Adamsville city        52.3        44.9
# 3              AL     Addison town        99.1         0.1
# 4              AL       Akron town        13.2        86.5
#
#   share_native_american share_asian share_hispanic
# 0                     0           0            1.6
# 1                   0.1           1            3.1
# 2                   0.5         0.3            2.3
# 3                     0         0.1            0.4
# 4                     0           0            0.3

# %% [markdown]
# .

# %%
ShareRaceByCity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29268 entries, 0 to 29267
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Geographic area        29268 non-null  object
#  1   City                   29268 non-null  object
#  2   share_white            29268 non-null  object
#  3   share_black            29268 non-null  object
#  4   share_native_american  29268 non-null  object
#  5   share_asian            29268 non-null  object
#  6   share_hispanic         29268 non-null  object
# dtypes: object(7)
# memory usage: 1.6+ MB

# %% [markdown]
# Per ogni colonna che identifica una razza eseguo una pulizia dei dati e li trasformo da python objects a float

# %%
df2_ShareRaceByCity = ShareRaceByCity.copy()
for j,item in enumerate(df2_ShareRaceByCity['share_white']):
    #if not item.isnumeric(): 
        item2 = df2_ShareRaceByCity['share_white'][j].split(".")
        if not item2[0].isnumeric():
            df2_ShareRaceByCity['share_white'][j]= '0' 
            print(str(j)+' :Not a number.'+ ' Value: '+item2[0])
         
for j,item in enumerate(df2_ShareRaceByCity['share_black']):
    #if not item.isnumeric():  
        item2 = df2_ShareRaceByCity['share_black'][j].split(".")
        if not item2[0].isnumeric():
            df2_ShareRaceByCity['share_black'][j]= '0' 
            print(str(j)+' :Not a number.'+ ' Value: '+item2[0])
            
for j,item in enumerate(df2_ShareRaceByCity['share_native_american']):
    #if not item.isnumeric(): 
        item2 = df2_ShareRaceByCity['share_native_american'][j].split(".")
        if not item2[0].isnumeric():
            df2_ShareRaceByCity['share_native_american'][j]= '0' 
            print(str(j)+' :Not a number.'+ ' Value: '+item2[0])
            
for j,item in enumerate(df2_ShareRaceByCity['share_asian']):
    #if not item.isnumeric(): 
        item2 = df2_ShareRaceByCity['share_asian'][j].split(".")
        if not item2[0].isnumeric():
            df2_ShareRaceByCity['share_asian'][j]= '0' 
            print(str(j)+' :Not a number.'+ ' Value: '+item2[0])
            
for j,item in enumerate(df2_ShareRaceByCity['share_hispanic']):
    #if not item.isnumeric(): 
        item2 = df2_ShareRaceByCity['share_hispanic'][j].split(".")
        if not item2[0].isnumeric():
            df2_ShareRaceByCity['share_hispanic'][j]= '0' 
            print(str(j)+' :Not a number.'+ ' Value: '+item2[0])
df2_ShareRaceByCity['share_white'] = df2_ShareRaceByCity['share_white'].astype(float)
df2_ShareRaceByCity['share_black'] = df2_ShareRaceByCity['share_black'].astype(float)
df2_ShareRaceByCity['share_native_american'] = df2_ShareRaceByCity['share_native_american'].astype(float)
df2_ShareRaceByCity['share_asian'] = df2_ShareRaceByCity['share_asian'].astype(float)
df2_ShareRaceByCity['share_hispanic'] = df2_ShareRaceByCity['share_hispanic'].astype(float)
df2_ShareRaceByCity.dtypes
# Out:
# 630 :Not a number. Value: (X)
# 678 :Not a number. Value: (X)
# 777 :Not a number. Value: (X)
# 1946 :Not a number. Value: (X)
# 2134 :Not a number. Value: (X)
# 2160 :Not a number. Value: (X)
# 3194 :Not a number. Value: (X)
# 3248 :Not a number. Value: (X)
# 3331 :Not a number. Value: (X)
# 3345 :Not a number. Value: (X)
# 11621 :Not a number. Value: (X)
# 13953 :Not a number. Value: (X)
# 14003 :Not a number. Value: (X)
# 14151 :Not a number. Value: (X)
# 21217 :Not a number. Value: (X)
# 25324 :Not a number. Value: (X)
# 25744 :Not a number. Value: (X)
# 26107 :Not a number. Value: (X)
# 26108 :Not a number. Value: (X)
# 29243 :Not a number. Value: (X)
# 630 :Not a number. Value: (X)
# 678 :Not a number. Value: (X)
# 777 :Not a number. Value: (X)
# 1946 :Not a number. Value: (X)
# 2134 :Not a number. Value: (X)
# 2160 :Not a number. Value: (X)
# 3194 :Not a number. Value: (X)
# 3248 :Not a number. Value: (X)
# 3331 :Not a number. Value: (X)
# 3345 :Not a number. Value: (X)
# 11621 :Not a number. Value: (X)
# 13953 :Not a number. Value: (X)
# 14003 :Not a number. Value: (X)
# 14151 :Not a number. Value: (X)
# 21217 :Not a number. Value: (X)
# 25324 :Not a number. Value: (X)
# 25744 :Not a number. Value: (X)
# 26107 :Not a number. Value: (X)
# 26108 :Not a number. Value: (X)
# 29243 :Not a number. Value: (X)
# 630 :Not a number. Value: (X)
# 678 :Not a number. Value: (X)
# 777 :Not a number. Value: (X)
# 1946 :Not a number. Value: (X)
# 2134 :Not a number. Value: (X)
# 2160 :Not a number. Value: (X)
# 3194 :Not a number. Value: (X)
# 3248 :Not a number. Value: (X)
# 3331 :Not a number. Value: (X)
# 3345 :Not a number. Value: (X)
# 11621 :Not a number. Value: (X)
# 13953 :Not a number. Value: (X)
# 14003 :Not a number. Value: (X)
# 14151 :Not a number. Value: (X)
# 21217 :Not a number. Value: (X)
# 25324 :Not a number. Value: (X)
# 25744 :Not a number. Value: (X)
# 26107 :Not a number. Value: (X)
# 26108 :Not a number. Value: (X)
# 29243 :Not a number. Value: (X)
# 630 :Not a number. Value: (X)
# 678 :Not a number. Value: (X)
# 777 :Not a number. Value: (X)
# 1946 :Not a number. Value: (X)
# 2134 :Not a number. Value: (X)
# 2160 :Not a number. Value: (X)
# 3194 :Not a number. Value: (X)
# 3248 :Not a number. Value: (X)
# 3331 :Not a number. Value: (X)
# 3345 :Not a number. Value: (X)
# 11621 :Not a number. Value: (X)
# 13953 :Not a number. Value: (X)
# 14003 :Not a number. Value: (X)
# 14151 :Not a number. Value: (X)
# 21217 :Not a number. Value: (X)
# 25324 :Not a number. Value: (X)
# 25744 :Not a number. Value: (X)
# 26107 :Not a number. Value: (X)
# 26108 :Not a number. Value: (X)
# 29243 :Not a number. Value: (X)
# 630 :Not a number. Value: (X)
# 678 :Not a number. Value: (X)
# 777 :Not a number. Value: (X)
# 1946 :Not a number. Value: (X)
# 2134 :Not a number. Value: (X)
# 2160 :Not a number. Value: (X)
# 3194 :Not a number. Value: (X)
# 3248 :Not a number. Value: (X)
# 3331 :Not a number. Value: (X)
# 3345 :Not a number. Value: (X)
# 11621 :Not a number. Value: (X)
# 13953 :Not a number. Value: (X)
# 14003 :Not a number. Value: (X)
# 14151 :Not a number. Value: (X)
# 21217 :Not a number. Value: (X)
# 25324 :Not a number. Value: (X)
# 25744 :Not a number. Value: (X)
# 26107 :Not a number. Value: (X)
# 26108 :Not a number. Value: (X)
# 29243 :Not a number. Value: (X)
# Geographic area           object
# City                      object
# share_white              float64
# share_black              float64
# share_native_american    float64
# share_asian              float64
# share_hispanic           float64
# dtype: object

# %%
df2_ShareRaceByCity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29268 entries, 0 to 29267
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Geographic area        29268 non-null  object
#  1   City                   29268 non-null  object
#  2   share_white            29268 non-null  float64
#  3   share_black            29268 non-null  float64
#  4   share_native_american  29268 non-null  float64
#  5   share_asian            29268 non-null  float64
#  6   share_hispanic         29268 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 1.6+ MB

# %%
df2_ShareRaceByCity.head(5)
# Out:
#   Geographic area             City  share_white  share_black  \
# 0              AL       Abanda CDP         67.2         30.2
# 1              AL   Abbeville city         54.4         41.4
# 2              AL  Adamsville city         52.3         44.9
# 3              AL     Addison town         99.1          0.1
# 4              AL       Akron town         13.2         86.5
#
#    share_native_american  share_asian  share_hispanic
# 0                    0.0          0.0             1.6
# 1                    0.1          1.0             3.1
# 2                    0.5          0.3             2.3
# 3                    0.0          0.1             0.4
# 4                    0.0          0.0             0.3

# %% [markdown]
# Porto tutto in lower case e tolgo tag CDP per uniformare tutti i nomi di città dei data frame dei diversi csv in modo da non perdere erroneamente dati a seguito del merge.

# %%
df3_ShareRaceByCity = df2_ShareRaceByCity.copy()
df3_ShareRaceByCity["City"] = df3_ShareRaceByCity["City"].str.lower()
df3_ShareRaceByCity["City"] = df3_ShareRaceByCity["City"].str.replace("cdp","")

# %%
df3_ShareRaceByCity.head(5)
# Out:
#   Geographic area             City  share_white  share_black  \
# 0              AL          abanda          67.2         30.2
# 1              AL   abbeville city         54.4         41.4
# 2              AL  adamsville city         52.3         44.9
# 3              AL     addison town         99.1          0.1
# 4              AL       akron town         13.2         86.5
#
#    share_native_american  share_asian  share_hispanic
# 0                    0.0          0.0             1.6
# 1                    0.1          1.0             3.1
# 2                    0.5          0.3             2.3
# 3                    0.0          0.1             0.4
# 4                    0.0          0.0             0.3

# %%
df4_ShareRaceByCity  = df3_ShareRaceByCity.rename(columns={'Geographic area': 'Geographic Area'})

# %%
df4_ShareRaceByCity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29268 entries, 0 to 29267
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Geographic Area        29268 non-null  object
#  1   City                   29268 non-null  object
#  2   share_white            29268 non-null  float64
#  3   share_black            29268 non-null  float64
#  4   share_native_american  29268 non-null  float64
#  5   share_asian            29268 non-null  float64
#  6   share_hispanic         29268 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 1.6+ MB

# %%
df4_ShareRaceByCity.to_csv('df4_ShareRaceByCity.csv')
dfMedianIncomePovertyCompletedHighSchool.to_csv('dfMedianIncomePovertyCompletedHighSchool.csv')

# %%
dfTotal3 = pd.merge(df4_ShareRaceByCity,dfMedianIncomePovertyCompletedHighSchool, on=["Geographic Area","City"])

# %%
dfTotal3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27210 entries, 0 to 27209
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Geographic Area        27210 non-null  object
#  1   City                   27210 non-null  object
#  2   share_white            27210 non-null  float64
#  3   share_black            27210 non-null  float64
#  4   share_native_american  27210 non-null  float64
#  5   share_asian            27210 non-null  float64
#  6   share_hispanic         27210 non-null  float64
#  7   Median Income          27210 non-null  int32
#  8   poverty_rate           27210 non-null  float64
#  9   percent_completed_hs   27210 non-null  float64
# dtypes: float64(7), int32(1), object(2)
# memory usage: 2.2+ MB

# %% [markdown]
# 14.Merging killing dataset with the main dataframe
# ===

# %%
df4["manner_of_death"]=df4["manner_of_death"].str.strip()
df4["armed"]=df4["armed"].str.strip()
df4["gender"]=df4["gender"].str.strip()
df4["race"]=df4["race"].str.strip()
df4["city"]=df4["city"].str.strip()
df4["state"]=df4["state"].str.strip()
df4["threat_level"]=df4["threat_level"].str.strip()
df4["flee"]=df4["flee"].str.strip()

# %% [markdown]
# Ora devo convertire il dataframe che contiene le uccisioni in sequenza temporale in più colonne che contengono le uccisioni suddivise per razza e per città e stato. In tal modo potrò fare un merge di queste informazioni con quelle dei precedenti dataframe sull'income , percentuale di over 25 che hanno completato le superiori, tasso di povertà etc..

# %%
dfRaceGroupA = df4.groupby(["state",'city'], sort=True)["race"].apply(lambda x: x[x == 'A'].count())
df1_RaceGroupA = dfRaceGroupA.rename('A')
dfRaceGroupB = df4.groupby(["state",'city'], sort=True)["race"].apply(lambda x: x[x == 'B'].count())
df1_RaceGroupB = dfRaceGroupB.rename('B')
dfRaceGroupH = df4.groupby(["state",'city'], sort=True)["race"].apply(lambda x: x[x == 'H'].count())
df1_RaceGroupH = dfRaceGroupH.rename('H')
dfRaceGroupN = df4.groupby(["state",'city'], sort=True)["race"].apply(lambda x: x[x == 'N'].count())
df1_RaceGroupN = dfRaceGroupN.rename('N')
dfRaceGroupO = df4.groupby(["state",'city'], sort=True)["race"].apply(lambda x: x[x == 'O'].count())
df1_RaceGroupO = dfRaceGroupO.rename('O')
dfRaceGroupW = df4.groupby(["state",'city'], sort=True)["race"].apply(lambda x: x[x == 'W'].count())
df1_RaceGroupW = dfRaceGroupW.rename('W')

# %%
dfRaceMannerOfDeath_1 = df4.groupby(["state",'city'], sort=True)["manner_of_death"].apply(lambda x: x[x == 'shot'].count())
dfRaceMannerOfDeath_2 = df4.groupby(["state",'city'], sort=True)["manner_of_death"].apply(lambda x: x[x == 'shot and Tasered'].count())

# %%
dfRaceMannerOfDeath_2
# Out:
# state  city
# AK     Anchor Point     0
#        Anchorage        0
#        Barrow           0
#        Big Lake         0
#        Copper Center    0
#                        ..
# WY     Douglas          0
#        Gillette         1
#        Laramie          0
#        Rawlins          0
#        Riverton         0
# Name: manner_of_death, Length: 3156, dtype: int64

# %%
dfRaceThreatLevel_Attack = df4.groupby(["state",'city'], sort=True)["threat_level"].apply(lambda x: x[x == 'attack'].count())
dfRaceThreatLevel_Other = df4.groupby(["state",'city'], sort=True)["threat_level"].apply(lambda x: x[x == 'other'].count())

# %%
dfRaceThreatLevel_Attack
# Out:
# state  city
# AK     Anchor Point     1
#        Anchorage        8
#        Barrow           1
#        Big Lake         1
#        Copper Center    0
#                        ..
# WY     Douglas          1
#        Gillette         1
#        Laramie          0
#        Rawlins          0
#        Riverton         1
# Name: threat_level, Length: 3156, dtype: int64

# %%
dfRaceThreatLevel_Attack
dfRaceThreatLevel_Attack_1 = dfRaceThreatLevel_Attack.rename('Threat attack')

# %%
df4["armed"]=df4["armed"].str.strip()
dfRaceArmed2 = df4.groupby(["armed"], sort=True).sum()

# %%
dfRaceArmed2.to_csv("dfRaceArmed2.csv")

# %%
dfRaceArmed2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 98 entries, Airsoft pistol to wrench
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       98 non-null     int64
#  1   age                      98 non-null     float64
#  2   signs_of_mental_illness  98 non-null     int64
#  3   body_camera              98 non-null     int64
#  4   longitude                98 non-null     float64
#  5   latitude                 98 non-null     float64
#  6   is_geocoding_exact       98 non-null     int64
#  7   Counter                  98 non-null     float64
# dtypes: float64(4), int64(4)
# memory usage: 6.9+ KB

# %%
dfRaceArmed2.head(5)
# Out:
#                         id     age  signs_of_mental_illness  body_camera  \
# armed
# Airsoft pistol       17356   122.0                        0            1
# BB gun               58421   477.0                        7            2
# BB gun and vehicle    5074    32.0                        0            0
# Taser               115382  1086.0                        4            8
# air conditioner       2209    41.0                        0            0
#
#                     longitude  latitude  is_geocoding_exact  Counter
# armed
# Airsoft pistol       -345.866   114.875                   3      3.0
# BB gun              -1185.296   490.123                  12     12.0
# BB gun and vehicle    -87.798    41.704                   1      1.0
# Taser               -2871.866  1064.859                  31     31.0
# air conditioner       -92.986    43.659                   1      1.0

# %% [markdown]
# 15.Economic and killing inference by race
# ===

# %% [markdown]
# Raggruppo le coordinate raccolte nel tempo facendone la media per città

# %%
dfLongitude = df4.dropna().groupby(["state",'city'], sort=True)["longitude"].apply(lambda x: x.mean())

# %%
dfLongitude
# Out:
# state  city
# AK     Anchorage     -149.851333
#        Barrow        -156.738000
#        Eagle River   -149.558000
#        Fairbanks     -147.734889
#        Houston       -149.778000
#                          ...
# WY     Cheyenne      -104.797000
#        Douglas       -105.385500
#        Gillette      -105.469000
#        Laramie       -105.752000
#        Riverton      -108.378000
# Name: longitude, Length: 2501, dtype: float64

# %%
dfLatitude = df4.dropna().groupby(["state",'city'], sort=True)["latitude"].apply(lambda x: x.mean())

# %% [markdown]
# Unisco tutte le colonne rielaborate del dataframe temporale

# %%
dfRaceGroup = pd.concat([df1_RaceGroupA, df1_RaceGroupB , df1_RaceGroupH, df1_RaceGroupN, df1_RaceGroupO, df1_RaceGroupW, dfRaceThreatLevel_Attack_1, dfLongitude, dfLatitude], axis=1)

# %%
dfRaceGroup.head()
# Out:
#                      A  B  H  N  O  W  Threat attack   longitude   latitude
# state city
# AK    Anchor Point   0  0  0  0  0  1              1         NaN        NaN
#       Anchorage      1  1  0  1  0  6              8 -149.851333  61.212111
#       Barrow         0  0  0  1  0  0              1 -156.738000  71.301000
#       Big Lake       0  1  0  0  0  0              1         NaN        NaN
#       Copper Center  1  0  0  0  0  0              0         NaN        NaN

# %%
df1_RaceGroup = dfRaceGroup.reset_index()

# %%
df2_RaceGroup = df1_RaceGroup.rename(columns={'city':'City'}) 
df2_RaceGroup = df2_RaceGroup.rename(columns={'state':'Geographic Area'})

# %%
df2_RaceGroup["City"] = df2_RaceGroup["City"].str.replace("cdp","")

# %%
df2_RaceGroup["City"] = df2_RaceGroup["City"].str.lower()
df2_RaceGroup.head()
# Out:
#   Geographic Area           City  A  B  H  N  O  W  Threat attack   longitude  \
# 0              AK   anchor point  0  0  0  0  0  1              1         NaN
# 1              AK      anchorage  1  1  0  1  0  6              8 -149.851333
# 2              AK         barrow  0  0  0  1  0  0              1 -156.738000
# 3              AK       big lake  0  1  0  0  0  0              1         NaN
# 4              AK  copper center  1  0  0  0  0  0              0         NaN
#
#     latitude
# 0        NaN
# 1  61.212111
# 2  71.301000
# 3        NaN
# 4        NaN

# %%
df2_RaceGroup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3156 entries, 0 to 3155
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  3156 non-null   object
#  1   City             3156 non-null   object
#  2   A                3156 non-null   int64
#  3   B                3156 non-null   int64
#  4   H                3156 non-null   int64
#  5   N                3156 non-null   int64
#  6   O                3156 non-null   int64
#  7   W                3156 non-null   int64
#  8   Threat attack    3156 non-null   int64
#  9   longitude        2501 non-null   float64
#  10  latitude         2501 non-null   float64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 271.3+ KB

# %%
dfTotal3["City"]=dfTotal3["City"].str.replace("city","")
dfTotal3["City"]=dfTotal3["City"].str.strip()
df2_RaceGroup["City"]= df2_RaceGroup["City"].str.strip()

# %%
df2_RaceGroup = df2_RaceGroup.sort_values(["Geographic Area","City"])
dfTotal3=dfTotal3.sort_values(["Geographic Area","City"])

# %%
df2_RaceGroup.head()
# Out:
#   Geographic Area           City  A  B  H  N  O  W  Threat attack   longitude  \
# 0              AK   anchor point  0  0  0  0  0  1              1         NaN
# 1              AK      anchorage  1  1  0  1  0  6              8 -149.851333
# 2              AK         barrow  0  0  0  1  0  0              1 -156.738000
# 3              AK       big lake  0  1  0  0  0  0              1         NaN
# 4              AK  copper center  1  0  0  0  0  0              0         NaN
#
#     latitude
# 0        NaN
# 1  61.212111
# 2  71.301000
# 3        NaN
# 4        NaN

# %%
dfTotal3.head()
# Out:
#     Geographic Area      City  share_white  share_black  \
# 539              AK      adak         19.6          4.0
# 540              AK    akhiok          8.5          1.4
# 541              AK  akiachak          3.5          0.2
# 542              AK     akiak          5.2          0.0
# 543              AK    akutan         23.3         17.9
#
#      share_native_american  share_asian  share_hispanic  Median Income  \
# 539                    5.5         52.5             8.9          78500
# 540                   50.7          1.4            11.3          26250
# 541                   95.1          0.2             0.2          38750
# 542                   92.8          0.0             0.3          42000
# 543                    5.5         43.3            20.8          24750
#
#      poverty_rate  percent_completed_hs
# 539          39.3                  93.4
# 540          40.5                  62.5
# 541          26.1                  76.7
# 542          31.3                  81.3
# 543          16.1                  73.0

# %%
df2_RaceGroup.to_csv('df2_RaceGroup.csv')
dfTotal4 = dfTotal3.copy()
dfTotal4 = dfTotal4.reset_index()
dfTotal4.to_csv('dfTotal4.csv')

# %%
dfTotal5 = pd.merge(dfTotal4, df2_RaceGroup, on=["Geographic Area","City"] )

# %%
dfTotal5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2031 entries, 0 to 2030
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   index                  2031 non-null   int64
#  1   Geographic Area        2031 non-null   object
#  2   City                   2031 non-null   object
#  3   share_white            2031 non-null   float64
#  4   share_black            2031 non-null   float64
#  5   share_native_american  2031 non-null   float64
#  6   share_asian            2031 non-null   float64
#  7   share_hispanic         2031 non-null   float64
#  8   Median Income          2031 non-null   int32
#  9   poverty_rate           2031 non-null   float64
#  10  percent_completed_hs   2031 non-null   float64
#  11  A                      2031 non-null   int64
#  12  B                      2031 non-null   int64
#  13  H                      2031 non-null   int64
#  14  N                      2031 non-null   int64
#  15  O                      2031 non-null   int64
#  16  W                      2031 non-null   int64
#  17  Threat attack          2031 non-null   int64
#  18  longitude              1670 non-null   float64
#  19  latitude               1670 non-null   float64
# dtypes: float64(9), int32(1), int64(8), object(2)
# memory usage: 325.3+ KB

# %%
#fg2 = sns.FacetGrid(dfKillsCompleted, col="Geographic Area").map(plt.scatter,"share_white", "poverty_rate", alpha=0.5).add_legend()

# %%
dfTotal5.to_csv('dfTotal5.csv')

# %% [markdown]
# 15.1White people
# ---

# %%
dfTotal_W = dfTotal5.copy()
for j,item in enumerate(dfTotal_W['W']):
    if item == 0  :
        dfTotal_W.drop(index=j, inplace = True) 

df_byGeoArea_W = dfTotal_W.groupby(["Geographic Area"], sort=True)["W"].sum()
df_byGeoArea_W_1 = df_byGeoArea_W.copy()
df_byGeoArea_W_2 = df_byGeoArea_W_1.reset_index()

# %%
jpWhite = sns.jointplot(x="W", y="share_white", kind='scatter', data=dfTotal_W)
for index,(i,j) in enumerate(zip(dfTotal_W["W"],dfTotal_W["share_white"])):
    if dfTotal_W["W"].iloc[index]> 8 :
        jpWhite.ax_joint.annotate(str(dfTotal_W["Geographic Area"].iloc[index]), xy=(i,j))
jpWhite.set_axis_labels(xlabel='White people kills', ylabel='Share white people', size=13)
r, p = stats.pearsonr(dfTotal_W["W"], dfTotal_W["share_white"])
phantom, = jpWhite.ax_joint.plot([], [], linestyle="", alpha=0)
jpWhite.ax_joint.legend([phantom],['r={:f}, p={:f}'.format(r,p)])

# %% [markdown]
# Da questa combinazione di distribuzioni si evince che:
#
#  <ul>
#   <li>la distribuzione di bianchi è molto varia nei vari stati degli USA</li>
#   <li>la deviazione standard della distribuzione di uccisioni per città è ridotta infatti la curva è decisamente assottigliata
#     Ciò significa che la quantità di uccisioni per città è mediamente la stessa.</li>
#   <li>Il numero di uccisioni di razza bianca è più alto in una fascia percentuale di presenza in uno stato che è compresa
#     tra il 60% e il 90%</li>
# </ul>

# %%
jpWhite2 = sns.jointplot(x="share_white", y="poverty_rate", kind='reg', data=dfTotal_W)
jpWhite2.set_axis_labels(xlabel='Share white people', ylabel='Poverty rate by state', size=13)
r, p = stats.pearsonr(dfTotal_W["share_white"], dfTotal_W["poverty_rate"])
phantom, = jpWhite2.ax_joint.plot([], [], linestyle="", alpha=0)
jpWhite2.ax_joint.legend([phantom],['r={:f}, p={:f}'.format(r,p)])

# %% [markdown]
# Dal grafico sopra invece si nota:
# <ul>
#   <li>una correlazione debolmente lineare tra il tasso di povertà che include tutte le razze e la quantità di bianchi.</li>
#   <li>una tendenza a deviare dalla linearità man mano che la presenza dei bianchi si avvicina al 100%: quel che accade è che il tasso di povertà tra bianchi diminuisce quando la presenza dei bianchi è maggiore.</li>
# </ul>

# %%
jpWhite3 = sns.jointplot(x="share_white", y="percent_completed_hs", kind='reg', data=dfTotal_W)
jpWhite3.set_axis_labels(xlabel='Share white people', ylabel='Percentage of over 25 that completed HS', size=13)
r, p = stats.pearsonr(dfTotal_W["share_white"], dfTotal_W["percent_completed_hs"])
phantom, = jpWhite3.ax_joint.plot([], [], linestyle="", alpha=0)
jpWhite3.ax_joint.legend([phantom],['r={:f}, p={:f}'.format(r,p)])

# %% [markdown]
# Qui sopra vediamo una tendenza lievemente lineare nella correlazione tra la presenza di razza bianca e percentuale di over 25 che hanno completato la scuola. Anche in questo confronto notiamo che le distribuzioni sono right skewed per le ascisse e left skewed per le ordinate. Queste code vanno a indebolire la linearità della correlazione al diminuire della presenza dei bianchi. La percentuale di over 25 diplomati infatti copre tutte le razze.

# %%
jpWhite4 = sns.jointplot(x="W", y="Median Income", kind='scatter', data=dfTotal_W)
for index,(i,j) in enumerate(zip(dfTotal_W["W"],dfTotal_W["Median Income"])):
    if dfTotal_W["W"].iloc[index]> 9 :
        jpWhite4.ax_joint.annotate(str(dfTotal_W["Geographic Area"].iloc[index]), xy=(i,j))
jpWhite4.set_axis_labels(xlabel='White people kills by police', ylabel='Median Income by State', size=13)
r, p = stats.pearsonr(dfTotal_W["W"], dfTotal_W["Median Income"])
phantom, = jpWhite4.ax_joint.plot([], [], linestyle="", alpha=0)
jpWhite4.ax_joint.legend([phantom],['r={:f}, p={:f}'.format(r,p)])

# %% [markdown]
# Dal grafico si vede che la dipendenza tra lo stipendio medio e le uccisioni è bassa eccetto in una fascia intorno ai 50000 dollari.

# %% [markdown]
# 15.2Black people
# ---

# %%
dfTotal_B = dfTotal5.copy()
for j,item in enumerate(dfTotal_B['B']):
    if item == 0  :
        dfTotal_B.drop(index=j, inplace = True) 
df_byGeoArea_B = dfTotal_B.groupby(["Geographic Area"], sort=True)["B"].sum()
df_byGeoArea_B_1 = df_byGeoArea_B.copy()
df_byGeoArea_B_2 = df_byGeoArea_B_1.reset_index()

# %%
jpBlack = sns.jointplot(x="B", y="share_black", kind='scatter', data=dfTotal_B)
for index,(i,j) in enumerate(zip(dfTotal_B["B"],dfTotal_B["share_black"])):
    if dfTotal_B["B"].iloc[index]> 8 :
        jpBlack.ax_joint.annotate(str(dfTotal_B["Geographic Area"].iloc[index]), xy=(i,j))
jpBlack.set_axis_labels(xlabel='Black people kills', ylabel='Share black people', size=13)
r, p = stats.pearsonr(dfTotal_B["B"], dfTotal_B["share_black"])
phantom, = jpBlack.ax_joint.plot([], [], linestyle="", alpha=0)
jpBlack.ax_joint.legend([phantom],['r={:f}, p={:f}'.format(r,p)])

# %% [markdown]
# <ul>
#   <li>Le uccisioni sono in media poco correlate alla percentuale di popolazione nera ( r = 0.122) </li>
#   <li>Rispetto alla popolazione bianca quando la percentuale di popolazione nera è compresa tra il 10% e il 65% il numero di uccisioni è puntualmente più alto in alcune città. </li>
#   <li>Gli stati con picchi più alti sono California , Texas e Florida come ci si può aspettare. Picchi inaspettati sono in Illinois , Arizona , Ohio , Georgia</li>
# </ul>

# %%
jpBlack2 = sns.jointplot(x="share_black", y="poverty_rate", kind='reg', data=dfTotal_B)
jpBlack2.set_axis_labels(xlabel='Share black people', ylabel='Poverty rate by state', size=13)
r, p = stats.pearsonr(dfTotal_B["share_black"], dfTotal_B["poverty_rate"])
phantom, = jpBlack2.ax_joint.plot([], [], linestyle="", alpha=0)
jpBlack2.ax_joint.legend([phantom],['r={:f}, p={:f}'.format(r,p)])

# %% [markdown]
# Qui si vede la relazione pressochè lineare tra la percentuale di povertà e quella di popolazione nera. La pendenza è esattamente opposta rispetto a quella del grafico della razza bianca

# %%
jpBlack3 = sns.jointplot(x="share_black", y="percent_completed_hs", kind='reg', data=dfTotal_B)
jpBlack3.set_axis_labels(xlabel='Share black people', ylabel='Percentage of over 25 that completed HS', size=13)
r, p = stats.pearsonr(dfTotal_B["share_black"], dfTotal_B["percent_completed_hs"])
phantom, = jpBlack3.ax_joint.plot([], [], linestyle="", alpha=0)
jpBlack3.ax_joint.legend([phantom],['r={:f}, p={:f}'.format(r,p)])

# %% [markdown]
# Comparando ciò che abbiamo ottenuto rispetto al medesimo grafico  ma per la popolazione bianca si denota una linearità inversa e divergente per percentuale di razza nera molto bassa.

# %%
jpBlack4 = sns.jointplot(x="B", y="Median Income", kind='scatter', data=dfTotal_B)
for index,(i,j) in enumerate(zip(dfTotal_B["B"],dfTotal_B["Median Income"])):
    if dfTotal_B["B"].iloc[index]> 9 :
        jpBlack4.ax_joint.annotate(str(dfTotal_B["Geographic Area"].iloc[index]), xy=(i,j))
jpBlack4.set_axis_labels(xlabel='Black people kills by police', ylabel='Median Income by State', size=13)
r, p = stats.pearsonr(dfTotal_B["B"], dfTotal_B["Median Income"])
phantom, = jpBlack4.ax_joint.plot([], [], linestyle="", alpha=0)
jpBlack4.ax_joint.legend([phantom],['r={:f}, p={:f}'.format(r,p)])

# %% [markdown]
# Sempre confrontando questa tipologia di grafico con quella per la razza bianca ci accorgiamo che un fenomeno simile accade anche per la razza nera: intorno ai 40000 dollari di stipendio il numero di uccisioni aumenta. Per i bianchi questo accadeva intorno ai 50000 dollari.
#
# La correlazione è irrilevante.

# %% [markdown]
# 15.3Hispanic people
# ---

# %%
dfTotal_H = dfTotal5.copy()
for j,item in enumerate(dfTotal_H['H']):
    if item == 0  :
        dfTotal_H.drop(index=j, inplace = True)
df_byGeoArea_H = dfTotal_H.groupby(["Geographic Area"], sort=True)["H"].sum()
df_byGeoArea_H_1 = df_byGeoArea_H.copy()
df_byGeoArea_H_2 = df_byGeoArea_H_1.reset_index()

#plt.ylim(-1, 6)

# %%
jpHispanic = sns.jointplot(x="H", y="share_hispanic", kind='scatter', data=dfTotal_H)
for index,(i,j) in enumerate(zip(dfTotal_H["H"],dfTotal_H["share_hispanic"])):
    if dfTotal_H["H"].iloc[index]> 8 :
        jpHispanic.ax_joint.annotate(str(dfTotal_H["Geographic Area"].iloc[index]), xy=(i,j))
jpHispanic.set_axis_labels(xlabel='Hispanic people kills', ylabel='Share hispanic people', size=13)
r, p = stats.pearsonr(dfTotal_H["H"], dfTotal_H["share_hispanic"])
phantom, = jpHispanic.ax_joint.plot([], [], linestyle="", alpha=0)
jpHispanic.ax_joint.legend([phantom],['r={:f}, p={:f}'.format(r,p)])

# %% [markdown]
# Per la razza ispanica il numero di uccisioni è piuttosto invariante rispetto alla percentuale di popolazione ispanica. C' è una deviazione tra il 30% e il 60% con picchi considerevoli di uccisioni in alcuni stati : California  , Texas , Arizona , New Mexico. I primi due sono abbastanza scontati dato che nella classifica delle uccisioni per stato sono tra i primi tre

# %%
jpHispanic2 = sns.jointplot(x="H", y="poverty_rate", kind='scatter', data=dfTotal_H)
for index,(i,j) in enumerate(zip(dfTotal_H["H"],dfTotal_H["poverty_rate"])):
    if dfTotal_H["H"].iloc[index]> 5 :
        jpHispanic2.ax_joint.annotate(str(dfTotal_H["Geographic Area"].iloc[index]), xy=(i,j))
jpHispanic.set_axis_labels(xlabel='Hispanic people kills', ylabel='Poverty Rate', size=13)
r, p = stats.pearsonr(dfTotal_H["H"], dfTotal_H["poverty_rate"])
phantom, = jpHispanic2.ax_joint.plot([], [], linestyle="", alpha=0)
jpHispanic2.ax_joint.legend([phantom],['r={:f}, p={:f}'.format(r,p)])

# %% [markdown]
# Come per la razza nera la correlazione è pressochè nulla ma quando il tasso di povertà è intorno al 20% c'è una deriva del numero di uccisioni. In media il numero di uccisioni è intorno a 1.

# %%
jpHispanic3 = sns.jointplot(x="share_hispanic", y="percent_completed_hs", kind='reg', data=dfTotal_H)
jpHispanic3.set_axis_labels(xlabel='Share hispanic people', ylabel='Percentage of over 25 that completed HS', size=13)
r, p = stats.pearsonr(dfTotal_H["share_hispanic"], dfTotal_H["percent_completed_hs"])
phantom, = jpHispanic3.ax_joint.plot([], [], linestyle="", alpha=0)
jpHispanic3.ax_joint.legend([phantom],['r={:f}, p={:f}'.format(r,p)])

# %% [markdown]
# Come per la razza nera si nota una linearità ma in questo caso ancora più marcata ad evidenziare che all'aumentare della concentrazione di popolazione ispanica la percentuale di over 25 che completa la scuola diminuisce.

# %%
jpHispanic4 = sns.jointplot(x="H", y="Median Income", kind='scatter', data=dfTotal_H  ) 
for index,(i,j) in enumerate(zip(dfTotal_H["H"],dfTotal_H["Median Income"])):
    if dfTotal_H["H"].iloc[index]> 5 :
        jpHispanic4.ax_joint.annotate(str(dfTotal_H["Geographic Area"].iloc[index]), xy=(i,j))
jpHispanic4.set_axis_labels(xlabel='Hispanic people kills by police', ylabel='Median Income by State', size=13)
r, p = stats.pearsonr(dfTotal_H["H"], dfTotal_H["Median Income"])
phantom, = jpHispanic4.ax_joint.plot([], [], linestyle="", alpha=0)
jpHispanic4.ax_joint.legend([phantom],['r={:f}, p={:f}'.format(r,p)])

# %% [markdown]
# Come nei casi di razza nera e bianca si ha una piccola deriva della correlazione intorno ai 50000. Per la restante fascia di reddito la quantità di uccisioni è pressochè invariante.

# %% [markdown]
# 15.4Native americans people
# ---

# %%
dfTotal_N = dfTotal5.copy()
for j,item in enumerate(dfTotal_N['N']):
    if item == 0  :
        dfTotal_N.drop(index=j, inplace = True)
df_byGeoArea_N = dfTotal_N.groupby(["Geographic Area"], sort=True)["N"].sum()
df_byGeoArea_N_1 = df_byGeoArea_N.copy()
df_byGeoArea_N_2 = df_byGeoArea_N_1.reset_index()

#plt.ylim(-1, 6)

# %%
jpNative = sns.jointplot(x="N", y="share_native_american", kind='scatter', data=dfTotal_N)
for index,(i,j) in enumerate(zip(dfTotal_N["N"],dfTotal_N["share_native_american"])):
   if dfTotal_N["N"].iloc[index]> 1.5 :        
      jpNative.ax_joint.annotate(str(dfTotal_N["Geographic Area"].iloc[index]), xy=(i,j))
jpNative.set_axis_labels(xlabel='Native kills', ylabel='Share native american', size=13)
r, p = stats.pearsonr(dfTotal_N["N"], dfTotal_N["share_native_american"])
phantom, = jpNative.ax_joint.plot([], [], linestyle="", alpha=0)
jpNative.ax_joint.legend([phantom],['r={:f}, p={:f}'.format(r,p)])

# %% [markdown]
# Anche in questo caso a parte degli outlier non c'è forte dipendenza tra la percentuale di razza nativa e le uccisioni. Ho attivato la visualizzazione delle etichette per capire quali fossero gli stati outliers e sorprende il fatto che un numero così al di fuori dalla media con una percentuale così piccola di nativi sia in Arkansas che nel Montana dove le uccisioni sono rare.

# %%
jpNative2 = sns.jointplot(x="share_native_american", y="poverty_rate", kind='reg', data=dfTotal_N)
for index,(i,j) in enumerate(zip(dfTotal_N["share_native_american"],dfTotal_N["poverty_rate"])):
   if dfTotal_N["share_native_american"].iloc[index]> 20 :        
      jpNative2.ax_joint.annotate(str(dfTotal_N["Geographic Area"].iloc[index]), xy=(i,j))
jpNative2.set_axis_labels(xlabel='Share native american', ylabel='Poverty rate by state', size=13)
r, p = stats.pearsonr(dfTotal_N["share_native_american"], dfTotal_N["poverty_rate"])
phantom, = jpNative2.ax_joint.plot([], [], linestyle="", alpha=0)
jpNative2.ax_joint.legend([phantom],['r={:f}, p={:f}'.format(r,p)])

# %% [markdown]
# I punti nel grafico sono pochi e sembra ci sia una carenza di dati nella fascia dal 20% al 90% di percentuale di razza bianca. Si denota comunque una tendenza lineare diretta ma con una deviazione standard abbastanza ampia rispetto alla percentuale di povertà nelle varie città.

# %%
jpNative3 = sns.jointplot(x="share_native_american", y="percent_completed_hs", kind='reg', data=dfTotal_N)
for index,(i,j) in enumerate(zip(dfTotal_N["share_native_american"],dfTotal_N["percent_completed_hs"])):
     if dfTotal_N["share_native_american"].iloc[index]> 20 :   
        jpNative3.ax_joint.annotate(str(dfTotal_N["Geographic Area"].iloc[index]), xy=(i,j))
jpNative3.set_axis_labels(xlabel='Share native american', ylabel='Percentage of over 25 that completed HS', size=13)
r, p = stats.pearsonr(dfTotal_N["share_native_american"], dfTotal_N["percent_completed_hs"])
phantom, = jpNative3.ax_joint.plot([], [], linestyle="", alpha=0)
jpNative3.ax_joint.legend([phantom],['r={:f}, p={:f}'.format(r,p)])

# %% [markdown]
# Come per ispanici e neri la relazione tra over 25 e percentuale di razza nativa è inversamente lineare in modo evidente.
# Qui la relazione tra over 25 e percentuale di razza nativa ha due tendenze:
# <ul>
#   <li> se la razza nativa è in percentuale al di sotto del 10% gli over 25 diplomati sono al di sopra del 80% </li>
#   <li> se la razza nativa sale oltre il 10% c è una tendenza lineare con pendenza negativa cioè il numero di diplomati diminuisce </li>
# </ul>

# %% [markdown]
# 15.5Asian people
# ---

# %%
dfTotal_A = dfTotal5.copy()
for j,item in enumerate(dfTotal_A['A']):
    if item == 0  :
        dfTotal_A.drop(index=j, inplace = True)
df_byGeoArea_A = dfTotal_A.groupby(["Geographic Area"], sort=True)["A"].sum()
df_byGeoArea_A_1 = df_byGeoArea_A.copy()
df_byGeoArea_A_2 = df_byGeoArea_A_1.reset_index()

# %%
jpAsian = sns.jointplot(x="A", y="share_asian", kind='scatter', data=dfTotal_A)
for index,(i,j) in enumerate(zip(dfTotal_A["A"],dfTotal_A["share_asian"])):
    if dfTotal_A["A"].iloc[index]> 1.5 :
        jpAsian.ax_joint.annotate(str(dfTotal_A["Geographic Area"].iloc[index]), xy=(i,j))
jpAsian.set_axis_labels(xlabel='Asian kills', ylabel='Share asian', size=15)
r, p = stats.pearsonr(dfTotal_A["A"], dfTotal_A["share_asian"])
phantom, = jpAsian.ax_joint.plot([], [], linestyle="", alpha=0)
jpAsian.ax_joint.legend([phantom],['r={:f}, p={:f}'.format(r,p)])

# %% [markdown]
# L'andamento possiamo dedurre che anche in questo caso è pressochè indipendente eccetto in una piccola fascia da 0% a 20% dove le uccisioni sono più frequenti.

# %%
jpAsian2 = sns.jointplot(x="share_asian", y="poverty_rate", kind='scatter', data=dfTotal_A)
for index,(i,j) in enumerate(zip(dfTotal_A["share_asian"],dfTotal_A["poverty_rate"])):
    if dfTotal_A["share_asian"].iloc[index]> 10 :
        jpAsian2.ax_joint.annotate(str(dfTotal_A["Geographic Area"].iloc[index]) , xy=(i,j)) 
jpAsian2.set_axis_labels(xlabel='Share asian', ylabel='Poverty rate by state', size=13)
r, p = stats.pearsonr(dfTotal_A["share_asian"], dfTotal_A["poverty_rate"])
phantom, = jpAsian2.ax_joint.plot([], [], linestyle="", alpha=0)
jpAsian2.ax_joint.legend([phantom],['r={:f}, p={:f}'.format(r,p)])

# %% [markdown]
# Da questo grafico non si può inferire un andamento ben determinato anche se sembra ci sia una debole dipendenza lineare negativa:
# <ul>
#   <li>La correlazione non è particolarmente evidente.</li>
#   <li>Molti casi di uccisione sono avvenuti in California</li>
# </ul>

# %%
jpAsian3 = sns.jointplot(x="share_asian", y="percent_completed_hs", kind='scatter', data=dfTotal_A)
for index,(i,j) in enumerate(zip(dfTotal_A["share_asian"],dfTotal_A["percent_completed_hs"])):
    if dfTotal_A["share_asian"].iloc[index]> 10 :
        jpAsian3.ax_joint.annotate(str(dfTotal_A["Geographic Area"].iloc[index]) , xy=(i,j))
jpAsian3.set_axis_labels(xlabel='Share asian', ylabel='Poverty rate by state', size=13)
r, p = stats.pearsonr(dfTotal_A["share_asian"], dfTotal_A["percent_completed_hs"])
phantom, = jpAsian3.ax_joint.plot([], [], linestyle="", alpha=0)
jpAsian3.ax_joint.legend([phantom],['r={:f}, p={:f}'.format(r,p)])

# %% [markdown]
# Anche in questo caso l'andamento somiglia vagamente ad uno logaritmico ma molto caotico. Ci vorrebbero più punti per delineare una curva più chiara. La relazione perciò non è ben definita. Anche in questo caso la California è lo stato in cui il numero di uccisioni è più elevato per questa razza.

# %% [markdown]
# 16.Killing by race and by state visualization with bars
# ===

# %%
df_rateBlackWhite = pd.merge(df_byGeoArea_W_2, df_byGeoArea_B_2, on=["Geographic Area"] )
df_shareBlack = dfTotal5.groupby(["Geographic Area"], sort=True)["share_black"].mean()
df_shareWhite = dfTotal5.groupby(["Geographic Area"], sort=True)["share_white"].mean()
df_1_rateBlackWhite = pd.merge(df_rateBlackWhite, df_shareBlack, on=["Geographic Area"] )
df_2_rateBlackWhite = pd.merge(df_1_rateBlackWhite, df_shareWhite, on=["Geographic Area"] )

# %%
df_2_rateBlackWhite.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43 entries, 0 to 42
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  43 non-null     object
#  1   W                43 non-null     int64
#  2   B                43 non-null     int64
#  3   share_black      43 non-null     float64
#  4   share_white      43 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 2.0+ KB

# %%
df_2_rateBlackWhite
# Out:
#    Geographic Area    W    B  share_black  share_white  B respect to W
# 0               AK   19    2     1.753846    67.684615        4.062327
# 1               AL   44   30    29.004000    65.944000        1.550194
# 2               AR   46   22    16.771429    75.261224        2.146180
# 3               AZ  101   22     2.731250    69.239583        5.521973
# 4               CA  221  145     5.127083    61.349306        7.850820
# 5               CO   86   18     2.546512    82.672093        6.794967
# 6               CT    7    5    14.700000    64.212500        3.120141
# 7               DC    2   15    50.700000    38.500000        5.695266
# 8               DE    4    5    27.687500    64.800000        2.925508
# 9               FL  149  125    19.377778    71.519259        3.096298
# 10              GA   64   78    35.474468    53.456383        1.836531
# 11              IA   27    7     3.261905    91.990476        7.311490
# 12              ID   31    1     0.586364    87.604545        4.819455
# 13              IL   21   56    18.914706    70.617647        9.955943
# 14              IN   46   16     8.819444    84.580556        3.335734
# 15              KS   35    5     3.365385    89.157692        3.784653
# 16              KY   46    6     6.053191    89.785106        1.934699
# 17              LA   26   51    37.644737    55.821053        2.908644
# 18              MA   15    7     6.804762    78.138095        5.358666
# 19              MD   16   51    35.763158    50.421053        4.493929
# 20              ME   10    1     1.463636    94.336364        6.445342
# 21              MI   25   25    23.200000    68.854839        2.967881
# 22              MN   43   13     4.838000    84.192000        5.261140
# 23              MO   58   36     8.360784    85.754902        6.366290
# 24              MS   29   21    42.696296    52.762963        0.894871
# 25              NC   38   48    27.209091    62.222727        2.888635
# 26              NE   18    6     2.218182    86.881818       13.056011
# 27              NJ    7   19    24.112500    51.343750        5.779642
# 28              NV   38   16     3.715385    75.546154        8.561404
# 29              NY   20   37    15.134375    72.006250        8.801920
# 30              OH   61   66    14.467797    80.245763        6.001141
# 31              OK   67   17     5.772549    69.317647        3.046845
# 32              OR   64    6     1.065854    85.590244        7.528318
# 33              PA   16   33    17.031818    70.227273        8.504303
# 34              RI    1    2    10.200000    70.666667       13.856209
# 35              SC   33   23    31.040541    62.178378        1.396124
# 36              TN   59   24    11.718000    82.318000        2.857594
# 37              TX  175  111    11.175758    73.830303        4.190276
# 38              UT   33    4     1.120588    84.291176        9.117633
# 39              VA   26   34    26.400000    63.336667        3.137306
# 40              WA   73   24     3.635294    75.766176        6.852108
# 41              WI   44   22     3.374419    88.537209       13.118884
# 42              WV   25    7     5.648276    91.151724        4.518632

# %%
dimensions = (14, 8)
fig, ax = plt.subplots(figsize=dimensions)
plt.xticks(rotation=90)
df_2_rateBlackWhite['B respect to W']=( (df_2_rateBlackWhite['B']/df_2_rateBlackWhite['share_black'])/(df_2_rateBlackWhite['W']/df_2_rateBlackWhite['share_white']))
BarPlotBW = sns.barplot(ax = ax, x='Geographic Area', y='B respect to W', data=df_2_rateBlackWhite )

# %% [markdown]
# I risultati di questo grafico sono piuttosto chiari:
# <ul>
#     <li> Le uccisioni di neri scalate sulla percentuale di razza variano da x2 a x14 volte quelle dei bianchi </li>
#     <li> Florida, Texas e Canada non sono tra gli stati con maggior divario di uccisioni tra razze pur avendone un elevato numero </li>
#     <li> Gli stati con un rapporto di uccisioni neri-bianchi più alto sono Illinois, Nebraska, Rhode Island, Wisconsin ma ce ne sono molti altri.
#     <li> Osservando non solo il valore del rapporto tra uccisioni ma i numeri che hanno generato quel risultato, si riscontra che a Rhode Island, Arkansas , Idaho , Maine le uccisioni sono al massimo 2.</li>
# </ul>

# %%
df_rateHispWhite = pd.merge(df_byGeoArea_W_2, df_byGeoArea_H_2, on=["Geographic Area"] )
df_shareHisp = dfTotal5.groupby(["Geographic Area"], sort=True)["share_hispanic"].mean()
df_shareWhite = dfTotal5.groupby(["Geographic Area"], sort=True)["share_white"].mean()
df_1_rateHispWhite = pd.merge(df_rateHispWhite, df_shareHisp , on=["Geographic Area"] )
df_2_rateHispWhite = pd.merge(df_1_rateHispWhite, df_shareWhite, on=["Geographic Area"] )

# %%
df_2_rateHispWhite
# Out:
#    Geographic Area    W    H  share_hispanic  share_white  H respect to W
# 0               AL   44    2        3.602000    65.944000        0.832164
# 1               AZ  101   85       30.025000    69.239583        1.940747
# 2               CA  221  335       38.897569    61.349306        2.390781
# 3               CO   86   51       22.523256    82.672093        2.176705
# 4               CT    7    7       20.893750    64.212500        3.073287
# 5               DE    4    1        7.587500    64.800000        2.135091
# 6               FL  149   52       17.837037    71.519259        1.399321
# 7               GA   64   10       11.042553    53.456383        0.756398
# 8               ID   31    6       14.122727    87.604545        1.200598
# 9               IL   21   13       12.447059    70.617647        3.512130
# 10              IN   46    4        6.344444    84.580556        1.159255
# 11              KS   35    6        6.407692    89.157692        2.385286
# 12              KY   46    2        2.878723    89.785106        1.356053
# 13              LA   26    2        5.007895    55.821053        0.857432
# 14              MA   15    8       10.057143    78.138095        4.143687
# 15              MD   16    3        9.605263    50.421053        0.984247
# 16              MI   25    2        4.883871    68.854839        1.127873
# 17              MN   43    3        5.164000    84.192000        1.137463
# 18              MO   58    1        4.158824    85.754902        0.355517
# 19              MS   29    1        3.200000    52.762963        0.568566
# 20              NC   38    5       10.443182    62.222727        0.783976
# 21              NE   18    2       11.463636    86.881818        0.842101
# 22              NJ    7    6       33.206250    51.343750        1.325321
# 23              NM   23   60       45.075000    63.275000        3.662013
# 24              NV   38   31       23.984615    75.546154        2.569554
# 25              NY   20    9       14.887500    72.006250        2.176511
# 26              OH   61    1        3.205085    80.245763        0.410443
# 27              OK   67    4        5.980392    69.317647        0.691989
# 28              OR   64    7       11.382927    85.590244        0.822410
# 29              PA   16    4       13.772727    70.227273        1.274752
# 30              RI    1    1       19.833333    70.666667        3.563025
# 31              SC   33    1        5.627027    62.178378        0.334847
# 32              TN   59    3        5.108000    82.318000        0.819432
# 33              TX  175  155       35.083030    73.830303        1.863937
# 34              UT   33   10       12.326471    84.291176        2.072189
# 35              VA   26    3        7.500000    63.336667        0.974410
# 36              WA   73   23       14.457353    75.766176        1.651169
# 37              WI   44    5        6.127907    88.537209        1.641841
# 38              WY   10    2       11.642857    89.142857        1.531288

# %%
dimensions = (14, 8)
fig, ax = plt.subplots(figsize=dimensions)
plt.xticks(rotation=90)
df_2_rateHispWhite['H respect to W']=( (df_2_rateHispWhite['H']/df_2_rateHispWhite['share_hispanic'])/(df_2_rateHispWhite['W']/df_2_rateHispWhite['share_white']))
BarPlotHW = sns.barplot(ax = ax, x='Geographic Area', y='H respect to W', data=df_2_rateHispWhite )

# %% [markdown]
# I risultati di questo grafico sono piuttosto chiari:
# <ul>
#      <li> Le uccisioni di ispanici scalate sulla percentuale di razza, hanno rapporti più bassi rispetto a quelli visti precedentemente tra neri e bianchi ma sono in molti casi da x2 a un massimo di x4 volte quelle dei bianchi.</li>
#      <li> Florida, Texas e Canada ancora una volta non sono tra gli stati con maggior divario di uccisioni tra razze pur avendone un elevato numero </li>
#      <li> Gli stati con un rapporto di uccisioni ispanici-bianchi più alto sono Illinois, Massachussets, New Mexico e Connecticut</li>
#      <li> Rhode Island e Delaware non sono da considerare per l'insufficienza di dati</li>
# </ul>

# %%
df_rateNativeWhite = pd.merge(df_byGeoArea_W_2, df_byGeoArea_N_2, on=["Geographic Area"] )
df_shareNative = dfTotal5.groupby(["Geographic Area"], sort=True)["share_native_american"].mean()
df_shareWhite = dfTotal5.groupby(["Geographic Area"], sort=True)["share_white"].mean()
df_1_rateNativeWhite = pd.merge(df_rateNativeWhite, df_shareNative , on=["Geographic Area"] )
df_2_rateNativeWhite = pd.merge(df_1_rateNativeWhite, df_shareWhite, on=["Geographic Area"] )

# %%
df_2_rateNativeWhite
# Out:
#    Geographic Area    W   N  share_native_american  share_white  \
# 0               AK   19   8              21.346154    67.684615
# 1               AZ  101  10              12.118750    69.239583
# 2               CA  221   4               1.182639    61.349306
# 3               CO   86   4               1.230233    82.672093
# 4               ID   31   1               0.972727    87.604545
# 5               KS   35   1               0.884615    89.157692
# 6               MN   43   5               2.688000    84.192000
# 7               MT   26   4               2.564286    93.150000
# 8               ND    4   5              17.542857    78.142857
# 9               NE   18   1               2.863636    86.881818
# 10              NM   23   2              16.375000    63.275000
# 11              NV   38   1               2.438462    75.546154
# 12              OK   67   8              14.409804    69.317647
# 13              SD    7   4              34.300000    60.372727
# 14              TX  175   1               0.741818    73.830303
# 15              UT   33   1               3.747059    84.291176
# 16              VA   26   1               0.353333    63.336667
# 17              VT    5   1               0.300000    90.275000
# 18              WA   73   6               1.492647    75.766176
# 19              WI   44   3               1.206977    88.537209
# 20              WY   10   2               2.328571    89.142857
#
#     N respect to W
# 0         1.335078
# 1         0.565686
# 2         0.938913
# 3         3.125599
# 4         2.905185
# 5         2.879627
# 6         3.642027
# 7         5.588601
# 8         5.567997
# 9         1.685538
# 10        0.336011
# 11        0.815291
# 12        0.574382
# 13        1.005793
# 14        0.568721
# 15        0.681675
# 16        6.894412
# 17       60.183333
# 18        4.172022
# 19        5.001445
# 20        7.656442

# %%
dimensions = (14, 8)
fig, ax = plt.subplots(figsize=dimensions)
plt.xticks(rotation=90)
df_2_rateNativeWhite['N respect to W']=( (df_2_rateNativeWhite['N']/df_2_rateNativeWhite['share_native_american'])/(df_2_rateNativeWhite['W']/df_2_rateNativeWhite['share_white']))
BarPlotNW = sns.barplot(ax = ax, x='Geographic Area', y='N respect to W', data=df_2_rateNativeWhite )

# %% [markdown]
# Dal confronto del grafico con i dati tabellari si vede che:
# <ul>
#     <li> Le uccisioni di nativi scalate sulla percentuale di razza variano fino a x60 volte quelle dei bianchi </li>
#     <li> Florida, Texas e Canada non sono tra gli stati con maggior divario di uccisioni </li>
#     <li> Colorado, Minnesota, Montana e Nord Dakota sono gli stati con un divario di uccisioni tra razze compreso tra x3 e x5 </li>
#     <li> Idaho, Kansas, Virginia e Vermont sono gli stati con un divario di uccisioni rilevante ma non significativo dato che il numero di uccisioni di nativi è 1. </li>
#
# </ul>

# %%
df_rateAsianWhite = pd.merge(df_byGeoArea_W_2, df_byGeoArea_A_2, on=["Geographic Area"] )
df_shareAsian = dfTotal5.groupby(["Geographic Area"], sort=True)["share_asian"].mean()
df_shareWhite = dfTotal5.groupby(["Geographic Area"], sort=True)["share_white"].mean()
df_1_rateAsianWhite = pd.merge(df_rateAsianWhite, df_shareAsian , on=["Geographic Area"] )
df_2_rateAsianWhite = pd.merge(df_1_rateAsianWhite, df_shareWhite, on=["Geographic Area"] )

# %%
df_2_rateAsianWhite

# %%
dimensions = (14, 8)
fig, ax = plt.subplots(figsize=dimensions)
plt.xticks(rotation=90)
df_2_rateAsianWhite['A respect to W']=( (df_2_rateAsianWhite['A']/df_2_rateAsianWhite['share_asian'])/(df_2_rateAsianWhite['W']/df_2_rateAsianWhite['share_white']))
BarPlotAW = sns.barplot(ax = ax, x='Geographic Area', y="A respect to W", data=df_2_rateAsianWhite )

# %% [markdown]
# 17.Killing inference based on geographical mapped data
# ===

# %%
import geopandas as gpd
import geoplot
import geoplot.crs as gcrs

# %% [markdown]
#  Lat-long coorditates for cities in United States are in range: Latitude from 19.50139 to 64.85694 and longitude from -125.75583 to -68.01197.
#  Eliminazione di tutte le righe in cui non è inserita alcuna coordinata geografica o coordinate errate

# %%
count_1=0
count_2=0
dfTotal6 = dfTotal5.copy()
for j,item  in enumerate(dfTotal6['latitude']):
    if item < 19.50139 or item > 64.85694 or pd.isna(dfTotal6['latitude'][j]):
            dfTotal6.drop(index=j, inplace = True) 
            print(str(j)+' :Wrong latitude'+ ' Value: '+str(item))
            count_1 = count_1 + 1
             
dfTotal7=dfTotal6.reset_index(drop=True)
for j,item  in enumerate(dfTotal7['longitude']):
    if item < -125 or item > -68.01197 or pd.isna(dfTotal7['longitude'][j]):
        dfTotal7.drop(index=j, inplace = True) 
        print(str(j)+' :Wrong longitude'+ ' Value: '+str(item))   
        count_2 = count_2 + 1
        
print(str(count_1)+ ' deleted over '+ str(len(dfTotal5)) +' rows')
print(str(count_2)+ ' deleted over '+ str(len(dfTotal6)) +' rows')  
dfTotal8=dfTotal7.reset_index(drop=True)
# Out:
# 0 :Wrong latitude Value: nan
# 1 :Wrong latitude Value: 71.301
# 2 :Wrong latitude Value: nan
# 3 :Wrong latitude Value: nan
# 8 :Wrong latitude Value: nan
# 9 :Wrong latitude Value: nan
# 10 :Wrong latitude Value: nan
# 24 :Wrong latitude Value: nan
# 26 :Wrong latitude Value: nan
# 27 :Wrong latitude Value: nan
# 28 :Wrong latitude Value: nan
# 30 :Wrong latitude Value: nan
# 33 :Wrong latitude Value: nan
# 34 :Wrong latitude Value: nan
# 39 :Wrong latitude Value: nan
# 40 :Wrong latitude Value: nan
# 41 :Wrong latitude Value: nan
# 42 :Wrong latitude Value: nan
# 52 :Wrong latitude Value: nan
# 59 :Wrong latitude Value: nan
# 64 :Wrong latitude Value: nan
# 66 :Wrong latitude Value: nan
# 71 :Wrong latitude Value: nan
# 79 :Wrong latitude Value: nan
# 81 :Wrong latitude Value: nan
# 83 :Wrong latitude Value: nan
# 87 :Wrong latitude Value: nan
# 88 :Wrong latitude Value: nan
# 95 :Wrong latitude Value: nan
# 106 :Wrong latitude Value: nan
# 107 :Wrong latitude Value: nan
# 110 :Wrong latitude Value: nan
# 117 :Wrong latitude Value: nan
# 124 :Wrong latitude Value: nan
# 126 :Wrong latitude Value: nan
# 129 :Wrong latitude Value: nan
# 131 :Wrong latitude Value: nan
# 135 :Wrong latitude Value: nan
# 136 :Wrong latitude Value: nan
# 137 :Wrong latitude Value: nan
# 142 :Wrong latitude Value: nan
# 144 :Wrong latitude Value: nan
# 149 :Wrong latitude Value: nan
# 150 :Wrong latitude Value: nan
# 153 :Wrong latitude Value: nan
# 155 :Wrong latitude Value: nan
# 164 :Wrong latitude Value: nan
# 171 :Wrong latitude Value: nan
# 172 :Wrong latitude Value: nan
# 179 :Wrong latitude Value: nan
# 184 :Wrong latitude Value: nan
# 186 :Wrong latitude Value: nan
# 187 :Wrong latitude Value: nan
# 190 :Wrong latitude Value: nan
# 201 :Wrong latitude Value: nan
# 216 :Wrong latitude Value: nan
# 228 :Wrong latitude Value: nan
# 233 :Wrong latitude Value: nan
# 254 :Wrong latitude Value: nan
# 267 :Wrong latitude Value: nan
# 272 :Wrong latitude Value: nan
# 274 :Wrong latitude Value: nan
# 282 :Wrong latitude Value: nan
# 284 :Wrong latitude Value: nan
# 288 :Wrong latitude Value: nan
# 289 :Wrong latitude Value: nan
# 291 :Wrong latitude Value: nan
# 292 :Wrong latitude Value: nan
# 293 :Wrong latitude Value: nan
# 301 :Wrong latitude Value: nan
# 307 :Wrong latitude Value: nan
# 312 :Wrong latitude Value: nan
# 315 :Wrong latitude Value: nan
# 341 :Wrong latitude Value: nan
# 356 :Wrong latitude Value: nan
# 364 :Wrong latitude Value: nan
# 365 :Wrong latitude Value: nan
# 367 :Wrong latitude Value: nan
# 379 :Wrong latitude Value: nan
# 380 :Wrong latitude Value: nan
# 384 :Wrong latitude Value: nan
# 386 :Wrong latitude Value: nan
# 406 :Wrong latitude Value: nan
# 407 :Wrong latitude Value: nan
# 408 :Wrong latitude Value: nan
# 412 :Wrong latitude Value: nan
# 422 :Wrong latitude Value: nan
# 441 :Wrong latitude Value: nan
# 443 :Wrong latitude Value: nan
# 461 :Wrong latitude Value: nan
# 467 :Wrong latitude Value: nan
# 468 :Wrong latitude Value: nan
# 472 :Wrong latitude Value: nan
# 473 :Wrong latitude Value: nan
# 476 :Wrong latitude Value: nan
# 492 :Wrong latitude Value: nan
# 498 :Wrong latitude Value: nan
# 506 :Wrong latitude Value: nan
# 508 :Wrong latitude Value: nan
# 510 :Wrong latitude Value: nan
# 531 :Wrong latitude Value: nan
# 533 :Wrong latitude Value: nan
# 534 :Wrong latitude Value: nan
# 556 :Wrong latitude Value: nan
# 557 :Wrong latitude Value: nan
# 562 :Wrong latitude Value: nan
# 577 :Wrong latitude Value: nan
# 578 :Wrong latitude Value: nan
# 589 :Wrong latitude Value: nan
# 596 :Wrong latitude Value: nan
# 598 :Wrong latitude Value: nan
# 609 :Wrong latitude Value: nan
# 612 :Wrong latitude Value: nan
# 623 :Wrong latitude Value: nan
# 625 :Wrong latitude Value: nan
# 627 :Wrong latitude Value: nan
# 635 :Wrong latitude Value: nan
# 652 :Wrong latitude Value: nan
# 656 :Wrong latitude Value: nan
# 657 :Wrong latitude Value: nan
# 664 :Wrong latitude Value: nan
# 667 :Wrong latitude Value: nan
# 670 :Wrong latitude Value: nan
# 680 :Wrong latitude Value: nan
# 682 :Wrong latitude Value: nan
# 694 :Wrong latitude Value: nan
# 697 :Wrong latitude Value: nan
# 701 :Wrong latitude Value: nan
# 708 :Wrong latitude Value: nan
# 717 :Wrong latitude Value: nan
# 722 :Wrong latitude Value: nan
# 724 :Wrong latitude Value: nan
# 738 :Wrong latitude Value: nan
# 745 :Wrong latitude Value: nan
# 747 :Wrong latitude Value: nan
# 749 :Wrong latitude Value: nan
# 752 :Wrong latitude Value: nan
# 792 :Wrong latitude Value: nan
# 794 :Wrong latitude Value: nan
# 801 :Wrong latitude Value: nan
# 816 :Wrong latitude Value: nan
# 824 :Wrong latitude Value: nan
# 832 :Wrong latitude Value: nan
# 835 :Wrong latitude Value: nan
# 845 :Wrong latitude Value: nan
# 849 :Wrong latitude Value: nan
# 855 :Wrong latitude Value: nan
# 864 :Wrong latitude Value: nan
# 867 :Wrong latitude Value: nan
# 876 :Wrong latitude Value: nan
# 884 :Wrong latitude Value: nan
# 896 :Wrong latitude Value: nan
# 901 :Wrong latitude Value: nan
# 903 :Wrong latitude Value: nan
# 912 :Wrong latitude Value: nan
# 914 :Wrong latitude Value: nan
# 919 :Wrong latitude Value: nan
# 927 :Wrong latitude Value: nan
# 929 :Wrong latitude Value: nan
# 939 :Wrong latitude Value: nan
# 944 :Wrong latitude Value: nan
# 945 :Wrong latitude Value: nan
# 951 :Wrong latitude Value: nan
# 953 :Wrong latitude Value: nan
# 965 :Wrong latitude Value: nan
# 970 :Wrong latitude Value: nan
# 971 :Wrong latitude Value: nan
# 976 :Wrong latitude Value: nan
# 977 :Wrong latitude Value: nan
# 980 :Wrong latitude Value: nan
# 982 :Wrong latitude Value: nan
# 985 :Wrong latitude Value: nan
# 987 :Wrong latitude Value: nan
# 995 :Wrong latitude Value: nan
# 997 :Wrong latitude Value: nan
# 1016 :Wrong latitude Value: nan
# 1018 :Wrong latitude Value: nan
# 1026 :Wrong latitude Value: nan
# 1039 :Wrong latitude Value: nan
# 1040 :Wrong latitude Value: nan
# 1056 :Wrong latitude Value: nan
# 1057 :Wrong latitude Value: nan
# 1062 :Wrong latitude Value: nan
# 1072 :Wrong latitude Value: nan
# 1079 :Wrong latitude Value: nan
# 1086 :Wrong latitude Value: nan
# 1095 :Wrong latitude Value: nan
# 1099 :Wrong latitude Value: nan
# 1102 :Wrong latitude Value: nan
# 1113 :Wrong latitude Value: nan
# 1116 :Wrong latitude Value: nan
# 1127 :Wrong latitude Value: nan
# 1128 :Wrong latitude Value: nan
# 1138 :Wrong latitude Value: nan
# 1141 :Wrong latitude Value: nan
# 1142 :Wrong latitude Value: nan
# 1143 :Wrong latitude Value: nan
# 1147 :Wrong latitude Value: nan
# 1148 :Wrong latitude Value: nan
# 1151 :Wrong latitude Value: nan
# 1155 :Wrong latitude Value: nan
# 1159 :Wrong latitude Value: nan
# 1169 :Wrong latitude Value: nan
# 1170 :Wrong latitude Value: nan
# 1178 :Wrong latitude Value: nan
# 1191 :Wrong latitude Value: nan
# 1206 :Wrong latitude Value: nan
# 1211 :Wrong latitude Value: nan
# 1213 :Wrong latitude Value: nan
# 1217 :Wrong latitude Value: nan
# 1219 :Wrong latitude Value: nan
# 1245 :Wrong latitude Value: nan
# 1258 :Wrong latitude Value: nan
# 1260 :Wrong latitude Value: nan
# 1264 :Wrong latitude Value: nan
# 1270 :Wrong latitude Value: nan
# 1271 :Wrong latitude Value: nan
# 1273 :Wrong latitude Value: nan
# 1279 :Wrong latitude Value: nan
# 1283 :Wrong latitude Value: nan
# 1287 :Wrong latitude Value: nan
# 1291 :Wrong latitude Value: nan
# 1293 :Wrong latitude Value: nan
# 1301 :Wrong latitude Value: nan
# 1303 :Wrong latitude Value: nan
# 1312 :Wrong latitude Value: nan
# 1314 :Wrong latitude Value: nan
# 1320 :Wrong latitude Value: nan
# 1323 :Wrong latitude Value: nan
# 1326 :Wrong latitude Value: nan
# 1329 :Wrong latitude Value: nan
# 1336 :Wrong latitude Value: nan
# 1340 :Wrong latitude Value: nan
# 1352 :Wrong latitude Value: nan
# 1359 :Wrong latitude Value: nan
# 1360 :Wrong latitude Value: nan
# 1365 :Wrong latitude Value: nan
# 1367 :Wrong latitude Value: nan
# 1375 :Wrong latitude Value: nan
# 1379 :Wrong latitude Value: nan
# 1383 :Wrong latitude Value: nan
# 1396 :Wrong latitude Value: nan
# 1400 :Wrong latitude Value: nan
# 1403 :Wrong latitude Value: nan
# 1428 :Wrong latitude Value: nan
# 1432 :Wrong latitude Value: nan
# 1434 :Wrong latitude Value: nan
# 1437 :Wrong latitude Value: nan
# 1438 :Wrong latitude Value: nan
# 1446 :Wrong latitude Value: nan
# 1449 :Wrong latitude Value: nan
# 1454 :Wrong latitude Value: nan
# 1455 :Wrong latitude Value: nan
# 1458 :Wrong latitude Value: nan
# 1461 :Wrong latitude Value: nan
# 1469 :Wrong latitude Value: nan
# 1484 :Wrong latitude Value: nan
# 1486 :Wrong latitude Value: nan
# 1489 :Wrong latitude Value: nan
# 1493 :Wrong latitude Value: nan
# 1496 :Wrong latitude Value: nan
# 1498 :Wrong latitude Value: nan
# 1503 :Wrong latitude Value: nan
# 1505 :Wrong latitude Value: nan
# 1507 :Wrong latitude Value: nan
# 1509 :Wrong latitude Value: nan
# 1516 :Wrong latitude Value: nan
# 1522 :Wrong latitude Value: nan
# 1525 :Wrong latitude Value: nan
# 1527 :Wrong latitude Value: nan
# 1530 :Wrong latitude Value: nan
# 1533 :Wrong latitude Value: nan
# 1538 :Wrong latitude Value: nan
# 1541 :Wrong latitude Value: nan
# 1544 :Wrong latitude Value: nan
# 1551 :Wrong latitude Value: nan
# 1553 :Wrong latitude Value: nan
# 1555 :Wrong latitude Value: nan
# 1556 :Wrong latitude Value: nan
# 1561 :Wrong latitude Value: nan
# 1564 :Wrong latitude Value: nan
# 1580 :Wrong latitude Value: nan
# 1582 :Wrong latitude Value: nan
# 1585 :Wrong latitude Value: nan
# 1589 :Wrong latitude Value: nan
# 1590 :Wrong latitude Value: nan
# 1593 :Wrong latitude Value: nan
# 1595 :Wrong latitude Value: nan
# 1596 :Wrong latitude Value: nan
# 1600 :Wrong latitude Value: nan
# 1604 :Wrong latitude Value: nan
# 1610 :Wrong latitude Value: nan
# 1619 :Wrong latitude Value: nan
# 1625 :Wrong latitude Value: nan
# 1626 :Wrong latitude Value: nan
# 1632 :Wrong latitude Value: nan
# 1640 :Wrong latitude Value: nan
# 1641 :Wrong latitude Value: nan
# 1652 :Wrong latitude Value: nan
# 1655 :Wrong latitude Value: nan
# 1671 :Wrong latitude Value: nan
# 1674 :Wrong latitude Value: nan
# 1675 :Wrong latitude Value: nan
# 1680 :Wrong latitude Value: nan
# 1685 :Wrong latitude Value: nan
# 1688 :Wrong latitude Value: nan
# 1695 :Wrong latitude Value: nan
# 1706 :Wrong latitude Value: nan
# 1709 :Wrong latitude Value: nan
# 1712 :Wrong latitude Value: nan
# 1714 :Wrong latitude Value: nan
# 1719 :Wrong latitude Value: nan
# 1730 :Wrong latitude Value: nan
# 1732 :Wrong latitude Value: nan
# 1753 :Wrong latitude Value: nan
# 1761 :Wrong latitude Value: nan
# 1769 :Wrong latitude Value: nan
# 1770 :Wrong latitude Value: nan
# 1773 :Wrong latitude Value: nan
# 1794 :Wrong latitude Value: nan
# 1797 :Wrong latitude Value: nan
# 1798 :Wrong latitude Value: nan
# 1801 :Wrong latitude Value: nan
# 1814 :Wrong latitude Value: nan
# 1817 :Wrong latitude Value: nan
# 1823 :Wrong latitude Value: nan
# 1824 :Wrong latitude Value: nan
# 1833 :Wrong latitude Value: nan
# 1846 :Wrong latitude Value: nan
# 1857 :Wrong latitude Value: nan
# 1862 :Wrong latitude Value: nan
# 1863 :Wrong latitude Value: nan
# 1867 :Wrong latitude Value: nan
# 1869 :Wrong latitude Value: nan
# 1882 :Wrong latitude Value: nan
# 1888 :Wrong latitude Value: nan
# 1892 :Wrong latitude Value: nan
# 1903 :Wrong latitude Value: nan
# 1905 :Wrong latitude Value: nan
# 1922 :Wrong latitude Value: nan
# 1932 :Wrong latitude Value: nan
# 1933 :Wrong latitude Value: nan
# 1941 :Wrong latitude Value: nan
# 1947 :Wrong latitude Value: nan
# 1957 :Wrong latitude Value: nan
# 1964 :Wrong latitude Value: nan
# 1970 :Wrong latitude Value: nan
# 1980 :Wrong latitude Value: nan
# 1986 :Wrong latitude Value: nan
# 1997 :Wrong latitude Value: nan
# 1998 :Wrong latitude Value: nan
# 2003 :Wrong latitude Value: nan
# 2008 :Wrong latitude Value: nan
# 2009 :Wrong latitude Value: nan
# 2011 :Wrong latitude Value: nan
# 2013 :Wrong latitude Value: nan
# 2016 :Wrong latitude Value: nan
# 2017 :Wrong latitude Value: nan
# 2020 :Wrong latitude Value: nan
# 2021 :Wrong latitude Value: nan
# 2022 :Wrong latitude Value: nan
# 2029 :Wrong latitude Value: nan
# 0 :Wrong longitude Value: -147.7348888888889
# 1 :Wrong longitude Value: -149.778
# 2 :Wrong longitude Value: -151.38
# 3 :Wrong longitude Value: -151.617
# 4 :Wrong longitude Value: -149.437
# 5 :Wrong longitude Value: -149.48125
# 612 :Wrong longitude Value: -155.03
# 613 :Wrong longitude Value: -157.797
# 614 :Wrong longitude Value: -158.137
# 615 :Wrong longitude Value: -154.92
# 362 deleted over 2031 rows
# 10 deleted over 1669 rows

# %%
dfTotal8.to_csv("dfTotal8.csv")

# %%
#dfGeo_W = dfTotal8.copy()
#for j,item in enumerate(dfGeo_W['W']):    
#    if item == 0  :
#        dfGeo_W.drop(index=j, inplace = True)
#dfGeo_W_1=dfGeo_W.dropna()

# %%
#dfGeo_W_2 = gpd.GeoDataFrame(dfGeo_W_1, geometry = gpd.points_from_xy(dfGeo_W_1.longitude , dfGeo_W_1.latitude))

# %%
#polyplot_kwargs = {'facecolor': (0.9, 0.9, 0.9), 'linewidth': 0}
#pointplot_kwargs = {
#    'scale': 'W', 'edgecolor': 'white', 'linewidth': 0.5#, 'color': 'red'
#}
#ax1 = geoplot.polyplot(contiguous_usa.geometry, projection=geoplot.crs.AlbersEqualArea(),figsize=(14, 8), **polyplot_kwargs)
#geoplot.polyplot(contiguous_usa, ax=ax1, zorder=1)
#geoplot.pointplot(dfGeo_W_2[['W','geometry']],limits=(1, 100),ax = ax1,hue= "W",legend=True, legend_var='hue',**pointplot_kwargs)
#plt.title("White people kills by city")

# %%
df_W = dfTotal8.copy()
for j,item in enumerate(df_W['W']):    
    #elimino le città con 1 o 2 uccisioni altrimenti nella rappresentazione grafica si visualizzerebbero dati che potrebbero 
    #sembrare significativi quando in realtà non lo sono per il fatto che i numeri sono decisamente piccoli.
    if item < 3  :
        df_W.drop(index=j, inplace = True)
df_1_W=df_W.dropna()
dfGeo_W = gpd.GeoDataFrame(df_1_W, geometry = gpd.points_from_xy(df_1_W.longitude , df_1_W.latitude))

df_B = dfTotal8.copy()
for j,item in enumerate(df_B['B']):    
    if item < 3  :
        df_B.drop(index=j, inplace = True)
df_1_B=df_B.dropna()
dfGeo_B = gpd.GeoDataFrame(df_1_B, geometry = gpd.points_from_xy(df_1_B.longitude , df_1_B.latitude))
#In df_2_B Non inserisco la colonna con le coordinate df_2_B perchè sono già presenti nell'altro data frame
df_2_B  = dfGeo_B[["Geographic Area","City","share_black","B"]]
df_2_W = dfGeo_W[["Geographic Area","City","share_white","W","geometry"]]
df_BW = pd.merge(df_2_W, df_2_B, on=["Geographic Area","City"])
df_BW['B respect to W']=( (df_BW['B']/df_BW['share_black'])/(df_BW['W']/df_BW['share_white']))

# %%
df_BW.to_csv("df_BW.csv")

# %%
df_BW.info()

# %%
contiguous_usa = gpd.read_file(geoplot.datasets.get_path('contiguous_usa'))

polyplot_kwargs = {'facecolor': (0.9, 0.9, 0.9), 'linewidth': 0}
pointplot_kwargs = {
    'scale': 'B respect to W', 'edgecolor': 'white', 'linewidth': 0.5#, 'color': 'red'
}

ax1 = geoplot.polyplot(contiguous_usa.geometry, projection=geoplot.crs.AlbersEqualArea(),figsize=(14, 8), **polyplot_kwargs)

for index,(i,j) in enumerate(zip(df_BW["Geographic Area"],df_BW['B respect to W'])):
    #if df_BW["share_asian"].iloc[index]> 10 :
    plt.annotate(text = str(df_BW["Geographic Area"].iloc[index]) , xy=df_BW["geometry"].iloc[index])
    #print(str(index)+" "+str(i)+" "+str(j)+" "+str(df_BW["Geographic Area"].iloc[index]), xy=[df_BW["geometry"].iloc[index]
geoplot.polyplot(contiguous_usa, ax=ax1, zorder=1)
geoplot.pointplot(df_BW[['B respect to W','geometry']],limits=(1, 200),ax = ax1,hue= 'B respect to W',legend=True, legend_var='hue',**pointplot_kwargs)
plt.title("Black killing rate respect to White")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15024/1182414207.py in <module>
#      10 for index,(i,j) in enumerate(zip(df_BW["Geographic Area"],df_BW['B respect to W'])):
#      11     #if df_BW["share_asian"].iloc[index]> 10 :
# ---> 12     plt.annotate(text = str(df_BW["Geographic Area"].iloc[index]) , xy=df_BW["geometry"].iloc[index])
#      13     #print(str(index)+" "+str(i)+" "+str(j)+" "+str(df_BW["Geographic Area"].iloc[index]), xy=[df_BW["geometry"].iloc[index]
#      14 geoplot.polyplot(contiguous_usa, ax=ax1, zorder=1)
#
# ~\.conda\envs\condaenv11042020\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     333                 f"for the old name will be dropped %(removal)s.")
#     334             kwargs[new] = kwargs.pop(old)
# --> 335         return func(*args, **kwargs)
#     336
#     337     # wrapper() must keep the same documented signature as func(): if we
#
# ~\.conda\envs\condaenv11042020\lib\site-packages\matplotlib\pyplot.py in annotate(text, xy, *args, **kwargs)
#    2593 @_copy_docstring_and_deprecators(Axes.annotate)
#    2594 def annotate(text, xy, *args, **kwargs):
# -> 2595     return gca().annotate(text, xy, *args, **kwargs)
#    2596
#    2597
#
# ~\.conda\envs\condaenv11042020\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     333                 f"for the old name will be dropped %(removal)s.")
#     334             kwargs[new] = kwargs.pop(old)
# --> 335         return func(*args, **kwargs)
#     336
#     337     # wrapper() must keep the same documented signature as func(): if we
#
# ~\.conda\envs\condaenv11042020\lib\site-packages\matplotlib\axes\_axes.py in annotate(self, text, xy, *args, **kwargs)
#     650     @docstring.dedent_interpd
#     651     def annotate(self, text, xy, *args, **kwargs):
# --> 652         a = mtext.Annotation(text, xy, *args, **kwargs)
#     653         a.set_transform(mtransforms.IdentityTransform())
#     654         if 'clip_on' in kwargs:
#
# ~\.conda\envs\condaenv11042020\lib\site-packages\matplotlib\text.py in __init__(self, text, xy, xytext, xycoords, textcoords, arrowprops, annotation_clip, **kwargs)
#    1787         if xytext is None:
#    1788             xytext = self.xy
# -> 1789         x, y = xytext
#    1790
#    1791         self.arrowprops = arrowprops
#
# TypeError: cannot unpack non-iterable Point object

# %% [markdown]
# <ul>
#     <li> Visivamente si evince che i paesi con un rapporto tra uccisioni per razza di valore ampio, sono soprattutto quelli al sud. Se si torna un po' indietro negli anni, allo scoppio della guerra di secessione, la situazione politica, economica e sociale era profondamente diversa negli stati del Nord e in quelli del Sud.</li>
#     <li> La società del Sud era assai più aristocratica e militarista di quella del Nord.Proprio a causa della minore industrializzazione, gran parte della popolazione era impegnata nell’agricoltura. I grandi proprietari ed i piccoli agricoltori erano abituati, già nella vita civile, ad utilizzare armi e a spostarsi a cavallo.
# Molti dei veterani della guerra del 1812-1815, della guerra Texas-Messico (1835-1836) e della guerra messicana (1846-1848) vivevano al Sud. Per tale ragione non è irragionevole pensare che ideologie discriminatorie con buona probabilità potrebbero essersi radicate maggiormente.
# Se si osservano i dati relativi alla percentuale di schiavi e uomini liberi si vede che dove la quantità di schiavi era più massiccia:
#     <ul>
#         <li> Alabama: 529 164 liberi e 435 132 schiavi (45,1%)</li>
#         <li> Arkansas: 324 323 liberi e 111 104 schiavi (25,5%)</li>
#         <li> Carolina del Nord: 661 586 liberi e 331 081 schiavi (33,3%)</li>
#         <li> Carolina del Sud: 301 271 liberi e 402 541 schiavi (57,2%)</li>
#         <li> Columbia (distretto): 71 895 liberi e 3 181 schiavi (4,2%)</li>
#         <li> Delaware: 110 420 liberi e 1 798 schiavi (1,6%)</li>
#         <li> Florida: 78 686 liberi e 61 753 schiavi (43,9%)</li>
#         <li> Georgia: 595 097 liberi e 462 300 schiavi (43,7%)</li>
#         <li> Kentucky: 930 223 liberi e 225 490 schiavi (19,5%)</li>
#         <li> Louisiana: 376 913 liberi e 332 520 schiavi (46,8%)</li>
#         <li> Mississippi: 354 699 liberi e 436 696 schiavi (55,2%)</li>
#         <li> Missouri: 1 058 352 liberi e 114 965 schiavi (9,8%)</li>
#         <li> Nebraska (territorio): 28 832 liberi e 10 schiavi (0,03%)</li>
#         <li> Nuovo Messico (territorio): 93 517 liberi e 24 schiavi (0,02%)</li>
#         <li>Tennessee: 834 063 liberi e 275 784 schiavi (24,8%)</li>
#         <li>Texas: 420 651 liberi e 180 388 schiavi (30,0%)</li>
#         <li> Utah (territorio): 40 266 liberi e 29 schiavi (0,07%)</li>
#         <li>Virginia: 1 105 196 liberi e 490 887 schiavi (30,8%)</li>
#     </ul>
#     <li> dall' articolo https://www.sacbee.com/opinion/op-ed/article251510623.html si osserva come nonostante la California non fosse mai stato uno stato schiavista ma accoglieva con entusiasmo i veterani della guerra.</li>
#
# </ul>

# %%
#dfGeo_B = dfTotal8.copy()
#for j,item in enumerate(dfGeo_B['B']):    
#    if item == 0  :
#        dfGeo_B.drop(index=j, inplace = True)
#dfGeo_B_1=dfGeo_B.dropna()

# %%
#dfGeo_B_2 = gpd.GeoDataFrame(dfGeo_B_1, geometry = gpd.points_from_xy(dfGeo_B_1.longitude , dfGeo_B_1.latitude))

# %%
#polyplot_kwargs = {'facecolor': (0.9, 0.9, 0.9), 'linewidth': 0}
#pointplot_kwargs = {
#    'scale': 'B', 'edgecolor': 'white', 'linewidth': 0.5#, 'color': 'red'
#}
#ax1 = geoplot.polyplot(contiguous_usa.geometry, projection=geoplot.crs.AlbersEqualArea(),figsize=(14, 8), **polyplot_kwargs)
#geoplot.polyplot(contiguous_usa, ax=ax1, zorder=1)
#geoplot.pointplot(dfGeo_B_2[['B','geometry']],limits=(1, 100),ax = ax1,hue= "B",legend=True, legend_var='hue',**pointplot_kwargs)
#plt.title("Black people kills by city")

# %% [markdown]
# https://www.sacbee.com/opinion/op-ed/article251510623.html

# %%
#dfGeo_H = dfTotal8.copy()
#for j,item in enumerate(dfGeo_H['H']):    
#    if item == 0  :
#        dfGeo_H.drop(index=j, inplace = True)
#dfGeo_H_1=dfGeo_H.dropna()

# %%
#dfGeo_H_2 = gpd.GeoDataFrame(dfGeo_H_1, geometry = gpd.points_from_xy(dfGeo_H_1.longitude , dfGeo_H_1.latitude))

# %%
#polyplot_kwargs = {'facecolor': (0.9, 0.9, 0.9), 'linewidth': 0}
#pointplot_kwargs = {
#    'scale': 'H', 'edgecolor': 'white', 'linewidth': 0.5#, 'color': 'red'
#}
#ax1 = geoplot.polyplot(contiguous_usa.geometry, projection=geoplot.crs.AlbersEqualArea(),figsize=(14, 8), **polyplot_kwargs)
#geoplot.polyplot(contiguous_usa, ax=ax1, zorder=1)
#geoplot.pointplot(dfGeo_H_2[['H','geometry']],limits=(1, 100),ax = ax1,hue= "H",legend=True, legend_var='hue',**pointplot_kwargs)
#plt.title("Hispanic people kills by city")

# %%
#dfGeo_N = dfTotal8.copy()
#for j,item in enumerate(dfGeo_N['N']):    
#    if item == 0  :
#        dfGeo_N.drop(index=j, inplace = True)
#dfGeo_N_1=dfGeo_N.dropna()

# %%
#dfGeo_N_2 = gpd.GeoDataFrame(dfGeo_N_1, geometry = gpd.points_from_xy(dfGeo_N_1.longitude , dfGeo_N_1.latitude))

# %%
#polyplot_kwargs = {'facecolor': (0.9, 0.9, 0.9), 'linewidth': 0}
#pointplot_kwargs = {
#    'scale': 'N', 'edgecolor': 'white', 'linewidth': 0.5#, 'color': 'red'
#}
#ax1 = geoplot.polyplot(contiguous_usa.geometry, projection=geoplot.crs.AlbersEqualArea(),figsize=(14, 8), **polyplot_kwargs)
#geoplot.polyplot(contiguous_usa, ax=ax1, zorder=1)
#geoplot.pointplot(dfGeo_N_2[['N','geometry']],limits=(1, 100),ax = ax1,hue= "N",legend=True, legend_var='hue',**pointplot_kwargs)
#plt.title("Native American people kills by city")
